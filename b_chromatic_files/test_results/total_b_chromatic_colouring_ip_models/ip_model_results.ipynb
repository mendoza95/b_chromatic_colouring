# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
pd.read_csv("d_regular_graphs.csv", index_col=0)
# Out:
#    d    V    E  m(G)  sol_status  b(G)       time
# 0  3   10   15     7           1   7.0   7.687367
# 1  3   20   30     7           1   7.0   2.604830
# 2  3   30   45     7           1   7.0   8.221211
# 3  3   40   60     7           1   7.0  13.935641
# 4  3   50   75     7           1   7.0   2.809740
# 5  3   60   90     7           1   7.0   9.420441
# 6  3   70  105     7           1   7.0   5.063549
# 7  3   80  120     7           1   7.0  16.385876
# 8  3   90  135     7           1   7.0  41.351617
# 9  3  100  150     7           1   7.0  16.881000

# %%
pd.read_csv("10_random_graph_with_20_vertices_31_12_2024_11_55.csv", index_col=0)
# Out:
#    d   V    E  m(G)  sol_status  b(G)        time
# 0  0  20   99    24           0   NaN   89.198758
# 1  1  20  102    24           0   NaN  112.743378
# 2  2  20   82    21           0   NaN   59.249567
# 3  3  20   92    23           0   NaN   80.636575
# 4  4  20   90    23           0   NaN  100.912382
# 5  5  20  101    25           0   NaN  112.051183
# 6  6  20   89    22           0   NaN   62.169371
# 7  7  20   88    21           0   NaN   59.836465
# 8  8  20   90    22           0   NaN   71.400338
# 9  9  20   99    24           0   NaN   87.469942

# %%
pd.read_csv("10_random_graph_with_20_vertices_6_1_2025_9_28.csv", index_col=0)
# Out:
#    d   V   E  m(G)  sol_status  b(G)       time
# 0  0  20  58    15           2   NaN  81.734786
# 1  1  20  55    16           2   NaN  89.650301
# 2  2  20  60    15           2   NaN  93.325374
# 3  3  20  51    14           2   NaN  99.030115
# 4  4  20  47    13           2   NaN  98.604806
# 5  5  20  47    14           2   NaN  97.941581
# 6  6  20  56    15           2   NaN  98.858278
# 7  7  20  56    15           2   NaN  96.937058
# 8  8  20  60    16           2   NaN  94.534599
# 9  9  20  66    18           0   NaN  77.934138

# %%
pd.read_csv("10_random_graph_with_20_vertices_6_1_2025_9_55.csv", index_col=0)
# Out:
#    d   V    E  m(G)  sol_status  b(G)        time
# 0  0  20  130    29           0   NaN  117.503207
# 1  1  20  136    30           0   NaN  152.875339
# 2  2  20  134    31           0   NaN  112.623037
# 3  3  20  131    30           0   NaN  110.648743
# 4  4  20  132    31           0   NaN  168.869192
# 5  5  20  127    29           0   NaN  108.882792
# 6  6  20  140    32           0   NaN  190.992515
# 7  7  20  137    31           0   NaN  114.039005
# 8  8  20  133    30           0   NaN  151.423624
# 9  9  20  123    29           0   NaN  153.602773

# %%
pd.read_csv("random_graphs_tests_ubuntu.csv", index_col=0)
# Out:
#     V      E  m(G) sol_status  b(G)  build_time  sol_time
# 0  10   21.9  11.4       0/10   0.0    0.157747       0.0
# 1  20   91.9  22.5       0/10   0.0    4.123039       0.0
# 2  30  217.5  34.7       0/10   0.0   35.131116       0.0

# %%
pd.read_csv("d_regular_graphs_ubuntu.csv", index_col=0)
# Out:
#       d    V       E  m(G) sol_status  b(G)        time
# 0     3   10    15.0     7      20/20  7.00    4.892479
# 1     3   20    30.0     7      20/20  7.00    5.674501
# 2     3   30    45.0     7      20/20  7.00    7.399788
# 3     3   40    60.0     7      20/20  7.00    6.759640
# 4     3   50    75.0     7      20/20  7.00    6.826895
# 5     3   60    90.0     7      20/20  7.00   14.117527
# 6     3   70   105.0     7      20/20  7.00   11.925806
# 7     3   80   120.0     7      20/20  7.00   14.298014
# 8     3   90   135.0     7      20/20  7.00   49.680710
# 9     3  100   150.0     7      20/20  7.00   18.601363
# 10    3  150   225.0     7      20/20  7.00   36.914386
# 11    4   10    20.0     9       5/20  2.25   27.852365
# 12    4   20    40.0     9      20/20  9.00   53.682148
# 13    4   30    60.0     9      20/20  9.00   85.428864
# 14    4   40    80.0     9      20/20  9.00  144.686813
# 15    4   50   100.0     9      18/20  8.10  235.096453
# ...
