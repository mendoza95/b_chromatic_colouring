# %%
import networkx as nx
import itertools
import matplotlib.pyplot as plt
from b_chromatic_utils import *
from b_chromatic_cubic_graphs import *
from bipartite_matching import getH, getNXgraph

# %% [markdown]
# ### Function for checking if a colouring is proper

# %%
def is_proper(G, c):
    for u,v in G.edges():
        if((c[u] is not None and c[v] is not None) and (c[u] == c[v])):
            return False
    return True

# %% [markdown]
# ### Function for checking if a set of vertices are b-chromatic

# %%
def are_b_chromatic(G, c, node_sets):
    C = set([d for d in c.values() if d is not None])
    for vi in node_sets:
        Cp = set()
        for u in G.adj[vi]:
            Cp.add(c[u])
        #print(Cp, C.difference([c[vi]]))
        if len(Cp) != len(C)-1:
            return False
    return True

# %% [markdown]
# ## Force brute algorithm for finding a b-chromatic colouring on cubic graphs ($n<22$)

# %%
def find_b_chromatic_colouring_bruteforce(G, d):
    """Search for a b-chromatic colouring with d+1 colours on a d-regular graph G trying out all posible combination of colours
    G: d-regular graph
    d: integer
    """
    C = set([i for i in range(1,d+2)])
    S = list(itertools.combinations(G.nodes(),d+1))
    colour_permutations = [list(itertools.permutations(C.difference({i}))) for i in C]
    colour_prod_permutations = list(itertools.product(*colour_permutations))
    for node_sets in S:
        c = {u:None for u in G.nodes()}
        for i, vi in enumerate(node_sets): c[vi] = i+1
        for Xs in colour_prod_permutations:
            for i, vi in enumerate(node_sets):
                for j, uj in enumerate(G.adj[vi]):
                    if uj not in node_sets:
                        c[uj] = Xs[i][j]
            if is_proper(G, c) and are_b_chromatic(G, c, node_sets):
                print("b-chromatic vertices: {}".format(node_sets))
                return c
    return False

# %%
G = nx.random_regular_graph(3,8)
c = find_b_chromatic_colouring_bruteforce(G, 3)
c
# Out:
# b-chromatic vertices: (0, 1, 3, 5)
# {0: 1, 1: 2, 2: 3, 4: 1, 3: 3, 7: 2, 6: 4, 5: 4}

# %%
if c is not False:
    nx.draw(G, with_labels=True, node_color=get_colors_to_use(c))
else:
    nx.draw(G, with_labels=True)

# %% [markdown]
# ## Algorithm for finding a b-chromatic colouring on cubic graphs ($n\geq 22$)

# %% [markdown]
# ### Function for finding two vertices $u$ and $v$ such that $d(u,v)=4$

# %%
def bfs_dist_4(G, u):
    """Runs a BFS on G and return a BFS tree in form of adjacency list"""
    dist = {v:-1 for v in G.nodes()}
    tree = {v:[] for v in G.nodes()}
    #For each i = 1,2,3,4 it stores a pair key:value where key is the vertex at distance i from u 
    # and value is its antecesor in the BFS tree
    distances = {}
    dist[u] = 0
    Q = [u]
    while(len(Q) > 0):
        w = Q.pop(0)
        for v in G.adj[w]:
            if(dist[v] == -1):
                dist[v] = dist[w] + 1
                tree[w].append(v)
                if dist[v] not in distances.keys(): distances[dist[v]] = {v:w}
                else: distances[dist[v]][v] = w
                Q.append(v)
    for key in distances.keys():
        print("Distance {}: {}".format(key, distances[key]))
    P = []
    w = next(iter(distances[4]))
    while(len(P) < 4):
        P.insert(0, w)
        w = distances[5-len(P)][w]
    P.insert(0,u)
    return P, tree

# %%
d = {1:2,3:4}
next(iter(d))
# Out:
# 1

# %%
l = []
l.insert(0, 2)

# %%
l
# Out:
# [2]

# %%
def dfs_path_4(tree, u):
    def dfs(tree, P, v):
        visited[v] = True
        P.append(v)
        for w in tree[v]:
            if not visited[w]:
                dfs(tree, P, w)
                if(len(P) == 5): break
                else: P.pop()# discard the last vertex added (which is w)

    visited = {v:False for v in tree.keys()}
    visited[u] = True
    P = []
    dfs(tree, P, u)
    return P

# %%
def get_path_length_4(G,u):
    tree = bfs_dist_4(G,u)
    P = dfs_path_4(tree, u)
    return P

# %%
G = nx.random_regular_graph(3, 24)
u = random.choice(list(G.nodes()))
P, _ = bfs_dist_4(G,u)
u, P
# Out:
# Distance 1: {3: 22, 7: 22, 18: 22}
# Distance 2: {19: 3, 1: 3, 17: 7, 20: 18, 14: 18}
# Distance 3: {2: 19, 6: 1, 8: 1, 13: 17, 12: 20}
# Distance 4: {21: 2, 10: 6, 23: 8, 5: 8, 11: 12}
# Distance 5: {15: 21, 0: 10, 16: 23, 9: 5, 4: 11}
# (22, [22, 3, 19, 2, 21])

# %%
colours = []
for w in G.nodes():
    if w in P:
        colours.append("#FF9933")
    #elif w in P_prime:
    #    colours.append("#AFB83B")
    else:
        colours.append("#96C3EB")

# %%
nx.draw(G, with_labels=True, node_color=colours)

# %% [markdown]
# ### Function for making $u,w$ and $v$ b-chromatic vertices of colour 1, 2 and 3

# %%
def find_3_b_chromatic_vertices(G, P):
    """Receive a graph G and a path P=<u,u3,w,v3,v> such that dist(u,v)=4"""
    c = {u:None for u in G.nodes()}
    u, u3, w, v3, v = P[0], P[1], P[2], P[3], P[4]
    #print(u,w,v)
    u1, u2 = tuple(set(G.adj[u]).difference({u3}))
    v1, v2 = tuple(set(G.adj[v]).difference({v3}))
    #print(u1,u2)
    #print(v1,v2)
    Pp = [u1,u2,v1,v2]
    c[u] = c[v3] = 1
    c[v] = c[u3] = 3 
    c[w] = c[u1] = c[v1] = 2
    c[u2] = c[v2] = 4
    wp = [x for x in G.adj[w] if x != u3 and x != v3][0]
    #print(wp)
    if wp in Pp:
        #print("w' in P'")
        if wp == u1: c[u1], c[u2] = c[u2], c[u1]
        elif wp == v1: c[v1], c[v2] = c[v2], c[v1]
    else:
        #print(wp, u, v)
        S = {x for x in G.adj[wp] if x in Pp}
        #print("S = {}".format(S))
        if len(S) == 0: c[wp] = 4
        elif len(S) == 1:
            
            # Assume S={x}
            x = S.pop()
            if x == u2: c[u1], c[x] = c[x], c[u1]
            if x == v2: c[v1], c[x] = c[x], c[v1]
            c[wp] = 4
        else:
            #Assume S={x,y}
            x, y = S.pop(), S.pop()
            #x in N(u) and y in N(v)
            if x in G.adj[u] and y in G.adj[v]:
                if x == u2: c[u1], c[x] = c[x], c[u1]
                if y == v2: c[v1], c[y] = c[y], c[v1]
            elif x in G.adj[v] and y in G.adj[u]:
                if x == v2: c[v1], c[x] = c[x], c[v1]
                if y == u2: c[u1], c[y] = c[y], c[u1]
            elif x in G.adj[u] and y in G.adj[u]:
                c[v2], c[v3] = c[v3], c[u2]
                c[wp] = c[u2]
            elif x in G.adj[v] and y in G.adj[v]:
                c[u2], c[u3] = c[u3], c[v2]
                c[wp] = c[v2]
    Q = P+[u1,u2,v1,v2,wp]
    return c, Q

# %% [markdown]
# ### Function for finding the 4th b-chromatic vertex

# %%
#This function 
#A more efficient implementation rely on the search of a perfect matching between the colours and the available colours in the neighbourhood of x
def find_b_chromatic_assignment(G, Cp, x, c):
    """Search through all possible combination of colours in Cp an assigment that makes x b-chromatic(provided that such assignment exists)
    G: graph,
    Cp: Colours that need to be assign to N(u)
    x: vertex to check, 
    c: colouring function, 
    success: True when a b-chromatic assigment has been found"""
    C = list(itertools.permutations(list(Cp)))
    #T = {y for y in G.adj[x]}
    for colours in C:
        cp = c.copy()
        for i, xi in enumerate(G.adj[x]):
            if cp[xi] is None:
                cp[xi] = colours[i]
        #print(is_proper(G, cp), are_b_chromatic(G, cp, {x}))
        #print(cp)
        if is_proper(G, cp) and are_b_chromatic(G, cp, {x}): return cp, True
    return c, False

# %%
# Out:
# True

# %%
def does_conditions_i_ii_lemma3_hold(G, Cp, c, x, CSNx, cNx):
    """Checks whether condition I and II of Lemma 3 hold on the uncoloured neighbours of x
    G: Graph
    Cp: set of colours that vertex x need to pick up on its neighbourhood
    c: colour function assigment
    x: candidate vertex to become b-chromatic
    SNx: Subset of neighbours of x with no colour assign to it (|CSNx| >= 2)
    cNx: Set of colour used in N(x)"""
    cCSNx = {xp: {c[xpp] for xpp in G.adj[xp] if xpp != x and c[xpp] is not None}for xp in CSNx}
    assert cCSNx != set()
    I = Cp.difference(cNx)
    for xp in cCSNx.keys(): I = I.intersection(cCSNx[xp])
    if I != set(): return False
    for xp1, xp2 in itertools.combinations(CSNx, 2):
        if (len(cCSNx[xp1].intersection(cCSNx[xp2])) == 2): return False
    return True

# %%
def can_u_become_b_chromatic(G, C, u, d, c):
    """Checks whether vertex u can become a b-chromatic vertex of colour d
    G: Graph
    C: Set of colours used in the colouring c
    u: vertex to be checked
    d: colour that vertex u will pick up
    c: colour assignation function
    """
    for up in G.adj[u]:
        if c[up] == d: return False#First we check whether or not d is in the neighbourhood of u
    cNu = {c[up] for up in G.adj[u] if c[up] is not None} #colour set of the neighbour of u
    SNx = {up for up in G.adj[u] if c[up] is not None} #set of coloured neighbours of u
    #print("coloruhood of u: {} and coloured vertices in N(u): {}".format(cNu, SNx))
    if (cNu != set() and SNx != set()) and len(cNu) == len(SNx): return True
    if (cNu != set() and SNx != set()) and len(cNu) < len(SNx): return False
    CSNx = {up for up in G.adj[u] if up not in SNx}
    return does_conditions_i_ii_lemma3_hold(G, C.difference({d}), c, u, CSNx, cNu)

# %%
Gp = nx.Graph()
C = {1,2,3,4}
d = 4
Gp.add_edges_from([(1,2),(1,3),(1,4),(2,5), (2,6), (3,7),(3,8), (4,9), (4,10)])
c = {u:None for u in Gp.nodes()}
c[1] = d
#c[2] = 1
#c[3] = 3
#c[4] = 2
c[8]  = 1
c[6] = c[7] = 2
#c[10] = 1
if can_u_become_b_chromatic(Gp, C, 1, d, c): 
    print("Yes, it can!")
    c, success = find_b_chromatic_assignment(Gp, C.difference({d}), 1, c)
    print(success)
else: print("No!")
nx.draw(Gp, with_labels=True, node_color = get_colors_to_use(c))
# Out:
# Yes, it can!
# True

# %%
c
# Out:
# {1: 4, 2: None, 3: None, 4: None, 5: None, 6: 2, 7: 2, 8: 1, 9: None, 10: None}

# %%
type({})
# Out:
# dict

# %%
def find_fourth_b_chromatic_vertex(G, x, c, visited, Vp, success, d):
    """G: Graph, x: vertex to check, c: colouring function, visited: verifies whether a vertex has been visited or not
    S: {u,w,v}, success: True when the fourth b-chromatic vertex has been found"""
    C = {a for a in c.values() if a is not None}
    if not visited[x]:
        visited[x] = True
        cNx = {c[xp] for xp in G.adj[x] if c[xp] is not None}
        if (c[x] == d or (c[x] is None and d not in cNx)):
            if (can_u_become_b_chromatic(G, C, x, d, c)):
                c, success = find_b_chromatic_assignment(G, C.difference({d}), x, c)
                if success:
                    if c[x] is None: c[x] = d
                    Vp.append(x)
                    return c, success
        for xp in G.adj[x]:
            if not visited[xp]:
                c, success = find_fourth_b_chromatic_vertex(G, xp, c, visited, Vp, success, d)
                if success:
                    return c, success

# %%
def cubic_b_chromatic_colouring(G):
    u = random.choice(list(G.nodes()))
    P = get_path_length_4(G, u)
    c, Q = find_3_b_chromatic_vertices(G, P)
    Vp = [P[0], P[2], P[4]]#set of b-chromatic vertices
    visited = {x:False for x in G.nodes()}
    success = False
    while not success:
        x = Q.pop()
        c, success = find_fourth_b_chromatic_vertex(G, x, c, visited, Vp, success, 4)
    assert are_b_chromatic(G, c, Vp)
    assert {c[w] for w in Vp} == {d for d in c.values() if d is not None}
    print(Vp)
    return c

# %%
G = nx.random_regular_graph(3, 24)
#c = cubic_b_chromatic_colouring(G)
nx.draw(G, with_labels=True)#, node_color=get_colors_to_use(c))

# %%
G.adj[2]
# Out:
# AtlasView({1: {}, 10: {}, 18: {}})

# %%
G = nx.random_regular_graph(3, 24)
u = random.choice(list(G.nodes()))
P, _ = bfs_dist_4(G, u)
c, Q = find_3_b_chromatic_vertices(G, P)
Vp = [P[0], P[2], P[4]]#set of b-chromatic vertices
visited = {x:False for x in G.nodes()}
success = False
while not success:
    x = Q.pop()
    c, success = find_fourth_b_chromatic_vertex(G, x, c, visited, Vp, success, 4)
assert are_b_chromatic(G, c, Vp)
assert {c[w] for w in Vp} == {d for d in c.values() if d is not None}
# Out:
# Distance 1: {23: 0, 17: 0, 10: 0}
# Distance 2: {2: 23, 3: 23, 11: 17, 6: 17, 5: 10, 4: 10}
# Distance 3: {19: 2, 21: 3, 8: 11, 7: 11, 15: 6, 1: 6, 9: 4, 14: 4}
# Distance 4: {18: 21, 12: 8, 16: 8, 22: 1, 13: 9}
# Distance 5: {20: 12}

# %%
Vp
# Out:
# [0, 3, 18, 19]

# %%
nx.draw(G, with_labels=True, node_color=get_colors_to_use(c))

# %%
# Out:
# 15 [10, 19, 0]
# 15 has colour 4
# 15 can become b-chromatic

# %%
nx.draw(G, with_labels=True, node_color=get_colors_to_use(c))

# %%
nx.draw(G, with_labels=True, node_color=get_colors_to_use(c))

# %%
nx.draw(G, with_labels=True, node_color=get_colors_to_use(c))

# %%
list(Q)

# %% [markdown]
# ## Testing b-chromatic colouring algorithm for cubic graph

# %%
nodes = [i for i in range(24)]
edges = [(6, 12), (6, 11), (6, 2), (12, 10), (12, 15), (18, 20), 
         (18, 17), (18, 19), (20, 3), (20, 5), (9, 14), (9, 7), 
         (9, 15), (14, 22), (14, 7), (22, 4), (22, 19), (17, 11), 
         (17, 5), (0, 8), (0, 13), (0, 21), (8, 4), (8, 5), (10, 11), 
         (10, 16), (13, 23), (13, 16), (23, 15), (23, 3), (1, 21), 
         (1, 2), (1, 7), (21, 3), (19, 4), (2, 16)]
Gr = nx.Graph()
Gr.add_nodes_from(nodes)
Gr.add_edges_from(edges)

# %%
while(True):
    #try:
    Gr = nx.random_regular_graph(3,24)
    if nx.is_connected(Gr):
        c = get_b_chromatic_colouring(Gr)
    #except:
        #break
#Grcolours = get_colors_to_use(c)
#nx.draw(Gr, with_labels=True, node_color=Grcolours)
# Out:
# 2
# [2, 6, 3]
# 0
# [0, 10, 5]
# 3
# [3, 9, 22]
# 8
# [8, 5, 10]
# 2
# [2, 23, 20]
# 13
# [13, 12, 10]
# 15
# [15, 22, 7]
# 22
# [22, 4, 15]
# 23
# [23, 0, 9]
# 6
# [6, 22, 2]
# 12
# [12, 6, 14]
# 12
# [12, 16, 2]
# 19
# [19, 16, 20]
# 21
# [21, 3, 9]
# 7
# [7, 8, 1]
# 0
# [0, 8, 5]
# 17
# [17, 22, 7]
# 22
# [22, 9, 20]
# 16
# [16, 4, 1]
# 14
# [14, 8, 16]
# 8
# [8, 6, 21]
# 20
# [20, 8, 22]
# 7
# [7, 11, 19]
# 10
# [10, 18, 2]
# 6
# [6, 16, 17]
# 15
# [15, 22, 4]
# 18
# [18, 3, 7]
# 10
# [10, 6, 19]
# 15
# [15, 4, 20]
# 14
# [14, 15, 13]
# 1
# [1, 13, 9]
# 13
# [13, 11, 9]
# 16
# [16, 11, 23]
# 13
# [13, 17, 3]
# 9
# [9, 2, 10]
# 22
# [22, 6, 20]
# 18
# [18, 15, 0]
# 4
# [4, 15, 22]
# 8
# [8, 23, 14]
# 5
# [5, 13, 0]
# 20
# [20, 7, 1]
# 23
# [23, 6, 12]
# 14
# [14, 18, 8]
# 3
# [3, 12, 11]
# 1
# [1, 16, 3]
# 6
# [6, 8, 15]
# 5
# [5, 20, 22]
# 20
# [20, 7, 18]
# 14
# [14, 20, 9]
# 8
# [8, 15, 7]
# 14
# [14, 17, 10]
# 21
# [21, 3, 2]
# 1
# [1, 17, 10]
# 14
# [14, 16, 6]
# 13
# [13, 4, 18]
# 9
# [9, 4, 17]
# 14
# [14, 7, 11]
# 10
# [10, 9, 5]
# 4
# [4, 23, 9]
# 21
# [21, 19, 15]
# 5
# [5, 4, 0]
# 11
# [11, 20, 13]
# 7
# [7, 11, 22]
# 21
# [21, 13, 2]
# 1
# [1, 4, 16]
# 3
# [3, 7, 13]
# 20
# [20, 22, 14]
# 1
# [1, 22, 6]
# 11
# [11, 3, 17]
# 11
# [11, 4, 6]
# 17
# [17, 14, 22]
# 23
# [23, 14, 11]
# 8
# [8, 15, 11]
# 7
# [7, 14, 1]
# 7
# [7, 13, 22]
# 9
# [9, 7, 15]
# 16
# [16, 13, 19]
# 21
# [21, 20, 22]
# 18
# [18, 3, 14]
# 13
# [13, 20, 7]
# 6
# [6, 20, 8]
# 5
# [5, 0, 16]
# 3
# [3, 9, 5]
# 23
# [23, 6, 16]
# 12
# [12, 23, 3]
# 11
# [11, 0, 18]
# 9
# [9, 6, 2]
# 20
# [20, 9, 3]
# 0
# [0, 22, 13]
# 14
# [14, 6, 13]
# 3
# [3, 5, 14]
# 23
# [23, 5, 1]
# 21
# [21, 18, 1]
# 14
# [14, 12, 11]
# 7
# [7, 18, 1]
# 18
# [18, 21, 16]
# 14
# [14, 11, 15]
# 11
# [11, 6, 18]
# 8
# [8, 22, 19]
# 1
# [1, 18, 20]
# 16
# [16, 4, 11]
# 20
# [20, 14, 16]
# 2
# [2, 16, 23]
# 7
# [7, 11, 16]
# 20
# [20, 12, 6]
# 15
# [15, 19, 11]
# 13
# [13, 0, 10]
# 0
# [0, 9, 17]
# 5
# [5, 15, 2]
# 8
# [8, 19, 3]
# 19
# [19, 23, 8]
# 6
# [6, 8, 23]
# 7
# [7, 1, 3]
# 16
# [16, 17, 4]
# 3
# [3, 16, 2]
# 15
# [15, 18, 22]
# 15
# [15, 17, 13]
# 1
# [1, 5, 22]
# 8
# [8, 22, 4]
# 13
# [13, 12, 21]
# 5
# [5, 14, 10]
# 6
# [6, 0, 10]
# 15
# [15, 6, 21]
# 15
# [15, 6, 21]
# 9
# [9, 23, 1]
# 12
# [12, 4, 8]
# 3
# [3, 18, 9]
# 21
# [21, 14, 20]
# 9
# [9, 3, 12]
# 0
# [0, 5, 1]
# 15
# [15, 19, 2]
# 19
# [19, 2, 16]
# 20
# [20, 21, 3]
# 10
# [10, 3, 17]
# 16
# [16, 10, 9]
# 2
# [2, 18, 10]
# 4
# [4, 0, 14]
# 9
# [9, 16, 23]
# 14
# [14, 21, 12]
# 7
# [7, 12, 22]
# 10
# [10, 4, 11]
# 22
# [22, 17, 13]
# 19
# [19, 13, 8]
# 12
# [12, 22, 9]
# 4
# [4, 8, 3]
# 2
# [2, 12, 13]
# 19
# [19, 1, 2]
# 19
# [19, 20, 10]
# 8
# [8, 20, 18]
# 11
# [11, 22, 0]
# 3
# [3, 15, 11]
# 14
# [14, 17, 7]
# 1
# [1, 5, 21]
# 1
# [1, 0, 14]
# 15
# [15, 18, 9]
# 11
# [11, 15, 23]
# 10
# [10, 13, 8]
# 3
# [3, 9, 5]
# 16
# [16, 5, 17]
# 15
# [15, 18, 8]
# 9
# [9, 12, 10]
# 6
# [6, 19, 17]
# 18
# [18, 19, 7]
# 6
# [6, 9, 15]
# 12
# [12, 6, 13]
# 22
# [22, 2, 9]
# 23
# [23, 21, 14]
# 2
# [2, 6, 9]
# 9
# [9, 18, 4]
# 6
# [6, 10, 7]
# 14
# [14, 13, 8]
# 1
# [1, 3, 17]
# 2
# [2, 13, 4]
# 21
# [21, 23, 4]
# 19
# [19, 5, 10]
# 19
# [19, 17, 18]
# 12
# [12, 9, 16]
# 1
# [1, 10, 8]
# 1
# [1, 3, 7]
# 1
# [1, 12, 5]
# 14
# [14, 7, 17]
# 14
# [14, 7, 18]
# 10
# [10, 6, 12]
# 5
# [5, 9, 18]
# 22
# [22, 16, 8]
# 22
# [22, 11, 5]
# 3
# [3, 12, 14]
# 17
# [17, 22, 2]
# 4
# [4, 8, 17]
# 22
# [22, 15, 20]
# 3
# [3, 14, 2]
# 22
# [22, 7, 5]
# 10
# [10, 7, 14]
# 23
# [23, 11, 12]
# 5
# [5, 14, 2]
# 19
# [19, 16, 20]
# 0
# [0, 8, 1]
# 5
# [5, 0, 8]
# 18
# [18, 12, 8]
# 11
# [11, 5, 15]
# 4
# [4, 21, 0]
# 10
# [10, 12, 22]
# 17
# [17, 10, 3]
# 19
# [19, 15, 20]
# 2
# [2, 8, 14]
# 23
# [23, 20, 15]
# 16
# [16, 9, 7]
# 19
# [19, 9, 4]
# 22
# [22, 0, 21]
# 1
# [1, 13, 22]
# 21
# [21, 1, 6]
# 1
# [1, 2, 14]
# 16
# [16, 7, 23]
# 15
# [15, 14, 21]
# 17
# [17, 14, 16]
# 14
# [14, 15, 3]
# 0
# [0, 6, 9]
# 11
# [11, 16, 2]
# 13
# [13, 9, 0]
# 8
# [8, 5, 3]
# 1
# [1, 23, 12]
# 14
# [14, 5, 19]
# 4
# [4, 18, 13]
# 22
# [22, 13, 21]
# 15
# [15, 18, 22]
# 4
# [4, 16, 6]
# 16
# [16, 23, 2]
# 14
# [14, 15, 18]
# 6
# [6, 22, 4]
# 13
# [13, 20, 10]
# 9
# [9, 22, 5]
# 13
# [13, 14, 4]
# 11
# [11, 14, 21]
# 15
# [15, 10, 23]
# 0
# [0, 6, 16]
# 1
# [1, 21, 5]
# 0
# [0, 15, 9]
# 0
# [0, 5, 20]
# 21
# [21, 22, 17]
# 23
# [23, 2, 3]
# 0
# [0, 10, 18]
# 19
# [19, 14, 23]
# 0
# [0, 21, 7]
# 19
# [19, 21, 7]
# 22
# [22, 10, 16]
# 5
# [5, 11, 10]
# 8
# [8, 5, 10]
# 3
# [3, 17, 11]
# 15
# [15, 4, 23]
# 22
# [22, 6, 11]
# 8
# [8, 7, 11]
# 2
# [2, 17, 15]
# 23
# [23, 8, 18]
# 22
# [22, 9, 12]
# 14
# [14, 3, 22]
# 6
# [6, 12, 10]
# 14
# [14, 13, 4]
# 22
# [22, 8, 12]
# 2
# [2, 15, 7]
# 22
# [22, 3, 5]
# 3
# [3, 5, 23]
# 16
# [16, 11, 22]
# 16
# [16, 8, 23]
# 4
# [4, 2, 6]
# 21
# [21, 19, 16]
# 19
# [19, 13, 23]
# 8
# [8, 11, 17]
# 23
# [23, 10, 16]
# 1
# [1, 10, 7]
# 15
# [15, 17, 22]
# 15
# [15, 14, 7]
# 15
# [15, 6, 20]
# 3
# [3, 5, 1]
# 10
# [10, 13, 19]
# 7
# [7, 20, 16]
# 15
# [15, 18, 21]
# 9
# [9, 4, 16]
# 5
# [5, 8, 14]
# 3
# [3, 7, 23]
# 9
# [9, 5, 6]
# 16
# [16, 6, 9]
# 3
# [3, 20, 22]
# 2
# [2, 10, 9]
# 23
# [23, 12, 9]
# 5
# [5, 21, 13]
# 13
# [13, 12, 15]
# 23
# [23, 11, 20]
# 23
# [23, 20, 3]
# 13
# [13, 12, 21]
# 22
# [22, 7, 2]
# 20
# [20, 12, 2]
# 4
# [4, 3, 11]
# 21
# [21, 12, 9]
# 0
# [0, 15, 22]
# 3
# [3, 5, 23]
# 8
# [8, 11, 14]
# 8
# [8, 12, 1]
# 3
# [3, 22, 20]
# 9
# [9, 4, 5]
# 6
# [6, 1, 0]
# 0
# [0, 18, 14]
# 4
# [4, 3, 7]
# 4
# [4, 20, 13]
# 8
# [8, 20, 9]
# 13
# [13, 12, 16]
# 3
# [3, 1, 9]
# 10
# [10, 1, 8]
# 21
# [21, 15, 9]
# 11
# [11, 2, 9]
# 12
# [12, 10, 23]
# 17
# [17, 20, 10]
# 19
# [19, 14, 16]
# 8
# [8, 18, 5]
# 22
# [22, 4, 12]
# 13
# [13, 15, 7]
# 12
# [12, 9, 11]
# 17
# [17, 9, 4]
# 12
# [12, 15, 5]
# 2
# [2, 15, 11]
# 3
# [3, 9, 13]
# 13
# [13, 6, 22]
# 5
# [5, 7, 12]
# 23
# [23, 8, 17]
# 17
# [17, 1, 5]
# 4
# [4, 23, 5]
# 14
# [14, 16, 21]
# 20
# [20, 16, 9]
# 12
# [12, 0, 9]
# 15
# [15, 19, 12]
# 4
# [4, 13, 11]
# 20
# [20, 11, 3]
# 9
# [9, 3, 21]
# 3
# [3, 11, 7]
# 15
# [15, 14, 1]
# 19
# [19, 9, 23]
# 7
# [7, 18, 11]
# 17
# [17, 11, 0]
# 17
# [17, 5, 16]
# 13
# [13, 15, 19]
# 2
# [2, 21, 1]
# 20
# [20, 2, 5]
# 7
# [7, 20, 8]
# 2
# [2, 0, 12]
# 19
# [19, 1, 9]
# 6
# [6, 9, 22]
# 13
# [13, 12, 3]
# 5
# [5, 19, 2]
# 2
# [2, 3, 12]
# 4
# [4, 1, 17]
# 21
# [21, 17, 5]
# 16
# [16, 20, 18]
# 22
# [22, 8, 23]
# 6
# [6, 23, 21]
# 18
# [18, 15, 20]
# 0
# [0, 19, 21]
# 7
# [7, 16, 17]
# 9
# [9, 19, 15]
# 4
# [4, 6, 16]
# 16
# [16, 14, 17]
# 9
# [9, 12, 21]
# 10
# [10, 17, 5]
# 19
# [19, 14, 21]
# 12
# [12, 23, 5]
# 15
# [15, 13, 7]
# 1
# [1, 12, 11]
# 21
# [21, 20, 11]
# 9
# [9, 8, 12]
# 2
# [2, 6, 5]
# 3
# [3, 1, 19]
# 12
# [12, 21, 20]
# 13
# [13, 21, 9]
# 16
# [16, 0, 1]
# 5
# [5, 21, 7]
# 2
# [2, 6, 15]
# 7
# [7, 12, 23]
# 2
# [2, 0, 14]
# 11
# [11, 9, 8]
# 6
# [6, 12, 13]
# 14
# [14, 22, 11]
# 0
# [0, 17, 18]
# 8
# [8, 21, 16]
# 17
# [17, 20, 7]
# 12
# [12, 4, 2]
# 14
# [14, 20, 8]
# 19
# [19, 14, 12]
# 21
# [21, 6, 3]
# 22
# [22, 11, 3]
# 12
# [12, 3, 17]
# 19
# [19, 12, 10]
# 5
# [5, 3, 2]
# 23
# [23, 20, 13]
# 0
# [0, 8, 6]
# 0
# [0, 21, 5]
# 21
# [21, 12, 19]
# 18
# [18, 20, 12]
# 2
# [2, 20, 23]
# 23
# [23, 6, 3]
# 12
# [12, 8, 2]
# 9
# [9, 23, 14]
# 17
# [17, 3, 2]
# 0
# [0, 22, 18]
# 14
# [14, 4, 6]
# 19
# [19, 23, 1]
# 18
# [18, 20, 3]
# 11
# [11, 15, 2]
# 1
# [1, 8, 2]
# 21
# [21, 16, 14]
# 10
# [10, 9, 19]
# 20
# [20, 5, 3]
# 19
# [19, 1, 2]
# 0
# [0, 9, 20]
# 10
# [10, 3, 12]
# 11
# [11, 18, 3]
# 10
# [10, 13, 11]
# 15
# [15, 3, 0]
# 3
# [3, 14, 5]
# 3
# [3, 11, 6]
# 10
# [10, 11, 0]
# 16
# [16, 19, 0]
# 18
# [18, 12, 2]
# 15
# [15, 9, 16]
# 15
# [15, 17, 19]
# 23
# [23, 1, 20]
# 22
# [22, 5, 11]
# 20
# [20, 21, 13]
# 20
# [20, 12, 17]
# 19
# [19, 23, 14]
# 6
# [6, 4, 19]
# 18
# [18, 19, 4]
# 8
# [8, 3, 19]
# 15
# [15, 4, 12]
# 14
# [14, 12, 15]
# 16
# [16, 2, 23]
# 8
# [8, 9, 6]
# 18
# [18, 23, 22]
# 9
# [9, 13, 22]
# 6
# [6, 17, 14]
# 15
# [15, 10, 21]
# 21
# [21, 11, 7]
# 12
# [12, 14, 2]
# 0
# [0, 1, 20]
# 8
# [8, 19, 0]
# 11
# [11, 7, 12]
# 6
# [6, 13, 18]
# 12
# [12, 0, 23]
# 4
# [4, 1, 18]
# 10
# [10, 12, 5]
# 15
# [15, 3, 17]
# 2
# [2, 23, 9]
# 4
# [4, 2, 14]
# 19
# [19, 20, 1]
# 14
# [14, 19, 11]
# 15
# [15, 5, 2]
# 15
# [15, 22, 5]
# 6
# [6, 12, 17]
# 17
# [17, 9, 16]
# 9
# [9, 2, 8]
# 4
# [4, 17, 1]
# 1
# [1, 15, 16]
# 12
# [12, 10, 21]
# 3
# [3, 12, 9]
# 8
# [8, 23, 17]
# 14
# [14, 11, 18]
# 21
# [21, 14, 23]
# 15
# [15, 0, 9]
# 0
# [0, 15, 11]
# 4
# [4, 15, 2]
# 2
# [2, 5, 0]
# 23
# [23, 7, 0]
# 23
# [23, 5, 6]
# 5
# [5, 7, 23]
# 10
# [10, 9, 11]
# 23
# [23, 3, 2]
# 15
# [15, 5, 3]
# 8
# [8, 15, 12]
# 10
# [10, 19, 17]
# 20
# [20, 16, 2]
# 4
# [4, 22, 0]
# 11
# [11, 23, 16]
# 21
# [21, 17, 11]
# 1
# [1, 6, 12]
# 14
# [14, 19, 7]
# 17
# [17, 8, 11]
# 23
# [23, 14, 5]
# 14
# [14, 12, 20]
# 4
# [4, 19, 3]
# 2
# [2, 6, 15]
# 11
# [11, 21, 6]
# 11
# [11, 7, 4]
# 19
# [19, 13, 1]
# 23
# [23, 15, 5]
# 1
# [1, 9, 2]
# 10
# [10, 6, 20]
# 9
# [9, 22, 23]
# 0
# [0, 10, 16]
# 23
# [23, 1, 17]
# 18
# [18, 4, 0]
# 14
# [14, 7, 3]
# 6
# [6, 20, 23]
# 23
# [23, 22, 5]
# 21
# [21, 9, 13]
# 9
# [9, 23, 7]
# 16
# [16, 7, 11]
# 8
# [8, 2, 4]
# 18
# [18, 9, 5]
# 12
# [12, 23, 5]
# 1
# [1, 7, 15]
# 4
# [4, 19, 7]
# 23
# [23, 8, 22]
# 14
# [14, 23, 21]
# 18
# [18, 2, 5]
# 7
# [7, 22, 12]
# 19
# [19, 7, 17]
# 2
# [2, 16, 15]
# 0
# [0, 20, 15]
# 4
# [4, 17, 5]
# 22
# [22, 13, 6]
# 14
# [14, 17, 2]
# 20
# [20, 19, 15]
# 8
# [8, 22, 0]
# 14
# [14, 5, 21]
# 23
# [23, 6, 19]
# 20
# [20, 14, 13]
# 8
# [8, 0, 2]
# 23
# [23, 5, 17]
# 20
# [20, 6, 13]
# 12
# [12, 18, 9]
# 20
# [20, 19, 18]
# 6
# [6, 2, 17]
# 19
# [19, 21, 13]
# 21
# [21, 1, 16]
# 6
# [6, 14, 0]
# 5
# [5, 13, 2]
# 20
# [20, 22, 6]
# 22
# [22, 6, 13]
# 6
# [6, 10, 18]
# 12
# [12, 9, 3]
# 1
# [1, 10, 17]
# 4
# [4, 17, 23]
# 11
# [11, 13, 3]
# 14
# [14, 8, 18]
# 15
# [15, 8, 7]
# 12
# [12, 20, 11]
# 18
# [18, 3, 23]
# 3
# [3, 0, 8]
# 5
# [5, 23, 17]
# 18
# [18, 9, 12]
# 5
# [5, 20, 3]
# 7
# [7, 6, 11]
# 3
# [3, 23, 7]
# 6
# [6, 12, 23]
# 11
# [11, 14, 18]
# 4
# [4, 5, 3]
# 11
# [11, 13, 20]
# 23
# [23, 20, 22]
# 1
# [1, 20, 10]
# 10
# [10, 12, 3]
# 17
# [17, 22, 4]
# 15
# [15, 6, 21]
# 18
# [18, 6, 10]
# 18
# [18, 20, 19]
# 7
# [7, 9, 8]
# 14
# [14, 22, 10]
# 15
# [15, 21, 7]
# 21
# [21, 17, 9]
# 3
# [3, 14, 17]
# 18
# [18, 21, 16]
# 10
# [10, 7, 8]
# 19
# [19, 16, 1]
# 0
# [0, 7, 1]
# 23
# [23, 7, 2]
# 17
# [17, 3, 23]
# 10
# [10, 9, 23]
# 0
# [0, 11, 10]
# 3
# [3, 1, 8]
# 10
# [10, 20, 4]
# 8
# [8, 18, 4]
# 14
# [14, 10, 8]
# 0
# [0, 18, 8]
# 7
# [7, 20, 14]
# 17
# [17, 6, 21]
# 16
# [16, 5, 8]
# 16
# [16, 21, 14]
# 23
# [23, 4, 12]
# 6
# [6, 18, 20]
# 9
# [9, 13, 21]
# 20
# [20, 23, 4]
# 3
# [3, 20, 19]
# 23
# [23, 17, 4]
# 3
# [3, 4, 20]
# 11
# [11, 0, 23]
# 9
# [9, 4, 23]
# 17
# [17, 8, 11]
# 2
# [2, 6, 19]
# 9
# [9, 22, 6]
# 8
# [8, 16, 1]
# 16
# [16, 6, 9]
# 7
# [7, 10, 14]
# 7
# [7, 13, 16]
# 17
# [17, 20, 7]
# 10
# [10, 16, 3]
# 20
# [20, 13, 12]
# 8
# [8, 7, 20]
# 17
# [17, 14, 16]
# 17
# [17, 23, 4]
# 6
# [6, 22, 9]
# 11
# [11, 22, 5]
# 0
# [0, 18, 22]
# 22
# [22, 19, 9]
# 15
# [15, 14, 22]
# 13
# [13, 4, 7]
# 15
# [15, 1, 6]
# 3
# [3, 2, 8]
# 18
# [18, 5, 20]
# 17
# [17, 23, 0]
# 16
# [16, 19, 18]
# 5
# [5, 0, 22]
# 9
# [9, 16, 5]
# 16
# [16, 14, 23]
# 10
# [10, 5, 20]
# 11
# [11, 18, 1]
# 2
# [2, 11, 13]
# 16
# [16, 15, 5]
# 23
# [23, 6, 17]
# 12
# [12, 1, 22]
# 0
# [0, 7, 6]
# 7
# [7, 23, 1]
# 10
# [10, 11, 2]
# 20
# [20, 12, 9]
# 13
# [13, 14, 23]
# 9
# [9, 19, 2]
# 9
# [9, 22, 11]
# 2
# [2, 8, 16]
# 5
# [5, 21, 1]
# 20
# [20, 0, 10]
# 2
# [2, 23, 9]
# 13
# [13, 9, 23]
# 5
# [5, 14, 4]
# 9
# [9, 22, 20]
# 15
# [15, 18, 13]
# 18
# [18, 9, 20]
# 18
# [18, 9, 5]
# 21
# [21, 22, 7]
# 3
# [3, 9, 11]
# 0
# [0, 20, 7]
# 4
# [4, 18, 7]
# 10
# [10, 12, 17]
# 23
# [23, 12, 22]
# 3
# [3, 15, 12]
# 19
# [19, 7, 4]
# 14
# [14, 17, 1]
# 11
# [11, 9, 21]
# 9
# [9, 15, 6]
# 19
# [19, 15, 13]
# 2
# [2, 9, 17]
# 12
# [12, 9, 22]
# 16
# [16, 14, 17]
# 23
# [23, 13, 9]
# 19
# [19, 9, 20]
# 1
# [1, 16, 13]
# 3
# [3, 10, 12]
# 19
# [19, 11, 1]
# 10
# [10, 8, 23]
# 9
# [9, 5, 18]
# 15
# [15, 23, 20]
# 11
# [11, 18, 3]
# 17
# [17, 19, 10]
# 23
# [23, 18, 13]
# 0
# [0, 4, 20]
# 12
# [12, 8, 10]
# 19
# [19, 14, 18]
# 16
# [16, 12, 18]
# 15
# [15, 21, 9]
# 13
# [13, 16, 3]
# 1
# [1, 4, 3]
# 3
# [3, 1, 6]
# 23
# [23, 0, 6]
# 22
# [22, 14, 20]
# 8
# [8, 11, 10]
# 4
# [4, 15, 11]
# 5
# [5, 17, 0]
# 18
# [18, 22, 6]
# 19
# [19, 2, 16]
# 2
# [2, 23, 11]
# 14
# [14, 1, 11]
# 22
# [22, 5, 23]
# 14
# [14, 5, 9]
# 7
# [7, 17, 21]
# 0
# [0, 6, 16]
# 18
# [18, 3, 2]
# 18
# [18, 22, 14]
# 8
# [8, 0, 3]
# 19
# [19, 2, 13]
# 17
# [17, 6, 12]
# 14
# [14, 15, 10]
# 10
# [10, 23, 12]
# 0
# [0, 10, 19]
# 11
# [11, 20, 17]
# 11
# [11, 4, 5]
# 22
# [22, 12, 14]
# 4
# [4, 13, 17]
# 18
# [18, 13, 6]
# 0
# [0, 8, 14]
# 6
# [6, 10, 19]
# 20
# [20, 0, 12]
# 21
# [21, 2, 8]
# 21
# [21, 15, 2]
# 2
# [2, 7, 12]
# 23
# [23, 6, 3]
# 10
# [10, 18, 2]
# 22
# [22, 20, 9]
# 14
# [14, 5, 17]
# 0
# [0, 14, 13]
# 4
# [4, 9, 12]
# 16
# [16, 12, 13]
# 4
# [4, 18, 1]
# 16
# [16, 15, 4]
# 18
# [18, 12, 4]
# 0
# [0, 3, 22]
# 4
# [4, 21, 3]
# 13
# [13, 18, 8]
# 16
# [16, 2, 10]
# 0
# [0, 3, 20]
# 11
# [11, 9, 10]
# 1
# [1, 16, 6]
# 11
# [11, 1, 19]
# 22
# [22, 4, 20]
# 14
# [14, 0, 6]
# 12
# [12, 1, 23]
# 4
# [4, 10, 11]
# 0
# [0, 6, 13]
# 13
# [13, 9, 12]
# 8
# [8, 19, 5]
# 10
# [10, 1, 6]
# 2
# [2, 0, 7]
# 20
# [20, 17, 23]
# 16
# [16, 7, 15]
# 0
# [0, 6, 20]
# 4
# [4, 6, 9]
# 6
# [6, 23, 19]
# 12
# [12, 6, 9]
# 4
# [4, 12, 11]
# 14
# [14, 13, 8]
# 20
# [20, 13, 11]
# 14
# [14, 10, 17]
# 16
# [16, 2, 10]
# 15
# [15, 7, 6]
# 16
# [16, 15, 17]
# 15
# [15, 21, 18]
# 13
# [13, 3, 17]
# 20
# [20, 2, 7]
# 18
# [18, 21, 3]
# 13
# [13, 23, 0]
# 2
# [2, 6, 3]
# 1
# [1, 21, 22]
# 7
# [7, 20, 1]
# 16
# [16, 19, 2]
# 23
# [23, 17, 8]
# 22
# [22, 5, 9]
# 21
# [21, 0, 14]
# 11
# [11, 0, 23]
# 3
# [3, 10, 15]
# 18
# [18, 4, 10]
# 12
# [12, 0, 7]
# 19
# [19, 8, 6]
# 12
# [12, 4, 9]
# 22
# [22, 6, 12]
# 9
# [9, 3, 10]
# 10
# [10, 1, 3]
# 12
# [12, 18, 8]
# 16
# [16, 13, 5]
# 1
# [1, 11, 22]
# 18
# [18, 3, 14]
# 4
# [4, 10, 8]
# 17
# [17, 2, 20]
# 21
# [21, 9, 6]
# 5
# [5, 14, 18]
# 8
# [8, 4, 16]
# 4
# [4, 6, 18]
# 7
# [7, 11, 17]
# 23
# [23, 17, 7]
# 8
# [8, 19, 0]
# 6
# [6, 13, 4]
# 11
# [11, 15, 10]
# 19
# [19, 13, 22]
# 5
# [5, 21, 11]
# 3
# [3, 15, 7]
# 14
# [14, 7, 23]
# 8
# [8, 11, 3]
# 2
# [2, 16, 11]
# 16
# [16, 12, 18]
# 16
# [16, 8, 15]
# 15
# [15, 19, 10]
# 20
# [20, 23, 3]
# 15
# [15, 5, 23]
# 11
# [11, 6, 21]
# 17
# [17, 23, 6]
# 8
# [8, 5, 7]
# 10
# [10, 0, 15]
# 14
# [14, 5, 0]
# 17
# [17, 0, 5]
# 21
# [21, 23, 1]
# 9
# [9, 4, 13]
# 20
# [20, 4, 5]
# 10
# [10, 12, 0]
# 18
# [18, 6, 2]
# 7
# [7, 9, 10]
# 20
# [20, 23, 10]
# 5
# [5, 9, 21]
# 9
# [9, 12, 0]
# 8
# [8, 3, 17]
# 4
# [4, 19, 5]
# 9
# [9, 11, 12]
# 15
# [15, 23, 10]
# 19
# [19, 8, 4]
# 12
# [12, 11, 14]
# 6
# [6, 23, 0]
# 0
# [0, 12, 10]
# 19
# [19, 21, 12]
# 18
# [18, 3, 22]
# 13
# [13, 21, 19]
# 4
# [4, 5, 12]
# 21
# [21, 20, 5]
# 17
# [17, 15, 9]
# 16
# [16, 6, 13]
# 10
# [10, 12, 4]
# 12
# [12, 23, 5]
# 8
# [8, 2, 9]
# 18
# [18, 12, 6]
# 17
# [17, 19, 15]
# 11
# [11, 7, 18]
# 3
# [3, 12, 0]
# 9
# [9, 16, 3]
# 3
# [3, 23, 8]
# 18
# [18, 23, 0]
# 0
# [0, 21, 4]
# 7
# [7, 11, 5]
# 15
# [15, 17, 13]
# 22
# [22, 8, 7]
# 0
# [0, 14, 21]
# 22
# [22, 17, 5]
# 9
# [9, 2, 5]
# 20
# [20, 7, 23]
# 8
# [8, 19, 14]
# 13
# [13, 4, 23]
# 13
# [13, 14, 17]
# 22
# [22, 5, 20]
# 7
# [7, 16, 11]
# 22
# [22, 18, 5]
# 9
# [9, 7, 20]
# 10
# [10, 8, 23]
# 1
# [1, 8, 3]
# 8
# [8, 20, 22]
# 15
# [15, 18, 0]
# 5
# [5, 22, 19]
# 11
# [11, 10, 8]
# 14
# [14, 12, 6]
# 12
# [12, 9, 4]
# 9
# [9, 19, 18]
# 0
# [0, 14, 5]
# 0
# [0, 21, 8]
# 19
# [19, 0, 23]
# 5
# [5, 15, 8]
# 22
# [22, 14, 5]
# 4
# [4, 20, 7]
# 23
# [23, 2, 12]
# 5
# [5, 22, 14]
# 17
# [17, 23, 2]
# 2
# [2, 4, 10]
# 1
# [1, 6, 2]
# 10
# [10, 11, 21]
# 8
# [8, 21, 5]
# 12
# [12, 8, 14]
# 2
# [2, 0, 17]
# 7
# [7, 18, 23]
# 5
# [5, 23, 18]
# 2
# [2, 9, 7]
# 19
# [19, 8, 12]
# 0
# [0, 2, 19]
# 7
# [7, 8, 9]
# 16
# [16, 23, 11]
# 4
# [4, 8, 0]
# 8
# [8, 5, 13]
# 4
# [4, 3, 16]
# 8
# [8, 7, 19]
# 9
# [9, 18, 4]
# 23
# [23, 18, 21]
# 21
# [21, 15, 4]
# 12
# [12, 7, 13]
# 17
# [17, 8, 12]
# 17
# [17, 4, 10]
# 15
# [15, 21, 17]
# 5
# [5, 20, 3]
# 3
# [3, 13, 2]
# 14
# [14, 23, 17]
# 2
# [2, 7, 10]
# 18
# [18, 19, 16]
# 4
# [4, 15, 21]
# 3
# [3, 5, 10]
# 22
# [22, 1, 2]
# 16
# [16, 11, 2]
# 20
# [20, 5, 23]
# 21
# [21, 10, 15]
# 8
# [8, 17, 18]
# 19
# [19, 0, 3]
# 1
# [1, 0, 22]
# 17
# [17, 3, 0]
# 2
# [2, 8, 21]
# 21
# [21, 5, 2]
# 10
# [10, 16, 19]
# 10
# [10, 20, 22]
# 20
# [20, 10, 8]
# 5
# [5, 6, 1]
# 4
# [4, 17, 1]
# 17
# [17, 19, 23]
# 12
# [12, 23, 14]
# 20
# [20, 0, 16]
# 18
# [18, 12, 19]
# 19
# [19, 5, 14]
# 19
# [19, 17, 3]
# 23
# [23, 10, 8]
# 10
# [10, 2, 6]
# 4
# [4, 14, 17]
# 4
# [4, 10, 3]
# 10
# [10, 8, 18]
# 7
# [7, 20, 23]
# 19
# [19, 15, 18]
# 13
# [13, 3, 10]
# 12
# [12, 10, 16]
# 9
# [9, 20, 18]
# 11
# [11, 1, 6]
# 10
# [10, 23, 14]
# 8
# [8, 14, 2]
# 10
# [10, 20, 19]
# 19
# [19, 10, 16]
# 2
# [2, 11, 7]
# 0
# [0, 18, 15]
# 16
# [16, 19, 11]
# 1
# [1, 13, 9]
# 1
# [1, 9, 16]
# 14
# [14, 8, 12]
# 22
# [22, 0, 15]
# 19
# [19, 8, 22]
# 20
# [20, 6, 4]
# 3
# [3, 16, 12]
# 16
# [16, 1, 5]
# 21
# [21, 11, 19]
# 4
# [4, 21, 16]
# 15
# [15, 19, 13]
# 7
# [7, 11, 9]
# 23
# [23, 9, 19]
# 17
# [17, 21, 10]
# 8
# [8, 1, 11]
# 4
# [4, 6, 2]
# 18
# [18, 10, 0]
# 18
# [18, 11, 14]
# 20
# [20, 14, 19]
# 6
# [6, 12, 9]
# 17
# [17, 6, 0]
# 8
# [8, 22, 7]
# 2
# [2, 19, 3]
# 8
# [8, 10, 15]
# 4
# [4, 1, 13]
# 15
# [15, 12, 17]
# 5
# [5, 11, 19]
# 4
# [4, 10, 8]
# 13
# [13, 4, 5]
# 11
# [11, 22, 4]
# 16
# [16, 4, 9]
# 4
# [4, 5, 19]
# 17
# [17, 11, 9]
# 4
# [4, 13, 19]
# 7
# [7, 1, 17]
# 20
# [20, 3, 23]
# 19
# [19, 8, 7]
# 13
# [13, 16, 7]
# 22
# [22, 13, 23]
# 12
# [12, 18, 7]
# 7
# [7, 12, 14]
# 2
# [2, 23, 6]
# 6
# [6, 7, 18]
# 2
# [2, 5, 3]
# 15
# [15, 12, 23]
# 20
# [20, 10, 19]
# 17
# [17, 5, 21]
# 8
# [8, 12, 2]
# 10
# [10, 23, 8]
# 1
# [1, 21, 14]
# 12
# [12, 13, 9]
# 15
# [15, 16, 9]
# 5
# [5, 9, 23]
# 19
# [19, 21, 17]
# 2
# [2, 6, 19]
# 13
# [13, 6, 7]
# 23
# [23, 1, 16]
# 5
# [5, 2, 9]
# 11
# [11, 10, 2]
# 0
# [0, 17, 23]
# 1
# [1, 21, 17]
# 22
# [22, 2, 19]
# 6
# [6, 10, 1]
# 3
# [3, 14, 5]
# 14
# [14, 18, 17]
# 0
# [0, 6, 8]
# 9
# [9, 20, 10]
# 5
# [5, 1, 6]
# 10
# [10, 7, 18]
# 4
# [4, 6, 7]
# 20
# [20, 1, 14]
# 17
# [17, 14, 9]
# 8
# [8, 9, 20]
# 7
# [7, 4, 8]
# 11
# [11, 15, 7]
# 22
# [22, 9, 10]
# 17
# [17, 7, 5]
# 14
# [14, 12, 17]
# 19
# [19, 16, 7]
# 7
# [7, 4, 13]
# 23
# [23, 17, 3]
# 2
# [2, 6, 5]
# 22
# [22, 1, 12]
# 0
# [0, 9, 10]
# 4
# [4, 17, 15]
# 4
# [4, 6, 15]
# 18
# [18, 17, 14]
# 23
# [23, 4, 17]
# 4
# [4, 6, 10]
# 9
# [9, 16, 4]
# 21
# [21, 20, 4]
# 12
# [12, 8, 6]
# 23
# [23, 17, 0]
# 6
# [6, 4, 23]
# 11
# [11, 7, 14]
# 19
# [19, 0, 18]
# 10
# [10, 12, 17]
# 4
# [4, 23, 14]
# 5
# [5, 2, 16]
# 4
# [4, 9, 0]
# 11
# [11, 2, 9]
# 17
# [17, 20, 11]
# 3
# [3, 15, 13]
# 1
# [1, 11, 17]
# 21
# [21, 15, 11]
# 20
# [20, 8, 10]
# 20
# [20, 6, 18]
# 16
# [16, 0, 1]
# 14
# [14, 9, 11]
# 9
# [9, 18, 14]
# 21
# [21, 19, 0]
# 9
# [9, 14, 23]
# 7
# [7, 2, 0]
# 14
# [14, 5, 9]
# 19
# [19, 5, 2]
# 13
# [13, 6, 20]
# 14
# [14, 7, 17]
# 18
# [18, 9, 11]
# 18
# [18, 2, 11]
# 16
# [16, 20, 6]
# 7
# [7, 11, 12]
# 18
# [18, 2, 1]
# 18
# [18, 2, 17]
# 14
# [14, 16, 12]
# 9
# [9, 19, 0]
# 5
# [5, 1, 7]
# 16
# [16, 21, 20]
# 8
# [8, 10, 14]
# 1
# [1, 9, 2]
# 0
# [0, 2, 10]
# 4
# [4, 13, 12]
# 12
# [12, 14, 20]
# 20
# [20, 0, 22]
# 18
# [18, 19, 23]
# 12
# [12, 16, 6]
# 8
# [8, 21, 15]
# 15
# [15, 22, 1]
# 10
# [10, 22, 13]
# 10
# [10, 17, 9]
# 18
# [18, 7, 13]
# 2
# [2, 8, 11]
# 21
# [21, 18, 20]
# 7
# [7, 11, 15]
# 16
# [16, 20, 11]
# 0
# [0, 19, 18]
# 7
# [7, 12, 6]
# 4
# [4, 13, 23]
# 7
# [7, 12, 1]
# 22
# [22, 3, 23]
# 0
# [0, 23, 10]
# 11
# [11, 7, 1]
# 20
# [20, 12, 5]
# 5
# [5, 2, 23]
# 17
# [17, 13, 2]
# 19
# [19, 16, 20]
# 5
# [5, 12, 4]
# 19
# [19, 0, 3]
# 13
# [13, 15, 19]
# 11
# [11, 8, 17]
# 5
# [5, 4, 17]
# 3
# [3, 4, 14]
# 14
# [14, 8, 16]
# 5
# [5, 16, 8]
# 19
# [19, 13, 8]
# 0
# [0, 5, 17]
# 23
# [23, 7, 17]
# 16
# [16, 22, 0]
# 3
# [3, 6, 18]
# 18
# [18, 1, 14]
# 8
# [8, 0, 6]
# 8
# [8, 19, 14]
# 3
# [3, 8, 0]
# 5
# [5, 12, 4]
# 14
# [14, 12, 20]
# 0
# [0, 2, 19]
# 0
# [0, 1, 20]
# 9
# [9, 17, 6]
# 13
# [13, 14, 17]
# 17
# [17, 16, 7]
# 23
# [23, 16, 1]
# 8
# [8, 16, 5]
# 20
# [20, 7, 10]
# 9
# [9, 23, 21]
# 12
# [12, 20, 9]
# 21
# [21, 15, 14]
# 12
# [12, 15, 0]
# 19
# [19, 3, 18]
# 17
# [17, 9, 5]
# 1
# [1, 6, 12]
# 1
# [1, 22, 16]
# 14
# [14, 4, 19]
# 2
# [2, 20, 3]
# 7
# [7, 13, 2]
# 13
# [13, 18, 4]
# 1
# [1, 7, 17]
# 16
# [16, 5, 9]
# 15
# [15, 18, 14]
# 16
# [16, 2, 21]
# 14
# [14, 3, 11]
# 19
# [19, 21, 10]
# 8
# [8, 22, 2]
# 9
# [9, 14, 3]
# 23
# [23, 11, 13]
# 8
# [8, 7, 2]
# 21
# [21, 7, 16]
# 22
# [22, 9, 0]
# 1
# [1, 23, 22]
# 16
# [16, 9, 0]
# 12
# [12, 4, 17]
# 11
# [11, 16, 17]
# 14
# [14, 21, 13]
# 17
# [17, 3, 10]
# 10
# [10, 5, 11]
# 20
# [20, 17, 23]
# 14
# [14, 9, 22]
# 1
# [1, 3, 16]
# 20
# [20, 10, 7]
# 18
# [18, 14, 3]
# 0
# [0, 1, 9]
# 19
# [19, 15, 9]
# 11
# [11, 4, 3]
# 7
# [7, 2, 12]
# 23
# [23, 9, 13]
# 15
# [15, 9, 13]
# 17
# [17, 7, 21]
# 3
# [3, 17, 5]
# 11
# [11, 12, 0]
# 8
# [8, 5, 12]
# 19
# [19, 10, 3]
# 15
# [15, 3, 6]
# 10
# [10, 7, 19]
# 14
# [14, 19, 18]
# 6
# [6, 1, 21]
# 5
# [5, 0, 6]
# 8
# [8, 17, 23]
# 21
# [21, 3, 20]
# 9
# [9, 20, 4]
# 3
# [3, 19, 10]
# 8
# [8, 1, 2]
# 17
# [17, 15, 5]
# 2
# [2, 11, 19]
# 6
# [6, 17, 1]
# 17
# [17, 1, 20]
# 19
# [19, 17, 9]
# 20
# [20, 9, 3]
# 3
# [3, 23, 7]
# 7
# [7, 22, 19]
# 20
# [20, 12, 23]
# 8
# [8, 3, 5]
# 16
# [16, 20, 7]
# 12
# [12, 15, 19]
# 22
# [22, 15, 13]
# 15
# [15, 22, 0]
# 13
# [13, 15, 21]
# 3
# [3, 7, 22]
# 12
# [12, 5, 11]
# 21
# [21, 1, 4]
# 22
# [22, 5, 2]
# 15
# [15, 0, 18]
# 5
# [5, 11, 18]
# 12
# [12, 5, 13]
# 2
# [2, 18, 13]
# 9
# [9, 19, 17]
# 21
# [21, 10, 19]
# 8
# [8, 19, 2]
# 19
# [19, 20, 10]
# 13
# [13, 14, 19]
# 6
# [6, 16, 10]
# 15
# [15, 19, 13]
# 19
# [19, 22, 18]
# 9
# [9, 17, 1]
# 0
# [0, 18, 15]
# 5
# [5, 9, 20]
# 21
# [21, 2, 8]
# 17
# [17, 12, 0]
# 19
# [19, 7, 3]
# 20
# [20, 10, 2]
# 4
# [4, 22, 6]
# 12
# [12, 3, 11]
# 16
# [16, 1, 4]
# 8
# [8, 14, 18]
# 7
# [7, 2, 11]
# 7
# [7, 3, 18]
# 0
# [0, 17, 2]
# 23
# [23, 7, 12]
# 11
# [11, 3, 16]
# 10
# [10, 8, 15]
# 11
# [11, 5, 15]
# 1
# [1, 21, 7]
# 3
# [3, 5, 10]
# 23
# [23, 1, 2]
# 23
# [23, 18, 9]
# 21
# [21, 19, 22]
# 20
# [20, 6, 16]
# 20
# [20, 22, 10]
# 16
# [16, 8, 10]
# 17
# [17, 20, 6]
# 10
# [10, 14, 3]
# 18
# [18, 12, 13]
# 20
# [20, 8, 1]
# 19
# [19, 6, 11]
# 6
# [6, 2, 14]
# 18
# [18, 21, 13]
# 23
# [23, 20, 6]
# 3
# [3, 0, 10]
# 16
# [16, 19, 3]
# 2
# [2, 23, 15]
# 16
# [16, 5, 15]
# 16
# [16, 18, 12]
# 2
# [2, 18, 10]
# 0
# [0, 23, 17]
# 12
# [12, 17, 15]
# 21
# [21, 10, 11]
# 17
# [17, 23, 21]
# 16
# [16, 3, 15]
# 19
# [19, 14, 12]
# 7
# [7, 19, 21]
# 7
# [7, 13, 8]
# 5
# [5, 4, 8]
# 1
# [1, 9, 7]
# 10
# [10, 8, 18]
# 14
# [14, 8, 10]
# 9
# [9, 15, 19]
# 16
# [16, 7, 20]
# 21
# [21, 5, 8]
# 18
# [18, 21, 13]
# 3
# [3, 14, 0]
# 22
# [22, 11, 2]
# 16
# [16, 5, 7]
# 23
# [23, 1, 18]
# 11
# [11, 8, 15]
# 10
# [10, 7, 1]
# 2
# [2, 7, 10]
# 0
# [0, 3, 20]
# 18
# [18, 8, 0]
# 4
# [4, 7, 6]
# 16
# [16, 14, 4]
# 5
# [5, 7, 14]
# 22
# [22, 19, 5]
# 18
# [18, 3, 15]
# 4
# [4, 17, 7]
# 10
# [10, 17, 8]
# 12
# [12, 8, 5]
# 0
# [0, 4, 14]
# 1
# [1, 12, 17]
# 19
# [19, 1, 3]
# 0
# [0, 18, 6]
# 12
# [12, 8, 3]
# 15
# [15, 18, 13]
# 12
# [12, 8, 10]
# 12
# [12, 18, 1]
# 8
# [8, 1, 0]
# 10
# [10, 20, 19]
# 13
# [13, 3, 11]
# 2
# [2, 3, 9]
# 17
# [17, 8, 22]
# 4
# [4, 11, 21]
# 18
# [18, 0, 11]
# 0
# [0, 19, 15]
# 7
# [7, 4, 11]
# 17
# [17, 0, 15]
# 12
# [12, 19, 13]
# 2
# [2, 16, 6]
# 18
# [18, 15, 23]
# 5
# [5, 15, 0]
# 13
# [13, 21, 0]
# 10
# [10, 8, 6]
# 8
# [8, 13, 19]
# 10
# [10, 2, 3]
# 21
# [21, 15, 16]
# 1
# [1, 19, 11]
# 5
# [5, 23, 8]
# 8
# [8, 4, 16]
# 0
# [0, 3, 7]
# 1
# [1, 8, 15]
# 4
# [4, 21, 19]
# 16
# [16, 20, 11]
# 7
# [7, 2, 11]
# 4
# [4, 3, 19]
# 17
# [17, 13, 22]
# 5
# [5, 7, 10]
# 16
# [16, 8, 4]
# 1
# [1, 22, 12]
# 4
# [4, 5, 9]
# 0
# [0, 12, 10]
# 19
# [19, 4, 13]
# 20
# [20, 0, 1]
# 9
# [9, 14, 20]
# 7
# [7, 16, 23]
# 4
# [4, 1, 14]
# 6
# [6, 1, 16]
# 2
# [2, 14, 3]
# 10
# [10, 6, 13]
# 23
# [23, 2, 14]
# 8
# [8, 9, 15]
# 7
# [7, 10, 2]
# 13
# [13, 3, 19]
# 11
# [11, 13, 7]
# 5
# [5, 7, 8]
# 13
# [13, 12, 17]
# 10
# [10, 8, 14]
# 21
# [21, 15, 11]
# 9
# [9, 2, 10]
# 1
# [1, 9, 17]
# 17
# [17, 14, 12]
# 10
# [10, 13, 19]
# 10
# [10, 22, 21]
# 7
# [7, 17, 11]
# 0
# [0, 21, 6]
# 10
# [10, 11, 8]
# 22
# [22, 8, 5]
# 2
# [2, 0, 7]
# 6
# [6, 5, 12]
# 7
# [7, 10, 22]
# 7
# [7, 6, 15]
# 21
# [21, 1, 0]
# 5
# [5, 2, 14]
# 18
# [18, 21, 14]
# 1
# [1, 21, 9]
# 5
# [5, 19, 16]
# 6
# [6, 15, 18]
# 12
# [12, 14, 13]
# 17
# [17, 11, 18]
# 14
# [14, 5, 10]
# 4
# [4, 16, 22]
# 9
# [9, 6, 21]
# 15
# [15, 17, 14]
# 13
# [13, 12, 2]
# 0
# [0, 4, 3]
# 9
# [9, 15, 11]
# 10
# [10, 3, 20]
# 3
# [3, 21, 9]
# 15
# [15, 1, 23]
# 16
# [16, 15, 14]
# 0
# [0, 18, 5]
# 1
# [1, 3, 14]
# 11
# [11, 10, 5]
# 18
# [18, 20, 13]
# 12
# [12, 4, 18]
# 6
# [6, 20, 19]
# 16
# [16, 17, 5]
# 19
# [19, 1, 5]
# 11
# [11, 0, 4]
# 6
# [6, 13, 9]
# 8
# [8, 20, 16]
# 21
# [21, 15, 2]
# 7
# [7, 19, 10]
# 6
# [6, 0, 7]
# 16
# [16, 0, 7]
# 1
# [1, 8, 9]
# 10
# [10, 2, 18]
# 6
# [6, 18, 21]
# 0
# [0, 1, 10]
# 8
# [8, 11, 22]
# 0
# [0, 11, 6]
# 10
# [10, 6, 21]
# 2
# [2, 9, 8]
# 23
# [23, 14, 2]
# 3
# [3, 8, 5]
# 19
# [19, 4, 7]
# 1
# [1, 4, 6]
# 1
# [1, 17, 14]
# 9
# [9, 10, 21]
# 22
# [22, 14, 19]
# 6
# [6, 15, 17]
# 14
# [14, 15, 10]
# 9
# [9, 3, 16]
# 20
# [20, 2, 12]
# 12
# [12, 1, 23]
# 22
# [22, 14, 7]
# 6
# [6, 12, 18]
# 21
# [21, 3, 1]
# 5
# [5, 6, 9]
# 9
# [9, 4, 19]
# 9
# [9, 17, 16]
# 14
# [14, 19, 15]
# 22
# [22, 5, 4]
# 1
# [1, 10, 6]
# 18
# [18, 6, 1]
# 6
# [6, 9, 5]
# 20
# [20, 22, 14]
# 20
# [20, 17, 8]
# 0
# [0, 9, 23]
# 15
# [15, 22, 16]
# 9
# [9, 5, 12]
# 5
# [5, 7, 20]
# 17
# [17, 22, 20]
# 17
# [17, 12, 6]
# 5
# [5, 3, 9]
# 14
# [14, 15, 2]
# 5
# [5, 23, 1]
# 16
# [16, 10, 3]
# 13
# [13, 6, 8]
# 3
# [3, 6, 5]
# 19
# [19, 10, 1]
# 3
# [3, 8, 16]
# 23
# [23, 4, 17]
# 4
# [4, 21, 5]
# 18
# [18, 21, 0]
# 19
# [19, 13, 11]
# 14
# [14, 22, 19]
# 8
# [8, 0, 7]
# 0
# [0, 5, 7]
# 23
# [23, 2, 22]
# 17
# [17, 23, 5]
# 19
# [19, 8, 20]
# 2
# [2, 22, 6]
# 11
# [11, 8, 4]
# 20
# [20, 0, 16]
# 7
# [7, 21, 22]
# 1
# [1, 9, 3]
# 10
# [10, 5, 7]
# 10
# [10, 5, 17]
# 5
# [5, 21, 7]
# 3
# [3, 21, 18]
# 4
# [4, 15, 22]
# 15
# [15, 8, 18]
# 11
# [11, 20, 23]
# 20
# [20, 2, 8]
# 22
# [22, 8, 17]
# 16
# [16, 5, 9]
# 1
# [1, 23, 15]
# 13
# [13, 8, 7]
# 1
# [1, 2, 23]
# 20
# [20, 1, 21]
# 5
# [5, 23, 8]
# 9
# [9, 13, 1]
# 6
# [6, 23, 4]
# 5
# [5, 14, 12]
# 0
# [0, 11, 7]
# 2
# [2, 0, 4]
# 22
# [22, 17, 11]
# 1
# [1, 20, 4]
# 1
# [1, 0, 12]
# 12
# [12, 14, 3]
# 2
# [2, 17, 18]
# 0
# [0, 3, 14]
# 5
# [5, 3, 11]
# 2
# [2, 7, 9]
# 1
# [1, 23, 0]
# 2
# [2, 12, 21]
# 13
# [13, 5, 8]
# 6
# [6, 4, 15]
# 11
# [11, 22, 12]
# 13
# [13, 2, 10]
# 14
# [14, 0, 15]
# 1
# [1, 8, 2]
# 5
# [5, 22, 15]
# 15
# [15, 7, 1]
# 18
# [18, 16, 3]
# 18
# [18, 2, 11]
# 5
# [5, 2, 12]
# 6
# [6, 15, 3]
# 0
# [0, 7, 3]
# 15
# [15, 17, 5]
# 4
# [4, 1, 8]
# 11
# [11, 14, 4]
# 10
# [10, 2, 17]
# 13
# [13, 16, 20]
# 10
# [10, 18, 15]
# 18
# [18, 5, 8]
# 22
# [22, 10, 20]
# 5
# [5, 2, 15]
# 7
# [7, 10, 2]
# 12
# [12, 4, 15]
# 1
# [1, 2, 17]
# 0
# [0, 6, 21]
# 9
# [9, 18, 5]
# 20
# [20, 12, 7]
# 22
# [22, 4, 23]
# 13
# [13, 16, 3]
# 16
# [16, 6, 22]
# 3
# [3, 4, 7]
# 0
# [0, 7, 11]
# 4
# [4, 6, 17]
# 13
# [13, 19, 21]
# 20
# [20, 23, 2]
# 11
# [11, 20, 0]
# 4
# [4, 16, 7]
# 15
# [15, 6, 0]
# 9
# [9, 22, 21]
# 9
# [9, 20, 4]
# 9
# [9, 13, 2]
# 4
# [4, 7, 21]
# 19
# [19, 2, 0]
# 21
# [21, 9, 16]
# 15
# [15, 14, 23]
# 21
# [21, 2, 7]
# 2
# [2, 0, 5]
# 15
# [15, 18, 5]
# 8
# [8, 19, 14]
# 17
# [17, 20, 22]
# 13
# [13, 8, 21]
# 15
# [15, 14, 22]
# 11
# [11, 4, 7]
# 4
# [4, 3, 11]
# 16
# [16, 8, 10]
# 5
# [5, 7, 17]
# 22
# [22, 4, 13]
# 18
# [18, 23, 9]
# 4
# [4, 23, 3]
# 22
# [22, 7, 14]
# 17
# [17, 5, 3]
# 19
# [19, 11, 4]
# 16
# [16, 0, 1]
# 13
# [13, 7, 16]
# 13
# [13, 22, 21]
# 19
# [19, 15, 14]
# 14
# [14, 11, 9]
# 23
# [23, 12, 6]
# 21
# [21, 14, 8]
# 23
# [23, 21, 20]
# 3
# [3, 16, 10]
# 0
# [0, 14, 5]
# 9
# [9, 8, 1]
# 10
# [10, 19, 1]
# 15
# [15, 18, 9]
# 15
# [15, 0, 3]
# 22
# [22, 15, 6]
# 18
# [18, 10, 21]
# 9
# [9, 6, 14]
# 23
# [23, 12, 15]
# 11
# [11, 13, 22]
# 21
# [21, 23, 9]
# 20
# [20, 12, 0]
# 7
# [7, 16, 21]
# 8
# [8, 2, 21]
# 20
# [20, 7, 3]
# 2
# [2, 10, 12]
# 22
# [22, 9, 15]
# 1
# [1, 7, 11]
# 13
# [13, 1, 8]
# 16
# [16, 20, 13]
# 5
# [5, 20, 9]
# 23
# [23, 5, 14]
# 10
# [10, 9, 15]
# 1
# [1, 14, 6]
# 15
# [15, 0, 21]
# 22
# [22, 19, 6]
# 8
# [8, 5, 19]
# 23
# [23, 7, 14]
# 20
# [20, 12, 7]
# 14
# [14, 20, 18]
# 15
# [15, 0, 20]
# 2
# [2, 4, 14]
# 17
# [17, 7, 18]
# 11
# [11, 13, 6]
# 16
# [16, 5, 2]
# 11
# [11, 2, 8]
# 0
# [0, 3, 7]
# 4
# [4, 3, 13]
# 2
# [2, 14, 13]
# 1
# [1, 3, 2]
# 1
# [1, 3, 0]
# 3
# [3, 18, 16]
# 0
# [0, 5, 3]
# 12
# [12, 23, 17]
# 15
# [15, 10, 12]
# 20
# [20, 4, 23]
# 12
# [12, 15, 2]
# 14
# [14, 16, 1]
# 14
# [14, 1, 13]
# 4
# [4, 0, 3]
# 5
# [5, 23, 7]
# 4
# [4, 20, 5]
# 7
# [7, 21, 5]
# 14
# [14, 10, 4]
# 4
# [4, 14, 9]
# 20
# [20, 5, 18]
# 17
# [17, 0, 13]
# 8
# [8, 23, 17]
# 17
# [17, 20, 4]
# 22
# [22, 17, 16]
# 0
# [0, 16, 8]
# 0
# [0, 11, 15]
# 8
# [8, 6, 7]
# 15
# [15, 2, 14]
# 1
# [1, 19, 11]
# 9
# [9, 17, 19]
# 23
# [23, 10, 5]
# 9
# [9, 7, 23]
# 8
# [8, 19, 14]
# 16
# [16, 8, 5]
# 22
# [22, 4, 16]
# 8
# [8, 17, 0]
# 9
# [9, 12, 18]
# 15
# [15, 13, 11]
# 9
# [9, 3, 23]
# 22
# [22, 16, 10]
# 3
# [3, 14, 8]
# 22
# [22, 21, 8]
# 18
# [18, 6, 3]
# 16
# [16, 11, 6]
# 14
# [14, 5, 19]
# 17
# [17, 5, 12]
# 9
# [9, 5, 0]
# 2
# [2, 21, 14]
# 21
# [21, 4, 7]
# 5
# [5, 1, 14]
# 1
# [1, 14, 0]
# 16
# [16, 9, 22]
# 6
# [6, 15, 8]
# 19
# [19, 10, 9]
# 18
# [18, 6, 13]
# 12
# [12, 7, 21]
# 23
# [23, 20, 16]
# 12
# [12, 19, 16]
# 7
# [7, 16, 19]
# 19
# [19, 17, 20]
# 8
# [8, 20, 9]
# 11
# [11, 22, 16]
# 1
# [1, 4, 5]
# 4
# [4, 1, 12]
# 16
# [16, 1, 4]
# 2
# [2, 6, 8]
# 11
# [11, 17, 12]
# 11
# [11, 21, 17]
# 18
# [18, 16, 20]
# 16
# [16, 19, 17]
# 17
# [17, 16, 7]
# 18
# [18, 11, 3]
# 21
# [21, 20, 18]
# 15
# [15, 16, 14]
# 13
# [13, 1, 8]
# 20
# [20, 16, 6]
# 23
# [23, 17, 12]
# 14
# [14, 21, 12]
# 11
# [11, 8, 13]
# 19
# [19, 4, 11]
# 16
# [16, 18, 20]
# 8
# [8, 9, 15]
# 3
# [3, 18, 5]
# 5
# [5, 0, 12]
# 6
# [6, 15, 10]
# 20
# [20, 12, 10]
# 13
# [13, 16, 14]
# 7
# [7, 11, 23]
# 1
# [1, 14, 15]
# 2
# [2, 0, 23]
# 13
# [13, 10, 7]
# 18
# [18, 12, 8]
# 14
# [14, 13, 9]
# 20
# [20, 23, 16]
# 19
# [19, 5, 20]
# 20
# [20, 3, 4]
# 7
# [7, 22, 5]
# 10
# [10, 22, 23]
# 2
# [2, 4, 0]
# 18
# [18, 15, 10]
# 17
# [17, 11, 5]
# 2
# [2, 14, 22]
# 22
# [22, 3, 11]
# 23
# [23, 22, 8]
# 8
# [8, 6, 5]
# 8
# [8, 16, 7]
# 22
# [22, 11, 17]
# 8
# [8, 14, 5]
# 16
# [16, 7, 0]
# 12
# [12, 15, 7]
# 6
# [6, 18, 10]
# 3
# [3, 5, 6]
# 4
# [4, 21, 23]
# 16
# [16, 19, 20]
# 19
# [19, 9, 0]
# 2
# [2, 23, 1]
# 8
# [8, 20, 11]
# 11
# [11, 9, 13]
# 5
# [5, 15, 0]
# 8
# [8, 12, 19]
# 2
# [2, 13, 20]
# 10
# [10, 13, 7]
# 17
# [17, 20, 22]
# 14
# [14, 9, 13]
# 10
# [10, 19, 11]
# 5
# [5, 9, 14]
# 19
# [19, 7, 16]
# 6
# [6, 11, 22]
# 8
# [8, 6, 14]
# 17
# [17, 20, 9]
# 15
# [15, 18, 11]
# 4
# [4, 17, 7]
# 10
# [10, 2, 3]
# 15
# [15, 17, 4]
# 11
# [11, 23, 3]
# 15
# [15, 5, 12]
# 23
# [23, 21, 1]
# 21
# [21, 15, 11]
# 21
# [21, 15, 3]
# 22
# [22, 12, 17]
# 4
# [4, 18, 15]
# 2
# [2, 8, 23]
# 19
# [19, 7, 5]
# 14
# [14, 3, 2]
# 20
# [20, 9, 1]
# 19
# [19, 9, 10]
# 10
# [10, 9, 20]
# 0
# [0, 13, 9]
# 21
# [21, 17, 14]
# 10
# [10, 23, 15]
# 23
# [23, 12, 6]
# 23
# [23, 8, 21]
# 7
# [7, 18, 5]
# 6
# [6, 15, 17]
# 8
# [8, 0, 22]
# 23
# [23, 20, 0]
# 19
# [19, 6, 15]
# 18
# [18, 10, 15]
# 13
# [13, 4, 22]
# 17
# [17, 21, 14]
# 15
# [15, 22, 12]
# 17
# [17, 13, 18]
# 16
# [16, 13, 21]
# 22
# [22, 2, 19]
# 21
# [21, 15, 10]
# 21
# [21, 18, 19]
# 13
# [13, 10, 19]
# 8
# [8, 16, 14]
# 18
# [18, 21, 23]
# 14
# [14, 10, 5]
# 0
# [0, 13, 15]
# 10
# [10, 7, 14]
# 0
# [0, 11, 10]
# 7
# [7, 1, 18]
# 7
# [7, 16, 14]
# 19
# [19, 13, 23]
# 17
# [17, 1, 18]
# 14
# [14, 21, 8]
# 10
# [10, 16, 5]
# 13
# [13, 15, 5]
# 17
# [17, 0, 14]
# 7
# [7, 6, 23]
# 22
# [22, 21, 23]
# 3
# [3, 10, 2]
# 23
# [23, 11, 19]
# 23
# [23, 12, 21]
# 19
# [19, 17, 22]
# 6
# [6, 3, 12]
# 4
# [4, 16, 8]
# 9
# [9, 0, 2]
# 8
# [8, 1, 7]
# 15
# [15, 3, 6]
# 18
# [18, 22, 13]
# 20
# [20, 10, 7]
# 6
# [6, 10, 3]
# 4
# [4, 23, 3]
# 8
# [8, 9, 20]
# 19
# [19, 2, 11]
# 15
# [15, 21, 12]
# 18
# [18, 21, 11]
# 8
# [8, 4, 15]
# 2
# [2, 19, 5]
# 6
# [6, 0, 5]
# 23
# [23, 0, 21]
# 0
# [0, 22, 4]
# 21
# [21, 8, 2]
# 16
# [16, 19, 0]
# 3
# [3, 23, 14]
# 9
# [9, 15, 4]
# 23
# [23, 21, 11]
# 10
# [10, 16, 1]
# 14
# [14, 12, 16]
# 10
# [10, 12, 22]
# 19
# [19, 1, 21]
# 20
# [20, 7, 21]
# 1
# [1, 18, 21]
# 14
# [14, 21, 3]
# 23
# [23, 10, 5]
# 23
# [23, 14, 16]
# 6
# [6, 5, 21]
# 23
# [23, 11, 22]
# 15
# [15, 9, 18]
# 9
# [9, 13, 18]
# 9
# [9, 4, 21]
# 5
# [5, 3, 12]
# 2
# [2, 11, 17]
# 10
# [10, 6, 20]
# 5
# [5, 20, 12]
# 18
# [18, 17, 5]
# 4
# [4, 1, 6]
# 8
# [8, 23, 16]
# 2
# [2, 7, 18]
# 11
# [11, 7, 20]
# 10
# [10, 1, 19]
# 17
# [17, 15, 21]
# 11
# [11, 16, 13]
# 15
# [15, 16, 5]
# 4
# [4, 18, 23]
# 18
# [18, 9, 1]
# 23
# [23, 0, 1]
# 8
# [8, 3, 15]
# 16
# [16, 5, 9]
# 10
# [10, 20, 13]
# 19
# [19, 7, 9]
# 10
# [10, 16, 9]
# 0
# [0, 17, 23]
# 10
# [10, 20, 19]
# 18
# [18, 23, 21]
# 12
# [12, 2, 17]
# 18
# [18, 5, 14]
# 19
# [19, 23, 8]
# 12
# [12, 10, 1]
# 22
# [22, 4, 6]
# 23
# [23, 3, 6]
# 16
# [16, 19, 9]
# 13
# [13, 6, 14]
# 10
# [10, 22, 18]
# 16
# [16, 20, 23]
# 19
# [19, 5, 17]
# 14
# [14, 18, 16]
# 3
# [3, 20, 6]
# 16
# [16, 20, 3]
# 20
# [20, 22, 8]
# 18
# [18, 2, 11]
# 5
# [5, 11, 13]
# 14
# [14, 10, 7]
# 2
# [2, 4, 11]
# 4
# [4, 3, 5]
# 1
# [1, 22, 10]
# 13
# [13, 18, 0]
# 17
# [17, 13, 14]
# 7
# [7, 9, 18]
# 0
# [0, 17, 4]
# 2
# [2, 7, 9]
# 16
# [16, 23, 13]
# 21
# [21, 19, 5]
# 18
# [18, 11, 14]
# 1
# [1, 2, 11]
# 23
# [23, 0, 11]
# 1
# [1, 13, 16]
# 5
# [5, 15, 11]
# 3
# [3, 22, 23]
# 7
# [7, 6, 21]
# 15
# [15, 8, 16]
# 10
# [10, 3, 8]
# 23
# [23, 6, 21]
# 23
# [23, 8, 6]
# 3
# [3, 18, 10]
# 19
# [19, 12, 23]
# 19
# [19, 14, 3]
# 11
# [11, 4, 6]
# 2
# [2, 11, 22]
# 9
# [9, 21, 20]
# 19
# [19, 0, 20]
# 4
# [4, 10, 12]
# 6
# [6, 5, 10]
# 3
# [3, 16, 13]
# 23
# [23, 6, 1]
# 17
# [17, 23, 11]
# 0
# [0, 14, 10]
# 10
# [10, 1, 22]
# 14
# [14, 23, 17]
# 19
# [19, 9, 2]
# 11
# [11, 21, 19]
# 5
# [5, 10, 9]
# 3
# [3, 15, 19]
# 14
# [14, 17, 10]
# 7
# [7, 21, 5]
# 7
# [7, 14, 17]
# 7
# [7, 11, 8]
# 5
# [5, 12, 4]
# 19
# [19, 0, 14]
# 20
# [20, 21, 22]
# 12
# [12, 9, 17]
# 20
# [20, 23, 1]
# 20
# [20, 15, 0]
# 7
# [7, 19, 12]
# 22
# [22, 10, 23]
# 8
# [8, 21, 18]
# 20
# [20, 9, 21]
# 22
# [22, 19, 7]
# 22
# [22, 13, 6]
# 20
# [20, 1, 13]
# 3
# [3, 22, 2]
# 0
# [0, 11, 10]
# 14
# [14, 13, 4]
# 6
# [6, 13, 16]
# 15
# [15, 10, 19]
# 16
# [16, 6, 21]
# 12
# [12, 17, 8]
# 22
# [22, 12, 15]
# 20
# [20, 5, 18]
# 22
# [22, 2, 17]
# 3
# [3, 16, 23]
# 16
# [16, 8, 9]
# 13
# [13, 10, 12]
# 20
# [20, 5, 14]
# 16
# [16, 9, 19]
# 5
# [5, 8, 11]
# 1
# [1, 7, 16]
# 2
# [2, 14, 10]
# 21
# [21, 11, 15]
# 20
# [20, 16, 22]
# 16
# [16, 19, 4]
# 3
# [3, 7, 21]
# 11
# [11, 3, 14]
# 1
# [1, 9, 21]
# 3
# [3, 20, 17]
# 16
# [16, 14, 18]
# 20
# [20, 12, 19]
# 18
# [18, 8, 2]
# 19
# [19, 13, 17]
# 0
# [0, 19, 4]
# 20
# [20, 5, 4]
# 17
# [17, 23, 3]
# 19
# [19, 1, 20]
# 6
# [6, 13, 3]
# 8
# [8, 23, 22]
# 11
# [11, 13, 19]
# 22
# [22, 18, 16]
# 17
# [17, 6, 22]
# 16
# [16, 18, 6]
# 13
# [13, 16, 21]
# 14
# [14, 5, 13]
# 14
# [14, 20, 8]
# 19
# [19, 4, 6]
# 19
# [19, 5, 4]
# 5
# [5, 7, 10]
# 13
# [13, 2, 9]
# 7
# [7, 17, 21]
# 6
# [6, 20, 11]
# 14
# [14, 9, 17]
# 10
# [10, 20, 2]
# 10
# [10, 16, 22]
# 9
# [9, 5, 19]
# 5
# [5, 4, 9]
# 23
# [23, 20, 22]
# 14
# [14, 16, 2]
# 1
# [1, 6, 13]
# 20
# [20, 10, 2]
# 23
# [23, 18, 13]
# 6
# [6, 23, 18]
# 13
# [13, 4, 5]
# 0
# [0, 23, 1]
# 9
# [9, 17, 23]
# 13
# [13, 23, 1]
# 13
# [13, 20, 19]
# 4
# [4, 14, 20]
# 17
# [17, 1, 21]
# 20
# [20, 17, 16]
# 11
# [11, 0, 8]
# 16
# [16, 23, 10]
# 23
# [23, 0, 1]
# 2
# [2, 15, 11]
# 14
# [14, 0, 23]
# 16
# [16, 9, 15]
# 6
# [6, 2, 15]
# 4
# [4, 13, 18]
# 0
# [0, 23, 9]
# 0
# [0, 11, 19]
# 12
# [12, 18, 10]
# 13
# [13, 16, 6]
# 5
# [5, 23, 15]
# 22
# [22, 16, 23]
# 2
# [2, 21, 10]
# 21
# [21, 0, 9]
# 13
# [13, 8, 14]
# 16
# [16, 15, 6]
# 3
# [3, 16, 19]
# 21
# [21, 13, 11]
# 7
# [7, 3, 5]
# 8
# [8, 15, 16]
# 6
# [6, 22, 4]
# 7
# [7, 9, 0]
# 20
# [20, 15, 1]
# 5
# [5, 4, 12]
# 0
# [0, 7, 2]
# 0
# [0, 15, 14]
# 18
# [18, 3, 4]
# 17
# [17, 4, 3]
# 10
# [10, 23, 13]
# 3
# [3, 22, 23]
# 18
# [18, 19, 7]
# 13
# [13, 2, 20]
# 14
# [14, 11, 6]
# 4
# [4, 7, 2]
# 0
# [0, 7, 17]
# 5
# [5, 8, 10]
# 22
# [22, 11, 13]
# 14
# [14, 12, 0]
# 6
# [6, 0, 17]
# 6
# [6, 12, 5]
# 14
# [14, 3, 21]
# 11
# [11, 7, 5]
# 4
# [4, 2, 17]
# 23
# [23, 14, 3]
# 2
# [2, 6, 21]
# 15
# [15, 6, 12]
# 8
# [8, 17, 23]
# 16
# [16, 17, 10]
# 9
# [9, 7, 10]
# 15
# [15, 9, 11]
# 10
# [10, 18, 12]
# 14
# [14, 0, 2]
# 13
# [13, 14, 5]
# 10
# [10, 16, 18]
# 12
# [12, 13, 1]
# 1
# [1, 4, 8]
# 2
# [2, 11, 21]
# 13
# [13, 19, 12]
# 9
# [9, 21, 1]
# 3
# [3, 14, 13]
# 7
# [7, 21, 8]
# 0
# [0, 17, 4]
# 10
# [10, 12, 20]
# 3
# [3, 9, 13]
# 15
# [15, 10, 14]
# 11
# [11, 12, 15]
# 2
# [2, 12, 5]
# 19
# [19, 21, 5]
# 16
# [16, 1, 10]
# 13
# [13, 10, 2]
# 23
# [23, 18, 22]
# 14
# [14, 17, 5]
# 16
# [16, 2, 5]
# 3
# [3, 21, 2]
# 13
# [13, 19, 23]
# 5
# [5, 23, 14]
# 13
# [13, 6, 8]
# 12
# [12, 3, 10]
# 10
# [10, 13, 7]
# 19
# [19, 16, 4]
# 5
# [5, 13, 9]
# 17
# [17, 6, 21]
# 7
# [7, 9, 15]
# 12
# [12, 14, 5]
# 15
# [15, 16, 6]
# 13
# [13, 10, 6]
# 6
# [6, 8, 4]
# 5
# [5, 8, 16]
# 0
# [0, 16, 19]
# 4
# [4, 0, 9]
# 15
# [15, 2, 11]
# 1
# [1, 10, 19]
# 14
# [14, 3, 15]
# 7
# [7, 11, 23]
# 16
# [16, 17, 18]
# 8
# [8, 6, 1]
# 21
# [21, 9, 18]
# 12
# [12, 5, 6]
# 6
# [6, 8, 1]
# 6
# [6, 8, 17]
# 9
# [9, 8, 21]
# 6
# [6, 19, 15]
# 0
# [0, 17, 2]
# 11
# [11, 23, 10]
# 19
# [19, 18, 20]
# 14
# [14, 15, 8]
# 16
# [16, 10, 8]
# 4
# [4, 15, 5]
# 1
# [1, 4, 23]
# 18
# [18, 22, 7]
# 19
# [19, 17, 18]
# 2
# [2, 22, 0]
# 14
# [14, 6, 2]
# 21
# [21, 7, 5]
# 2
# [2, 16, 23]
# 5
# [5, 19, 4]
# 10
# [10, 7, 13]
# 11
# [11, 13, 12]
# 0
# [0, 15, 20]
# 2
# [2, 8, 3]
# 7
# [7, 19, 13]
# 19
# [19, 7, 20]
# 11
# [11, 7, 2]
# 17
# [17, 12, 1]
# 1
# [1, 15, 8]
# 7
# [7, 0, 6]
# 13
# [13, 6, 10]
# 2
# [2, 21, 20]
# 1
# [1, 13, 14]
# 1
# [1, 8, 12]
# 20
# [20, 18, 7]
# 6
# [6, 4, 18]
# 1
# [1, 18, 4]
# 23
# [23, 16, 2]
# 13
# [13, 6, 5]
# 21
# [21, 5, 22]
# 2
# [2, 4, 9]
# 15
# [15, 5, 20]
# 23
# [23, 15, 9]
# 4
# [4, 3, 10]
# 18
# [18, 12, 16]
# 19
# [19, 9, 10]
# 8
# [8, 13, 9]
# 4
# [4, 7, 1]
# 21
# [21, 22, 17]
# 4
# [4, 19, 12]
# 19
# [19, 11, 2]
# 12
# [12, 21, 4]
# 21
# [21, 10, 6]
# 20
# [20, 4, 22]
# 11
# [11, 18, 6]
# 13
# [13, 14, 17]
# 22
# [22, 16, 19]
# 21
# [21, 23, 12]
# 3
# [3, 6, 14]
# 3
# [3, 5, 14]
# 6
# [6, 0, 3]
# 6
# [6, 12, 18]
# 19
# [19, 20, 16]
# 2
# [2, 6, 4]
# 17
# [17, 6, 19]
# 23
# [23, 15, 8]
# 19
# [19, 2, 7]
# 4
# [4, 11, 14]
# 3
# [3, 5, 15]
# 8
# [8, 6, 16]
# 21
# [21, 12, 10]
# 19
# [19, 5, 6]
# 5
# [5, 3, 9]
# 13
# [13, 1, 22]
# 7
# [7, 9, 6]
# 19
# [19, 6, 18]
# 16
# [16, 22, 3]
# 14
# [14, 11, 10]
# 2
# [2, 18, 17]
# 18
# [18, 23, 0]
# 4
# [4, 6, 16]
# 14
# [14, 3, 10]
# 16
# [16, 22, 18]
# 14
# [14, 17, 11]
# 14
# [14, 4, 16]
# 17
# [17, 8, 23]
# 10
# [10, 14, 0]
# 18
# [18, 17, 11]
# 16
# [16, 23, 1]
# 7
# [7, 21, 0]
# 15
# [15, 19, 18]
# 10
# [10, 13, 20]
# 15
# [15, 21, 22]
# 11
# [11, 2, 6]
# 10
# [10, 6, 14]
# 5
# [5, 11, 16]
# 4
# [4, 17, 5]
# 13
# [13, 6, 9]
# 18
# [18, 7, 9]
# 22
# [22, 1, 10]
# 12
# [12, 18, 7]
# 5
# [5, 12, 14]
# 13
# [13, 20, 7]
# 8
# [8, 4, 17]
# 4
# [4, 6, 12]
# 2
# [2, 20, 15]
# 12
# [12, 18, 6]
# 17
# [17, 8, 7]
# 13
# [13, 14, 5]
# 11
# [11, 6, 9]
# 6
# [6, 18, 1]
# 22
# [22, 3, 18]
# 2
# [2, 4, 11]
# 20
# [20, 3, 7]
# 4
# [4, 0, 3]
# 8
# [8, 6, 1]
# 0
# [0, 13, 9]
# 1
# [1, 19, 18]
# 2
# [2, 4, 19]
# 10
# [10, 19, 21]
# 0
# [0, 23, 19]
# 1
# [1, 13, 20]
# 10
# [10, 21, 14]
# 23
# [23, 19, 15]
# 12
# [12, 18, 5]
# 13
# [13, 6, 20]
# 6
# [6, 13, 12]
# 23
# [23, 9, 1]
# 23
# [23, 0, 5]
# 9
# [9, 16, 21]
# 5
# [5, 9, 17]
# 16
# [16, 23, 7]
# 16
# [16, 2, 17]
# 6
# [6, 11, 2]
# 16
# [16, 22, 0]
# 21
# [21, 23, 20]
# 11
# [11, 6, 4]
# 1
# [1, 15, 4]
# 12
# [12, 6, 2]
# 20
# [20, 16, 11]
# 13
# [13, 6, 17]
# 4
# [4, 14, 0]
# 12
# [12, 17, 14]
# 19
# [19, 11, 1]
# 9
# [9, 12, 8]
# 19
# [19, 7, 1]
# 0
# [0, 10, 14]
# 18
# [18, 6, 4]
# 12
# [12, 5, 14]
# 1
# [1, 6, 13]
# 2
# [2, 14, 3]
# 6
# [6, 17, 12]
# 17
# [17, 5, 0]
# 16
# [16, 11, 6]
# 10
# [10, 21, 19]
# 18
# [18, 19, 1]
# 3
# [3, 23, 19]
# 20
# [20, 15, 14]
# 14
# [14, 12, 0]
# 2
# [2, 8, 20]
# 6
# [6, 8, 13]
# 22
# [22, 19, 1]
# 9
# [9, 10, 2]
# 1
# [1, 6, 16]
# 8
# [8, 15, 12]
# 0
# [0, 22, 8]
# 23
# [23, 5, 3]
# 9
# [9, 12, 15]
# 16
# [16, 19, 8]
# 12
# [12, 21, 16]
# 19
# [19, 20, 9]
# 8
# [8, 17, 23]
# 22
# [22, 20, 10]
# 11
# [11, 7, 14]
# 21
# [21, 11, 19]
# 9
# [9, 20, 8]
# 10
# [10, 16, 13]
# 17
# [17, 5, 8]
# 12
# [12, 14, 9]
# 1
# [1, 16, 12]
# 15
# [15, 2, 23]
# 22
# [22, 7, 12]
# 7
# [7, 13, 1]
# 17
# [17, 4, 19]
# 12
# [12, 16, 6]
# 15
# [15, 14, 2]
# 9
# [9, 15, 0]
# 16
# [16, 3, 11]
# 1
# [1, 15, 10]
# 14
# [14, 3, 12]
# 3
# [3, 4, 8]
# 4
# [4, 16, 2]
# 15
# [15, 6, 2]
# 11
# [11, 23, 21]
# 4
# [4, 2, 0]
# 13
# [13, 2, 22]
# 2
# [2, 12, 4]
# 1
# [1, 12, 2]
# 10
# [10, 3, 14]
# 16
# [16, 9, 20]
# 23
# [23, 20, 19]
# 1
# [1, 14, 20]
# 7
# [7, 18, 9]
# 1
# [1, 8, 18]
# 18
# [18, 6, 17]
# 6
# [6, 20, 21]
# 12
# [12, 7, 9]
# 20
# [20, 17, 5]
# 7
# [7, 21, 22]
# 12
# [12, 14, 5]
# 6
# [6, 23, 15]
# 12
# [12, 6, 7]
# 20
# [20, 18, 15]
# 9
# [9, 22, 5]
# 14
# [14, 3, 4]
# 19
# [19, 1, 5]
# 14
# [14, 12, 6]
# 15
# [15, 3, 14]
# 18
# [18, 21, 9]
# 9
# [9, 5, 15]
# 14
# [14, 15, 3]
# 13
# [13, 7, 6]
# 12
# [12, 16, 7]
# 3
# [3, 17, 0]
# 17
# [17, 23, 20]
# 2
# [2, 9, 22]
# 1
# [1, 2, 3]
# 21
# [21, 10, 11]
# 21
# [21, 23, 9]
# 12
# [12, 23, 4]
# 23
# [23, 20, 17]
# 8
# [8, 17, 10]
# 23
# [23, 13, 10]
# 15
# [15, 6, 18]
# 21
# [21, 0, 5]
# 2
# [2, 21, 20]
# 13
# [13, 22, 7]
# 8
# [8, 7, 13]
# 22
# [22, 10, 7]
# 6
# [6, 19, 1]
# 0
# [0, 5, 8]
# 17
# [17, 4, 7]
# 23
# [23, 8, 0]
# 17
# [17, 16, 11]
# 19
# [19, 4, 0]
# 23
# [23, 10, 8]
# 15
# [15, 2, 14]
# 2
# [2, 9, 14]
# 9
# [9, 8, 4]
# 23
# [23, 3, 13]
# 14
# [14, 21, 19]
# 14
# [14, 9, 10]
# 16
# [16, 4, 14]
# 2
# [2, 21, 7]
# 13
# [13, 7, 2]
# 5
# [5, 18, 23]
# 20
# [20, 5, 11]
# 14
# [14, 0, 22]
# 3
# [3, 0, 8]
# 14
# [14, 4, 16]
# 20
# [20, 17, 19]
# 8
# [8, 19, 3]
# 23
# [23, 14, 21]
# 21
# [21, 11, 20]
# 8
# [8, 14, 7]
# 21
# [21, 23, 10]
# 6
# [6, 0, 3]
# 3
# [3, 12, 22]
# 0
# [0, 11, 14]
# 19
# [19, 22, 13]
# 3
# [3, 18, 5]
# 11
# [11, 17, 12]
# 21
# [21, 19, 7]
# 14
# [14, 18, 3]
# 5
# [5, 11, 4]
# 0
# [0, 22, 8]
# 17
# [17, 19, 2]
# 11
# [11, 15, 3]
# 22
# [22, 6, 5]
# 18
# [18, 20, 6]
# 15
# [15, 23, 17]
# 0
# [0, 11, 4]
# 20
# [20, 5, 16]
# 19
# [19, 8, 5]
# 5
# [5, 3, 6]
# 15
# [15, 23, 17]
# 20
# [20, 7, 14]
# 23
# [23, 20, 19]
# 17
# [17, 10, 23]
# 14
# [14, 15, 9]
# 22
# [22, 9, 18]
# 5
# [5, 19, 20]
# 17
# [17, 21, 20]
# 8
# [8, 3, 9]
# 8
# [8, 12, 5]
# 1
# [1, 9, 3]
# 2
# [2, 6, 12]
# 4
# [4, 20, 9]
# 9
# [9, 12, 1]
# 9
# [9, 17, 8]
# 17
# [17, 1, 0]
# 14
# [14, 10, 23]
# 13
# [13, 7, 9]
# 21
# [21, 4, 5]
# 0
# [0, 18, 22]
# 13
# [13, 22, 2]
# 18
# [18, 3, 22]
# 18
# [18, 13, 3]
# 22
# [22, 5, 8]
# 10
# [10, 0, 20]
# 19
# [19, 7, 20]
# 1
# [1, 8, 14]
# 9
# [9, 11, 6]
# 21
# [21, 3, 9]
# 9
# [9, 1, 19]
# 11
# [11, 10, 14]
# 12
# [12, 1, 15]
# 11
# [11, 12, 3]
# 2
# [2, 4, 13]
# 15
# [15, 22, 12]
# 15
# [15, 0, 5]
# 2
# [2, 7, 17]
# 0
# [0, 9, 4]
# 5
# [5, 17, 1]
# 3
# [3, 8, 19]
# 0
# [0, 4, 8]
# 17
# [17, 0, 9]
# 18
# [18, 2, 14]
# 11
# [11, 19, 6]
# 3
# [3, 16, 17]
# 9
# [9, 22, 16]
# 23
# [23, 1, 2]
# 1
# [1, 5, 2]
# 1
# [1, 20, 6]
# 15
# [15, 0, 7]
# 2
# [2, 21, 17]
# 12
# [12, 23, 3]
# 17
# [17, 18, 12]
# 7
# [7, 13, 12]
# 10
# [10, 4, 14]
# 15
# [15, 18, 0]
# 5
# [5, 3, 21]
# 21
# [21, 9, 4]
# 10
# [10, 17, 16]
# 12
# [12, 20, 5]
# 14
# [14, 21, 13]
# 23
# [23, 20, 21]
# 4
# [4, 23, 14]
# 18
# [18, 2, 15]
# 8
# [8, 10, 18]
# 8
# [8, 20, 19]
# 13
# [13, 4, 7]
# 7
# [7, 8, 3]
# 16
# [16, 17, 10]
# 15
# [15, 14, 6]
# 1
# [1, 17, 7]
# 10
# [10, 2, 14]
# 15
# [15, 21, 4]
# 3
# [3, 13, 17]
# 8
# [8, 17, 10]
# 12
# [12, 18, 9]
# 13
# [13, 0, 3]
# 7
# [7, 20, 21]
# 3
# [3, 1, 19]
# 11
# [11, 10, 13]
# 18
# [18, 9, 5]
# 0
# [0, 2, 14]
# 10
# [10, 16, 5]
# 16
# [16, 10, 13]
# 11
# [11, 12, 1]
# 7
# [7, 18, 9]
# 10
# [10, 20, 3]
# 4
# [4, 5, 12]
# 22
# [22, 13, 15]
# 17
# [17, 10, 20]
# 6
# [6, 5, 14]
# 1
# [1, 3, 14]
# 8
# [8, 13, 14]
# 4
# [4, 14, 2]
# 3
# [3, 20, 16]
# 4
# [4, 7, 10]
# 18
# [18, 23, 9]
# 9
# [9, 6, 3]
# 15
# [15, 6, 13]
# 12
# [12, 3, 9]
# 12
# [12, 17, 18]
# 22
# [22, 16, 9]
# 15
# [15, 23, 5]
# 21
# [21, 9, 18]
# 0
# [0, 23, 7]
# 4
# [4, 23, 5]
# 14
# [14, 3, 22]
# 1
# [1, 19, 0]
# 16
# [16, 6, 4]
# 2
# [2, 9, 12]
# 21
# [21, 13, 20]
# 2
# [2, 18, 5]
# 19
# [19, 18, 10]
# 21
# [21, 14, 19]
# 1
# [1, 8, 3]
# 14
# [14, 9, 12]
# 12
# [12, 4, 13]
# 1
# [1, 12, 22]
# 10
# [10, 6, 3]
# 11
# [11, 4, 9]
# 13
# [13, 0, 21]
# 23
# [23, 9, 17]
# 17
# [17, 23, 14]
# 19
# [19, 17, 2]
# 1
# [1, 0, 21]
# 18
# [18, 17, 9]
# 13
# [13, 0, 20]
# 2
# [2, 22, 19]
# 11
# [11, 10, 3]
# 8
# [8, 4, 5]
# 10
# [10, 19, 3]
# 6
# [6, 1, 0]
# 22
# [22, 9, 14]
# 9
# [9, 16, 7]
# 3
# [3, 4, 8]
# 9
# [9, 6, 12]
# 18
# [18, 11, 13]
# 16
# [16, 9, 23]
# 2
# [2, 22, 21]
# 6
# [6, 4, 9]
# 13
# [13, 4, 2]
# 19
# [19, 4, 18]
# 23
# [23, 20, 3]
# 12
# [12, 15, 14]
# 13
# [13, 4, 16]
# 8
# [8, 6, 16]
# 2
# [2, 15, 11]
# 22
# [22, 7, 21]
# 20
# [20, 1, 16]
# 0
# [0, 10, 21]
# 22
# [22, 9, 6]
# 0
# [0, 23, 15]
# 20
# [20, 3, 9]
# 1
# [1, 12, 13]
# 0
# [0, 13, 1]
# 22
# [22, 20, 3]
# 11
# [11, 16, 4]
# 5
# [5, 12, 2]
# 10
# [10, 19, 16]
# 7
# [7, 20, 13]
# 21
# [21, 12, 3]
# 18
# [18, 11, 4]
# 20
# [20, 16, 11]
# 18
# [18, 9, 19]
# 13
# [13, 16, 3]
# 16
# [16, 23, 0]
# 16
# [16, 23, 10]
# 22
# [22, 8, 12]
# 22
# [22, 20, 8]
# 20
# [20, 22, 9]
# 6
# [6, 10, 1]
# 18
# [18, 20, 1]
# 16
# [16, 10, 7]
# 6
# [6, 14, 8]
# 21
# [21, 18, 11]
# 16
# [16, 12, 10]
# 14
# [14, 18, 15]
# 13
# [13, 11, 19]
# 16
# [16, 13, 9]
# 1
# [1, 22, 15]
# 13
# [13, 9, 14]
# 5
# [5, 12, 0]
# 17
# [17, 7, 3]
# 2
# [2, 3, 18]
# 23
# [23, 14, 17]
# 15
# [15, 3, 16]
# 15
# [15, 3, 4]
# 14
# [14, 9, 20]
# 11
# [11, 7, 6]
# 1
# [1, 14, 20]
# 14
# [14, 2, 20]
# 3
# [3, 12, 22]
# 2
# [2, 7, 14]
# 15
# [15, 21, 23]
# 16
# [16, 4, 5]
# 9
# [9, 13, 19]
# 0
# [0, 18, 22]
# 10
# [10, 7, 4]
# 19
# [19, 5, 23]
# 19
# [19, 14, 7]
# 4
# [4, 8, 23]
# 16
# [16, 1, 5]
# 23
# [23, 11, 7]
# 12
# [12, 14, 23]
# 22
# [22, 4, 7]
# 19
# [19, 11, 21]
# 9
# [9, 23, 16]
# 15
# [15, 11, 5]
# 13
# [13, 4, 12]
# 15
# [15, 1, 21]
# 9
# [9, 0, 14]
# 15
# [15, 2, 1]
# 2
# [2, 5, 3]
# 1
# [1, 3, 8]
# 15
# [15, 22, 7]
# 6
# [6, 13, 20]
# 2
# [2, 7, 9]
# 12
# [12, 20, 5]
# 8
# [8, 22, 10]
# 4
# [4, 8, 20]
# 21
# [21, 3, 2]
# 5
# [5, 23, 8]
# 22
# [22, 7, 21]
# 6
# [6, 17, 18]
# 7
# [7, 4, 8]
# 3
# [3, 10, 19]
# 12
# [12, 2, 19]
# 21
# [21, 6, 1]
# 11
# [11, 15, 13]
# 9
# [9, 23, 1]
# 6
# [6, 16, 14]
# 13
# [13, 0, 6]
# 23
# [23, 14, 9]
# 12
# [12, 22, 5]
# 19
# [19, 16, 5]
# 14
# [14, 11, 22]
# 3
# [3, 12, 7]
# 19
# [19, 17, 10]
# 2
# [2, 6, 14]
# 9
# [9, 16, 23]
# 14
# [14, 3, 23]
# 9
# [9, 20, 3]
# 9
# [9, 8, 12]
# 3
# [3, 2, 14]
# 7
# [7, 6, 21]
# 4
# [4, 19, 8]
# 12
# [12, 22, 11]
# 2
# [2, 12, 1]
# 18
# [18, 12, 20]
# 2
# [2, 6, 15]
# 8
# [8, 4, 10]
# 1
# [1, 11, 12]
# 22
# [22, 19, 6]
# 6
# [6, 2, 17]
# 3
# [3, 15, 11]
# 23
# [23, 7, 12]
# 20
# [20, 14, 8]
# 17
# [17, 20, 2]
# 13
# [13, 0, 1]
# 19
# [19, 10, 0]
# 7
# [7, 18, 17]
# 13
# [13, 1, 14]
# 23
# [23, 11, 20]
# 23
# [23, 19, 22]
# 7
# [7, 17, 13]
# 10
# [10, 0, 19]
# 23
# [23, 4, 10]
# 14
# [14, 23, 2]
# 17
# [17, 3, 18]
# 5
# [5, 1, 2]
# 14
# [14, 23, 5]
# 14
# [14, 3, 21]
# 12
# [12, 18, 6]
# 12
# [12, 17, 18]
# 14
# [14, 22, 4]
# 17
# [17, 13, 8]
# 12
# [12, 7, 20]
# 16
# [16, 20, 6]
# 20
# [20, 0, 9]
# 16
# [16, 12, 0]
# 22
# [22, 5, 14]
# 12
# [12, 8, 23]
# 15
# [15, 13, 1]
# 1
# [1, 22, 5]
# 12
# [12, 22, 11]
# 13
# [13, 22, 5]
# 7
# [7, 4, 20]
# 8
# [8, 10, 13]
# 21
# [21, 9, 0]
# 5
# [5, 21, 20]
# 8
# [8, 13, 15]
# 23
# [23, 19, 15]
# 1
# [1, 9, 2]
# 22
# [22, 18, 10]
# 10
# [10, 11, 13]
# 22
# [22, 23, 2]
# 8
# [8, 20, 4]
# 2
# [2, 4, 5]
# 14
# [14, 3, 1]
# 5
# [5, 12, 11]
# 18
# [18, 0, 9]
# 10
# [10, 16, 3]
# 1
# [1, 19, 17]
# 15
# [15, 12, 6]
# 14
# [14, 21, 19]
# 6
# [6, 10, 1]
# 11
# [11, 4, 10]
# 3
# [3, 7, 11]
# 1
# [1, 11, 14]
# 6
# [6, 16, 1]
# 17
# [17, 0, 4]
# 1
# [1, 6, 9]
# 0
# [0, 7, 22]
# 21
# [21, 19, 7]
# 3
# [3, 10, 20]
# 5
# [5, 23, 0]
# 22
# [22, 9, 11]
# 18
# [18, 12, 15]
# 16
# [16, 12, 0]
# 11
# [11, 12, 2]
# 3
# [3, 11, 2]
# 17
# [17, 12, 21]
# 12
# [12, 16, 2]
# 21
# [21, 1, 8]
# 13
# [13, 0, 10]
# 1
# [1, 2, 5]
# 14
# [14, 19, 0]
# 19
# [19, 3, 12]
# 9
# [9, 23, 6]
# 22
# [22, 6, 11]
# 20
# [20, 22, 8]
# 4
# [4, 13, 14]
# 9
# [9, 20, 14]
# 8
# [8, 12, 13]
# 14
# [14, 5, 19]
# 11
# [11, 6, 8]
# 4
# [4, 21, 13]
# 16
# [16, 15, 7]
# 7
# [7, 20, 15]
# 1
# [1, 16, 20]
# 22
# [22, 23, 8]
# 17
# [17, 2, 18]
# 21
# [21, 18, 13]
# 4
# [4, 22, 15]
# 14
# [14, 3, 0]
# 18
# [18, 5, 6]
# 2
# [2, 17, 9]
# 1
# [1, 22, 6]
# 1
# [1, 19, 15]
# 9
# [9, 16, 2]
# 11
# [11, 9, 21]
# 18
# [18, 15, 8]
# 13
# [13, 7, 22]
# 6
# [6, 22, 7]
# 23
# [23, 22, 14]
# 4
# [4, 12, 8]
# 14
# [14, 1, 0]
# 12
# [12, 11, 17]
# 4
# [4, 10, 0]
# 23
# [23, 2, 7]
# 19
# [19, 13, 1]
# 18
# [18, 7, 15]
# 20
# [20, 17, 3]
# 6
# [6, 23, 20]
# 13
# [13, 4, 23]
# 4
# [4, 18, 12]
# 1
# [1, 10, 12]
# 17
# [17, 3, 0]
# 7
# [7, 23, 0]
# 3
# [3, 22, 12]
# 11
# [11, 21, 18]
# 21
# [21, 10, 7]
# 19
# [19, 13, 17]
# 18
# [18, 0, 7]
# 1
# [1, 17, 21]
# 11
# [11, 3, 6]
# 14
# [14, 10, 18]
# 6
# [6, 4, 23]
# 7
# [7, 18, 19]
# 0
# [0, 7, 16]
# 18
# [18, 14, 21]
# 11
# [11, 15, 2]
# 22
# [22, 9, 11]
# 14
# [14, 15, 22]
# 20
# [20, 14, 5]
# 15
# [15, 11, 5]
# 18
# [18, 20, 10]
# 13
# [13, 7, 20]
# 10
# [10, 1, 12]
# 0
# [0, 6, 16]
# 2
# [2, 10, 6]
# 23
# [23, 4, 12]
# 16
# [16, 19, 0]
# 23
# [23, 10, 8]
# 7
# [7, 19, 1]
# 18
# [18, 5, 4]
# 13
# [13, 1, 8]
# 13
# [13, 10, 8]
# 2
# [2, 12, 10]
# 3
# [3, 0, 6]
# 15
# [15, 11, 0]
# 23
# [23, 4, 0]
# 19
# [19, 12, 4]
# 19
# [19, 16, 3]
# 9
# [9, 22, 14]
# 5
# [5, 13, 20]
# 21
# [21, 8, 5]
# 12
# [12, 23, 7]
# 11
# [11, 12, 9]
# 8
# [8, 14, 13]
# 6
# [6, 1, 15]
# 1
# [1, 10, 11]
# 8
# [8, 15, 18]
# 17
# [17, 19, 4]
# 22
# [22, 19, 15]
# 18
# [18, 9, 3]
# 21
# [21, 14, 2]
# 1
# [1, 5, 3]
# 18
# [18, 15, 4]
# 12
# [12, 2, 19]
# 23
# [23, 3, 16]
# 12
# [12, 23, 11]
# 4
# [4, 17, 16]
# 23
# [23, 9, 13]
# 3
# [3, 5, 7]
# 7
# [7, 20, 16]
# 16
# [16, 13, 14]
# 15
# [15, 12, 5]
# 1
# [1, 23, 15]
# 22
# [22, 2, 12]
# 0
# [0, 2, 22]
# 11
# [11, 3, 15]
# 17
# [17, 13, 14]
# 8
# [8, 1, 18]
# 0
# [0, 11, 14]
# 9
# [9, 2, 22]
# 14
# [14, 16, 6]
# 14
# [14, 16, 4]
# 21
# [21, 15, 17]
# 17
# [17, 10, 3]
# 4
# [4, 10, 22]
# 1
# [1, 2, 12]
# 7
# [7, 20, 9]
# 11
# [11, 22, 15]
# 18
# [18, 1, 2]
# 15
# [15, 7, 13]
# 9
# [9, 8, 17]
# 22
# [22, 21, 20]
# 1
# [1, 16, 0]
# 11
# [11, 14, 1]
# 9
# [9, 15, 2]
# 17
# [17, 20, 12]
# 20
# [20, 1, 23]
# 18
# [18, 10, 0]
# 22
# [22, 2, 3]
# 14
# [14, 5, 12]
# 0
# [0, 15, 9]
# 6
# [6, 3, 2]
# 5
# [5, 6, 21]
# 21
# [21, 8, 1]
# 9
# [9, 14, 23]
# 9
# [9, 6, 21]
# 17
# [17, 4, 22]
# 2
# [2, 16, 9]
# 21
# [21, 16, 7]
# 2
# [2, 23, 17]
# 8
# [8, 12, 2]
# 19
# [19, 0, 21]
# 21
# [21, 17, 19]
# 14
# [14, 7, 3]
# 1
# [1, 17, 19]
# 0
# [0, 10, 16]
# 13
# [13, 20, 4]
# 12
# [12, 21, 0]
# 22
# [22, 2, 19]
# 12
# [12, 11, 5]
# 22
# [22, 11, 4]
# 15
# [15, 12, 16]
# 12
# [12, 7, 19]
# 1
# [1, 14, 19]
# 8
# [8, 5, 11]
# 21
# [21, 18, 9]
# 18
# [18, 0, 5]
# 0
# [0, 22, 19]
# 16
# [16, 5, 21]
# 9
# [9, 7, 11]
# 7
# [7, 1, 22]
# 19
# [19, 13, 9]
# 10
# [10, 8, 0]
# 17
# [17, 8, 18]
# 7
# [7, 1, 20]
# 2
# [2, 21, 13]
# 21
# [21, 9, 8]
# 23
# [23, 6, 21]
# 21
# [21, 0, 9]
# 3
# [3, 17, 2]
# 10
# [10, 6, 7]
# 11
# [11, 4, 1]
# 1
# [1, 18, 3]
# 6
# [6, 18, 0]
# 12
# [12, 22, 9]
# 4
# [4, 1, 15]
# 3
# [3, 2, 16]
# 23
# [23, 13, 19]
# 8
# [8, 15, 3]
# 10
# [10, 0, 13]
# 15
# [15, 6, 10]
# 2
# [2, 5, 23]
# 9
# [9, 0, 12]
# 20
# [20, 17, 18]
# 19
# [19, 15, 17]
# 1
# [1, 8, 23]
# 5
# [5, 21, 1]
# 10
# [10, 17, 2]
# 14
# [14, 2, 18]
# 19
# [19, 2, 5]
# 6
# [6, 9, 14]
# 12
# [12, 22, 11]
# 4
# [4, 15, 9]
# 10
# [10, 17, 15]
# 2
# [2, 22, 12]
# 17
# [17, 21, 8]
# 9
# [9, 5, 19]
# 1
# [1, 10, 13]
# 0
# [0, 7, 22]
# 2
# [2, 4, 6]
# 18
# [18, 21, 1]
# 7
# [7, 21, 6]
# 22
# [22, 11, 0]
# 2
# [2, 8, 12]
# 3
# [3, 15, 5]
# 20
# [20, 18, 23]
# 3
# [3, 13, 10]
# 7
# [7, 17, 2]
# 23
# [23, 10, 19]
# 11
# [11, 10, 20]
# 19
# [19, 15, 8]
# 23
# [23, 22, 8]
# 4
# [4, 11, 8]
# 2
# [2, 17, 10]
# 19
# [19, 14, 10]
# 6
# [6, 15, 12]
# 21
# [21, 13, 3]
# 10
# [10, 6, 8]
# 11
# [11, 10, 15]
# 5
# [5, 9, 20]
# 20
# [20, 0, 19]
# 1
# [1, 11, 3]
# 1
# [1, 11, 8]
# 4
# [4, 22, 7]
# 22
# [22, 3, 20]
# 6
# [6, 11, 5]
# 2
# [2, 20, 1]
# 16
# [16, 18, 13]
# 1
# [1, 23, 14]
# 1
# [1, 20, 17]
# 23
# [23, 17, 0]
# 18
# [18, 10, 9]
# 16
# [16, 23, 8]
# 14
# [14, 0, 18]
# 7
# [7, 12, 16]
# 15
# [15, 14, 17]
# 20
# [20, 17, 5]
# 17
# [17, 0, 12]
# 16
# [16, 11, 15]
# 10
# [10, 6, 8]
# 12
# [12, 15, 4]
# 10
# [10, 12, 16]
# 20
# [20, 13, 5]
# 23
# [23, 20, 15]
# 15
# [15, 16, 10]
# 12
# [12, 14, 22]
# 21
# [21, 15, 11]
# 16
# [16, 9, 12]
# 21
# [21, 20, 5]
# 1
# [1, 17, 6]
# 23
# [23, 1, 8]
# 18
# [18, 10, 22]
# 5
# [5, 17, 23]
# 18
# [18, 10, 0]
# 8
# [8, 12, 22]
# 14
# [14, 1, 4]
# 19
# [19, 0, 23]
# 2
# [2, 3, 9]
# 18
# [18, 19, 2]
# 23
# [23, 18, 9]
# 1
# [1, 16, 12]
# 4
# [4, 1, 20]
# 3
# [3, 11, 18]
# 8
# [8, 20, 9]
# 15
# [15, 21, 20]
# 20
# [20, 2, 0]
# 19
# [19, 18, 0]
# 5
# [5, 21, 20]
# 11
# [11, 13, 18]
# 4
# [4, 15, 17]
# 5
# [5, 20, 7]
# 8
# [8, 10, 1]
# 17
# [17, 3, 15]
# 10
# [10, 23, 16]
# 2
# [2, 17, 13]
# 16
# [16, 19, 22]
# 13
# [13, 23, 11]
# 2
# [2, 12, 23]
# 11
# [11, 16, 1]
# 17
# [17, 22, 4]
# 1
# [1, 8, 22]
# 7
# [7, 4, 0]
# 12
# [12, 9, 0]
# 9
# [9, 19, 16]
# 16
# [16, 11, 7]
# 23
# [23, 16, 13]
# 18
# [18, 21, 9]
# 18
# [18, 13, 6]
# 22
# [22, 23, 14]
# 20
# [20, 5, 19]
# 0
# [0, 23, 21]
# 21
# [21, 19, 12]
# 22
# [22, 16, 20]
# 22
# [22, 6, 4]
# 13
# [13, 18, 23]
# 3
# [3, 15, 6]
# 7
# [7, 21, 3]
# 12
# [12, 18, 7]
# 18
# [18, 23, 2]
# 5
# [5, 7, 19]
# 20
# [20, 16, 5]
# 16
# [16, 19, 5]
# 6
# [6, 22, 19]
# 3
# [3, 16, 14]
# 19
# [19, 11, 12]
# 15
# [15, 18, 9]
# 11
# [11, 0, 21]
# 13
# [13, 2, 9]
# 6
# [6, 11, 16]
# 8
# [8, 22, 19]
# 5
# [5, 0, 21]
# 20
# [20, 22, 17]
# 12
# [12, 20, 6]
# 5
# [5, 3, 22]
# 11
# [11, 1, 19]
# 18
# [18, 4, 17]
# 10
# [10, 21, 2]
# 15
# [15, 12, 21]
# 7
# [7, 10, 1]
# 10
# [10, 19, 13]
# 21
# [21, 12, 5]
# 1
# [1, 3, 14]
# 4
# [4, 3, 23]
# 11
# [11, 4, 23]
# 14
# [14, 17, 4]
# 0
# [0, 20, 7]
# 13
# [13, 16, 4]
# 11
# [11, 2, 9]
# 20
# [20, 21, 11]
# 0
# [0, 10, 6]
# 21
# [21, 3, 4]
# 20
# [20, 2, 0]
# 22
# [22, 9, 5]
# 19
# [19, 20, 9]
# 6
# [6, 21, 5]
# 14
# [14, 18, 20]
# 1
# [1, 12, 10]
# 0
# [0, 14, 7]
# 8
# [8, 0, 15]
# 23
# [23, 9, 20]
# 21
# [21, 17, 6]
# 13
# [13, 22, 14]
# 6
# [6, 10, 21]
# 0
# [0, 17, 18]
# 22
# [22, 11, 17]
# 1
# [1, 19, 15]
# 22
# [22, 3, 23]
# 11
# [11, 23, 3]
# 21
# [21, 14, 22]
# 2
# [2, 12, 3]
# 17
# [17, 4, 1]
# 18
# [18, 8, 9]
# 10
# [10, 2, 7]
# 15
# [15, 6, 11]
# 22
# [22, 18, 17]
# 8
# [8, 1, 7]
# 8
# [8, 16, 19]
# 21
# [21, 12, 16]
# 12
# [12, 19, 18]
# 8
# [8, 16, 0]
# 14
# [14, 21, 13]
# 6
# [6, 18, 20]
# 1
# [1, 23, 18]
# 7
# [7, 19, 16]
# 4
# [4, 14, 19]
# 9
# [9, 21, 16]
# 21
# [21, 20, 4]
# 15
# [15, 4, 5]
# 6
# [6, 23, 5]
# 19
# [19, 4, 23]
# 22
# [22, 6, 12]
# 6
# [6, 15, 17]
# 18
# [18, 19, 10]
# 9
# [9, 11, 7]
# 7
# [7, 3, 9]
# 9
# [9, 1, 6]
# 16
# [16, 9, 15]
# 9
# [9, 22, 2]
# 12
# [12, 6, 20]
# 22
# [22, 10, 16]
# 1
# [1, 12, 6]
# 11
# [11, 19, 1]
# 5
# [5, 4, 9]
# 0
# [0, 18, 19]
# 1
# [1, 21, 14]
# 10
# [10, 4, 17]
# 17
# [17, 23, 6]
# 14
# [14, 23, 2]
# 1
# [1, 15, 4]
# 11
# [11, 23, 21]
# 5
# [5, 18, 9]
# 15
# [15, 1, 20]
# 13
# [13, 7, 12]
# 15
# [15, 12, 7]
# 15
# [15, 17, 12]
# 7
# [7, 0, 19]
# 3
# [3, 22, 15]
# 23
# [23, 0, 21]
# 19
# [19, 10, 14]
# 12
# [12, 20, 1]
# 1
# [1, 9, 14]
# 6
# [6, 10, 9]
# 17
# [17, 20, 4]
# 16
# [16, 9, 3]
# 10
# [10, 18, 7]
# 23
# [23, 2, 20]
# 5
# [5, 12, 16]
# 7
# [7, 16, 4]
# 12
# [12, 3, 6]
# 22
# [22, 1, 23]
# 15
# [15, 8, 21]
# 11
# [11, 12, 23]
# 17
# [17, 18, 1]
# 7
# [7, 13, 10]
# 9
# [9, 7, 21]
# 8
# [8, 13, 17]
# 17
# [17, 18, 10]
# 0
# [0, 2, 4]
# 15
# [15, 19, 20]
# 23
# [23, 1, 14]
# 20
# [20, 1, 15]
# 15
# [15, 18, 13]
# 7
# [7, 6, 5]
# 15
# [15, 11, 5]
# 5
# [5, 14, 16]
# 7
# [7, 20, 14]
# 1
# [1, 4, 16]
# 2
# [2, 21, 23]
# 5
# [5, 17, 3]
# 3
# [3, 23, 11]
# 22
# [22, 12, 6]
# 12
# [12, 4, 16]
# 9
# [9, 20, 7]
# 19
# [19, 2, 11]
# 21
# [21, 23, 15]
# 14
# [14, 21, 18]
# 2
# [2, 22, 6]
# 12
# [12, 2, 19]
# 12
# [12, 11, 15]
# 8
# [8, 15, 7]
# 22
# [22, 21, 7]
# 15
# [15, 4, 9]
# 20
# [20, 11, 8]
# 2
# [2, 13, 0]
# 18
# [18, 11, 10]
# 15
# [15, 10, 2]
# 10
# [10, 8, 19]
# 3
# [3, 5, 22]
# 3
# [3, 7, 16]
# 9
# [9, 8, 12]
# 9
# [9, 11, 18]
# 16
# [16, 3, 18]
# 15
# [15, 17, 5]
# 3
# [3, 10, 15]
# 8
# [8, 22, 18]
# 21
# [21, 10, 15]
# 18
# [18, 5, 7]
# 19
# [19, 0, 7]
# 14
# [14, 1, 16]
# 4
# [4, 6, 8]
# 11
# [11, 19, 18]
# 14
# [14, 15, 1]
# 2
# [2, 4, 1]
# 5
# [5, 17, 20]
# 3
# [3, 19, 12]
# 15
# [15, 21, 12]
# 1
# [1, 5, 8]
# 19
# [19, 23, 20]
# 9
# [9, 13, 14]
# 1
# [1, 4, 16]
# 20
# [20, 16, 17]
# 6
# [6, 3, 19]
# 22
# [22, 11, 16]
# 9
# [9, 16, 22]
# 2
# [2, 17, 10]
# 1
# [1, 0, 3]
# 6
# [6, 8, 7]
# 5
# [5, 2, 9]
# 13
# [13, 11, 21]
# 8
# [8, 15, 12]
# 5
# [5, 7, 15]
# 10
# [10, 21, 3]
# 9
# [9, 15, 18]
# 11
# [11, 17, 14]
# 7
# [7, 12, 11]
# 3
# [3, 9, 16]
# 23
# [23, 14, 10]
# 20
# [20, 9, 13]
# 19
# [19, 21, 11]
# 13
# [13, 16, 0]
# 4
# [4, 14, 7]
# 15
# [15, 3, 18]
# 11
# [11, 23, 9]
# 17
# [17, 20, 9]
# 17
# [17, 16, 3]
# 1
# [1, 15, 19]
# 8
# [8, 4, 0]
# 13
# [13, 22, 12]
# 5
# [5, 20, 13]
# 7
# [7, 20, 19]
# 22
# [22, 2, 3]
# 14
# [14, 11, 1]
# 1
# [1, 9, 18]
# 4
# [4, 8, 22]
# 16
# [16, 2, 15]
# 3
# [3, 14, 13]
# 17
# [17, 20, 9]
# 6
# [6, 16, 21]
# 18
# [18, 23, 2]
# 10
# [10, 12, 16]
# 0
# [0, 1, 21]
# 16
# [16, 2, 5]
# 6
# [6, 4, 0]
# 0
# [0, 5, 19]
# 9
# [9, 0, 23]
# 21
# [21, 23, 14]
# 2
# [2, 7, 4]
# 4
# [4, 22, 16]
# 5
# [5, 17, 20]
# 22
# [22, 18, 14]
# 23
# [23, 6, 0]
# 16
# [16, 0, 2]
# 3
# [3, 1, 20]
# 6
# [6, 9, 4]
# 14
# [14, 8, 23]
# 18
# [18, 17, 15]
# 10
# [10, 12, 3]
# 19
# [19, 2, 23]
# 4
# [4, 21, 15]
# 13
# [13, 5, 8]
# 13
# [13, 22, 5]
# 17
# [17, 23, 4]
# 18
# [18, 9, 23]
# 2
# [2, 23, 3]
# 19
# [19, 9, 6]
# 19
# [19, 9, 3]
# 15
# [15, 14, 7]
# 22
# [22, 9, 13]
# 3
# [3, 9, 6]
# 10
# [10, 18, 16]
# 12
# [12, 11, 18]
# 10
# [10, 18, 23]
# 9
# [9, 17, 18]
# 21
# [21, 8, 6]
# 2
# [2, 19, 17]
# 7
# [7, 18, 5]
# 16
# [16, 11, 12]
# 8
# [8, 1, 3]
# 7
# [7, 5, 8]
# 20
# [20, 9, 14]
# 20
# [20, 12, 9]
# 8
# [8, 9, 2]
# 23
# [23, 0, 11]
# 21
# [21, 5, 0]
# 18
# [18, 11, 16]
# 17
# [17, 22, 14]
# 14
# [14, 17, 2]
# 17
# [17, 9, 20]
# 17
# [17, 6, 5]
# 16
# [16, 2, 7]
# 7
# [7, 21, 3]
# 6
# [6, 21, 17]
# 0
# [0, 10, 11]
# 17
# [17, 16, 19]
# 9
# [9, 11, 22]
# 19
# [19, 4, 8]
# 17
# [17, 4, 9]
# 23
# [23, 14, 11]
# 1
# [1, 11, 20]
# 15
# [15, 9, 4]
# 8
# [8, 22, 5]
# 17
# [17, 19, 0]
# 3
# [3, 19, 1]
# 11
# [11, 17, 8]
# 2
# [2, 15, 10]
# 12
# [12, 3, 20]
# 7
# [7, 2, 11]
# 6
# [6, 20, 12]
# 13
# [13, 0, 16]
# 15
# [15, 6, 9]
# 5
# [5, 1, 0]
# 22
# [22, 14, 7]
# 16
# [16, 6, 14]
# 20
# [20, 3, 6]
# 10
# [10, 12, 21]
# 19
# [19, 22, 18]
# 18
# [18, 4, 15]
# 16
# [16, 8, 3]
# 17
# [17, 4, 18]
# 8
# [8, 10, 1]
# 16
# [16, 6, 22]
# 6
# [6, 5, 10]
# 21
# [21, 12, 23]
# 22
# [22, 4, 7]
# 23
# [23, 16, 9]
# 17
# [17, 14, 15]
# 9
# [9, 5, 12]
# 3
# [3, 18, 1]
# 23
# [23, 12, 18]
# 14
# [14, 2, 6]
# 17
# [17, 2, 0]
# 9
# [9, 6, 23]
# 1
# [1, 12, 5]
# 3
# [3, 12, 4]
# 23
# [23, 0, 17]
# 0
# [0, 21, 15]
# 7
# [7, 12, 16]
# 12
# [12, 4, 2]
# 14
# [14, 7, 23]
# 0
# [0, 7, 22]
# 4
# [4, 3, 12]
# 22
# [22, 14, 5]
# 18
# [18, 6, 2]
# 3
# [3, 5, 16]
# 3
# [3, 14, 2]
# 7
# [7, 13, 4]
# 22
# [22, 7, 14]
# 0
# [0, 7, 18]
# 4
# [4, 9, 10]
# 11
# [11, 5, 6]
# 18
# [18, 7, 22]
# 22
# [22, 16, 23]
# 19
# [19, 22, 17]
# 13
# [13, 6, 17]
# 3
# [3, 14, 13]
# 6
# [6, 22, 0]
# 16
# [16, 7, 17]
# 20
# [20, 19, 16]
# 13
# [13, 19, 23]
# 17
# [17, 6, 15]
# 22
# [22, 9, 4]
# 7
# [7, 3, 9]
# 1
# [1, 4, 6]
# 10
# [10, 6, 21]
# 13
# [13, 6, 8]
# 4
# [4, 23, 5]
# 8
# [8, 4, 21]
# 5
# [5, 7, 20]
# 7
# [7, 2, 23]
# 18
# [18, 16, 21]
# 13
# [13, 12, 4]
# 14
# [14, 9, 23]
# 12
# [12, 18, 1]
# 12
# [12, 10, 16]
# 8
# [8, 16, 11]
# 8
# [8, 11, 2]
# 14
# [14, 9, 11]
# 4
# [4, 12, 13]
# 18
# [18, 4, 2]
# 12
# [12, 16, 14]
# 9
# [9, 2, 7]
# 15
# [15, 7, 2]
# 22
# [22, 13, 16]
# 15
# [15, 14, 19]
# 4
# [4, 17, 0]
# 0
# [0, 6, 8]
# 19
# [19, 22, 16]
# 2
# [2, 10, 16]
# 16
# [16, 2, 20]
# 11
# [11, 14, 23]
# 17
# [17, 7, 11]
# 3
# [3, 16, 8]
# 13
# [13, 4, 12]
# 10
# [10, 6, 8]
# 12
# [12, 23, 18]
# ...
# 4
# [4, 6, 21]
# 20
# [20, 10, 8]
# 8
# [8, 4, 18]
# 2
# [2, 23, 20]
# 20
# [20, 0, 21]
# 4
# [4, 19, 2]
# 0
# [0, 7, 22]
# 0
# [0, 11, 20]
# 23
# [23, 17, 21]
# 19
# [19, 9, 23]
# 5
# [5, 16, 4]
# 6
# [6, 4, 23]
# 23
# [23, 18, 16]
# 16
# [16, 22, 5]
# 9
# [9, 13, 7]
# 12
# [12, 15, 0]
# 19
# [19, 16, 21]
# 11
# [11, 17, 14]
# 5
# [5, 2, 19]
# 4
# [4, 19, 9]
# 3
# [3, 19, 16]
# 19
# [19, 18, 16]
# 11
# [11, 16, 5]
# 10
# [10, 9, 0]
# 13
# [13, 7, 22]
# 2
# [2, 4, 9]
# 13
# [13, 0, 20]
# 19
# [19, 8, 17]
# 14
# [14, 16, 20]
# 4
# [4, 12, 13]
# 1
# [1, 4, 21]
# 3
# [3, 6, 23]
# 10
# [10, 19, 12]
# 9
# [9, 14, 10]
# 10
# [10, 5, 8]
# 10
# [10, 9, 3]
# 17
# [17, 19, 14]
# 8
# [8, 7, 22]
# 23
# [23, 20, 0]
# 14
# [14, 20, 1]
# 3
# [3, 7, 11]
# 8
# [8, 2, 13]
# 19
# [19, 5, 2]
# 5
# [5, 20, 7]
# 19
# [19, 10, 21]
# 19
# [19, 16, 18]
# 18
# [18, 2, 21]
# 5
# [5, 17, 22]
# 1
# [1, 17, 13]
# 14
# [14, 3, 16]
# 15
# [15, 5, 22]
# 7
# [7, 15, 22]
# 16
# [16, 21, 8]
# 11
# [11, 5, 17]
# 23
# [23, 7, 15]
# 14
# [14, 5, 6]
# 14
# [14, 5, 16]
# 4
# [4, 2, 1]
# 5
# [5, 7, 1]
# 23
# [23, 6, 7]
# 15
# [15, 12, 17]
# 21
# [21, 16, 23]
# 15
# [15, 8, 2]
# 23
# [23, 17, 21]
# 3
# [3, 5, 0]
# 21
# [21, 5, 16]
# 21
# [21, 11, 17]
# 0
# [0, 4, 19]
# 12
# [12, 10, 1]
# 5
# [5, 21, 19]
# 17
# [17, 6, 14]
# 11
# [11, 20, 6]
# 12
# [12, 2, 7]
# 16
# [16, 23, 3]
# 0
# [0, 14, 16]
# 10
# [10, 8, 16]
# 15
# [15, 11, 9]
# 7
# [7, 0, 17]
# 2
# [2, 10, 0]
# 14
# [14, 21, 12]
# 22
# [22, 21, 7]
# 7
# [7, 0, 5]
# 13
# [13, 4, 9]
# 9
# [9, 23, 6]
# 19
# [19, 15, 18]
# 16
# [16, 12, 22]
# 8
# [8, 22, 10]
# 15
# [15, 9, 8]
# 17
# [17, 11, 0]
# 1
# [1, 16, 18]
# 22
# [22, 19, 13]
# 0
# [0, 2, 10]
# 4
# [4, 23, 6]
# 18
# [18, 23, 7]
# 4
# [4, 23, 3]
# 21
# [21, 22, 12]
# 22
# [22, 21, 16]
# 3
# [3, 10, 21]
# 19
# [19, 16, 6]
# 15
# [15, 17, 10]
# 4
# [4, 13, 16]
# 9
# [9, 16, 23]
# 6
# [6, 1, 15]
# 19
# [19, 16, 6]
# 23
# [23, 0, 17]
# 10
# [10, 5, 17]
# 20
# [20, 3, 22]
# 8
# [8, 5, 16]
# 1
# [1, 7, 5]
# 23
# [23, 3, 14]
# 7
# [7, 17, 8]
# 20
# [20, 17, 1]
# 0
# [0, 9, 11]
# 14
# [14, 8, 6]
# 5
# [5, 19, 15]
# 5
# [5, 11, 6]
# 16
# [16, 7, 11]
# 1
# [1, 22, 5]
# 13
# [13, 8, 12]
# 11
# [11, 23, 22]
# 18
# [18, 10, 9]
# 15
# [15, 17, 11]
# 23
# [23, 1, 22]
# 11
# [11, 21, 22]
# 2
# [2, 20, 18]
# 18
# [18, 21, 11]
# 1
# [1, 8, 5]
# 5
# [5, 21, 15]
# 19
# [19, 16, 23]
# 13
# [13, 4, 17]
# 14
# [14, 11, 16]
# 8
# [8, 10, 5]
# 18
# [18, 16, 4]
# 6
# [6, 15, 10]
# 22
# [22, 16, 9]
# 3
# [3, 14, 6]
# 13
# [13, 17, 3]
# 5
# [5, 3, 8]
# 8
# [8, 0, 16]
# 6
# [6, 14, 12]
# 10
# [10, 17, 8]
# 5
# [5, 3, 9]
# 11
# [11, 10, 4]
# 13
# [13, 11, 22]
# 21
# [21, 12, 5]
# 11
# [11, 0, 14]
# 14
# [14, 7, 9]
# 22
# [22, 4, 7]
# 7
# [7, 3, 19]
# 19
# [19, 2, 5]
# 2
# [2, 8, 5]
# 11
# [11, 18, 1]
# 3
# [3, 16, 20]
# 16
# [16, 6, 7]
# 1
# [1, 6, 3]
# 12
# [12, 20, 8]
# 7
# [7, 19, 18]
# 10
# [10, 21, 9]
# 17
# [17, 7, 6]
# 10
# [10, 11, 20]
# 17
# [17, 23, 8]
# 15
# [15, 6, 1]
# 18
# [18, 8, 7]
# 9
# [9, 4, 11]
# 6
# [6, 15, 7]
# 22
# [22, 15, 5]
# 23
# [23, 21, 2]
# 23
# [23, 1, 8]
# 13
# [13, 12, 10]
# 13
# [13, 20, 2]
# 12
# [12, 11, 13]
# 0
# [0, 5, 15]
# 11
# [11, 22, 12]
# 9
# [9, 0, 4]
# 13
# [13, 8, 21]
# 20
# [20, 19, 17]
# 21
# [21, 5, 1]
# 12
# [12, 1, 15]
# 1
# [1, 22, 4]
# 12
# [12, 4, 1]
# 23
# [23, 10, 19]
# 0
# [0, 20, 2]
# 22
# [22, 4, 7]
# 1
# [1, 17, 0]
# 2
# [2, 4, 19]
# 23
# [23, 5, 12]
# 4
# [4, 15, 19]
# 19
# [19, 1, 0]
# 8
# [8, 23, 17]
# 6
# [6, 16, 1]
# 21
# [21, 22, 12]
# 5
# [5, 22, 12]
# 0
# [0, 16, 6]
# 19
# [19, 10, 8]
# 3
# [3, 20, 6]
# 5
# [5, 21, 15]
# 8
# [8, 2, 21]
# 20
# [20, 18, 8]
# 7
# [7, 13, 2]
# 23
# [23, 5, 20]
# 11
# [11, 22, 18]
# 15
# [15, 6, 14]
# 20
# [20, 3, 9]
# 11
# [11, 12, 22]
# 1
# [1, 0, 3]
# 17
# [17, 23, 20]
# 4
# [4, 17, 6]
# 17
# [17, 6, 1]
# 18
# [18, 11, 22]
# 9
# [9, 16, 23]
# 17
# [17, 9, 22]
# 3
# [3, 12, 13]
# 3
# [3, 4, 19]
# 19
# [19, 0, 2]
# 16
# [16, 19, 4]
# 4
# [4, 5, 12]
# 12
# [12, 1, 7]
# 15
# [15, 5, 17]
# 10
# [10, 23, 1]
# 3
# [3, 9, 17]
# 2
# [2, 18, 20]
# 0
# [0, 13, 19]
# 15
# [15, 12, 21]
# 17
# [17, 19, 9]
# 10
# [10, 17, 1]
# 5
# [5, 20, 9]
# 17
# [17, 3, 8]
# 21
# [21, 16, 4]
# 20
# [20, 2, 19]
# 16
# [16, 12, 0]
# 19
# [19, 11, 9]
# 14
# [14, 0, 9]
# 9
# [9, 8, 7]
# 5
# [5, 22, 20]
# 20
# [20, 4, 22]
# 15
# [15, 13, 23]
# 9
# [9, 0, 4]
# 11
# [11, 10, 7]
# 15
# [15, 10, 0]
# 8
# [8, 16, 21]
# 17
# [17, 6, 22]
# 19
# [19, 17, 3]
# 7
# [7, 10, 5]
# 7
# [7, 3, 15]
# 10
# [10, 8, 4]
# 7
# [7, 23, 0]
# 10
# [10, 9, 17]
# 15
# [15, 16, 7]
# 11
# [11, 22, 12]
# 21
# [21, 23, 19]
# 15
# [15, 10, 2]
# 23
# [23, 7, 18]
# 18
# [18, 20, 14]
# 1
# [1, 10, 0]
# 18
# [18, 17, 22]
# 18
# [18, 12, 20]
# 23
# [23, 4, 16]
# 10
# [10, 1, 9]
# 5
# [5, 23, 9]
# 9
# [9, 20, 16]
# 14
# [14, 3, 4]
# 12
# [12, 18, 3]
# 22
# [22, 7, 15]
# 13
# [13, 1, 22]
# 12
# [12, 10, 18]
# 4
# [4, 22, 8]
# 1
# [1, 5, 9]
# 9
# [9, 2, 18]
# 6
# [6, 18, 8]
# 7
# [7, 14, 12]
# 9
# [9, 1, 14]
# 6
# [6, 10, 17]
# 19
# [19, 20, 21]
# 13
# [13, 8, 20]
# 10
# [10, 16, 1]
# 20
# [20, 15, 19]
# 3
# [3, 21, 14]
# 16
# [16, 14, 5]
# 2
# [2, 7, 22]
# 1
# [1, 5, 21]
# 9
# [9, 12, 14]
# 8
# [8, 12, 23]
# 9
# [9, 18, 23]
# 10
# [10, 12, 16]
# 23
# [23, 7, 11]
# 7
# [7, 20, 14]
# 15
# [15, 17, 18]
# 6
# [6, 1, 17]
# 6
# [6, 13, 19]
# 8
# [8, 7, 4]
# 2
# [2, 12, 20]
# 1
# [1, 14, 23]
# 1
# [1, 18, 6]
# 2
# [2, 9, 18]
# 21
# [21, 11, 6]
# 15
# [15, 21, 23]
# 4
# [4, 11, 0]
# 3
# [3, 17, 2]
# 9
# [9, 15, 0]
# 10
# [10, 5, 2]
# 14
# [14, 9, 16]
# 16
# [16, 10, 3]
# 4
# [4, 18, 11]
# 12
# [12, 13, 18]
# 10
# [10, 4, 15]
# 8
# [8, 15, 20]
# 12
# [12, 2, 9]
# 0
# [0, 4, 12]
# 13
# [13, 2, 20]
# 20
# [20, 2, 14]
# 20
# [20, 23, 13]
# 1
# [1, 21, 18]
# 10
# [10, 23, 6]
# 23
# [23, 13, 19]
# 16
# [16, 10, 22]
# 11
# [11, 14, 20]
# 0
# [0, 12, 13]
# 5
# [5, 3, 23]
# 8
# [8, 13, 16]
# 13
# [13, 19, 22]
# 17
# [17, 21, 19]
# 21
# [21, 12, 1]
# 13
# [13, 16, 0]
# 18
# [18, 14, 15]
# 17
# [17, 4, 1]
# 16
# [16, 18, 15]
# 15
# [15, 11, 23]
# 1
# [1, 6, 7]
# 11
# [11, 23, 10]
# 18
# [18, 21, 6]
# 3
# [3, 20, 0]
# 18
# [18, 23, 19]
# 5
# [5, 13, 16]
# 7
# [7, 10, 14]
# 23
# [23, 0, 15]
# 0
# [0, 4, 1]
# 11
# [11, 8, 16]
# 1
# [1, 10, 7]
# 13
# [13, 21, 4]
# 2
# [2, 7, 13]
# 6
# [6, 14, 17]
# 3
# [3, 11, 21]
# 14
# [14, 3, 15]
# 11
# [11, 8, 9]
# 2
# [2, 14, 10]
# 21
# [21, 3, 11]
# 12
# [12, 11, 21]
# 16
# [16, 21, 6]
# 21
# [21, 18, 20]
# 14
# [14, 23, 2]
# 10
# [10, 0, 1]
# 11
# [11, 3, 4]
# 22
# [22, 3, 20]
# 10
# [10, 9, 7]
# 21
# [21, 13, 23]
# 9
# [9, 23, 22]
# 17
# [17, 5, 1]
# 16
# [16, 12, 11]
# 14
# [14, 13, 3]
# 18
# [18, 14, 15]
# 15
# [15, 18, 9]
# 18
# [18, 21, 9]
# 4
# [4, 8, 23]
# 8
# [8, 14, 17]
# 7
# [7, 13, 21]
# 8
# [8, 9, 0]
# 1
# [1, 22, 3]
# 4
# [4, 17, 15]
# 14
# [14, 16, 7]
# 7
# [7, 3, 20]
# 2
# [2, 16, 23]
# 9
# [9, 4, 15]
# 19
# [19, 6, 3]
# 2
# [2, 23, 8]
# 1
# [1, 11, 0]
# 18
# [18, 12, 21]
# 18
# [18, 12, 17]
# 10
# [10, 5, 8]
# 18
# [18, 11, 13]
# 2
# [2, 15, 18]
# 10
# [10, 5, 6]
# 3
# [3, 1, 11]
# 18
# [18, 8, 6]
# 4
# [4, 23, 0]
# 19
# [19, 6, 14]
# 14
# [14, 10, 11]
# 23
# [23, 17, 21]
# 18
# [18, 12, 10]
# 0
# [0, 18, 17]
# 17
# [17, 11, 6]
# 23
# [23, 1, 15]
# 21
# [21, 2, 14]
# 9
# [9, 20, 4]
# 4
# [4, 8, 6]
# 23
# [23, 2, 12]
# 15
# [15, 21, 18]
# 10
# [10, 2, 9]
# 22
# [22, 21, 17]
# 18
# [18, 15, 5]
# 8
# [8, 6, 19]
# 5
# [5, 9, 15]
# 1
# [1, 4, 22]
# 19
# [19, 13, 16]
# 17
# [17, 3, 6]
# 16
# [16, 21, 8]
# 5
# [5, 18, 17]
# 17
# [17, 16, 8]
# 8
# [8, 11, 12]
# 18
# [18, 2, 3]
# 15
# [15, 0, 17]
# 3
# [3, 12, 2]
# 13
# [13, 6, 9]
# 3
# [3, 16, 1]
# 19
# [19, 13, 17]
# 14
# [14, 19, 21]
# 13
# [13, 22, 8]
# 23
# [23, 2, 11]
# 16
# [16, 9, 14]
# 21
# [21, 20, 3]
# 5
# [5, 11, 13]
# 1
# [1, 13, 7]
# 4
# [4, 1, 6]
# 13
# [13, 5, 6]
# 2
# [2, 19, 14]
# 0
# [0, 8, 5]
# 4
# [4, 16, 2]
# 2
# [2, 7, 15]
# 15
# [15, 7, 1]
# 15
# [15, 6, 21]
# 17
# [17, 22, 14]
# 4
# [4, 6, 7]
# 16
# [16, 11, 1]
# 23
# [23, 14, 20]
# 2
# [2, 12, 16]
# 5
# [5, 20, 0]
# 14
# [14, 4, 9]
# 0
# [0, 22, 21]
# 6
# [6, 9, 4]
# 5
# [5, 17, 23]
# 4
# [4, 10, 19]
# 0
# [0, 9, 14]
# 11
# [11, 4, 0]
# 3
# [3, 7, 13]
# 3
# [3, 2, 5]
# 13
# [13, 22, 0]
# 22
# [22, 5, 12]
# 5
# [5, 16, 8]
# 23
# [23, 18, 5]
# 11
# [11, 18, 4]
# 15
# [15, 5, 9]
# 3
# [3, 13, 16]
# 1
# [1, 17, 8]
# 6
# [6, 5, 16]
# 10
# [10, 6, 11]
# 11
# [11, 15, 8]
# 7
# [7, 23, 18]
# 3
# [3, 11, 16]
# 12
# [12, 1, 20]
# 18
# [18, 22, 13]
# 16
# [16, 1, 2]
# 20
# [20, 12, 19]
# 11
# [11, 13, 8]
# 13
# [13, 0, 20]
# 12
# [12, 15, 3]
# 5
# [5, 1, 13]
# 10
# [10, 4, 19]
# 6
# [6, 0, 11]
# 14
# [14, 9, 22]
# 3
# [3, 9, 16]
# 16
# [16, 14, 20]
# 1
# [1, 4, 20]
# 0
# [0, 4, 15]
# 0
# [0, 5, 19]
# 15
# [15, 9, 13]
# 21
# [21, 4, 23]
# 10
# [10, 13, 18]
# 22
# [22, 11, 17]
# 8
# [8, 20, 15]
# 13
# [13, 11, 20]
# 17
# [17, 11, 4]
# 18
# [18, 3, 20]
# 17
# [17, 12, 22]
# 11
# [11, 9, 1]
# 17
# [17, 16, 10]
# 7
# [7, 1, 10]
# 6
# [6, 12, 0]
# 20
# [20, 12, 6]
# 16
# [16, 10, 19]
# 15
# [15, 13, 23]
# 20
# [20, 21, 11]
# 7
# [7, 19, 16]
# 13
# [13, 18, 6]
# 18
# [18, 12, 19]
# 14
# [14, 20, 9]
# 5
# [5, 15, 8]
# 12
# [12, 21, 13]
# 2
# [2, 4, 17]
# 15
# [15, 3, 10]
# 6
# [6, 16, 23]
# 12
# [12, 19, 17]
# 15
# [15, 13, 21]
# 1
# [1, 21, 17]
# 17
# [17, 9, 18]
# 19
# [19, 22, 5]
# 19
# [19, 16, 23]
# 17
# [17, 19, 7]
# 20
# [20, 21, 22]
# 12
# [12, 7, 6]
# 14
# [14, 18, 21]
# 6
# [6, 4, 2]
# 14
# [14, 5, 6]
# 1
# [1, 8, 0]
# 23
# [23, 21, 18]
# 2
# [2, 15, 12]
# 11
# [11, 3, 23]
# 0
# [0, 7, 13]
# 4
# [4, 18, 19]
# 4
# [4, 23, 11]
# 19
# [19, 4, 22]
# 5
# [5, 13, 7]
# 13
# [13, 3, 6]
# 21
# [21, 1, 8]
# 4
# [4, 14, 19]
# 21
# [21, 19, 22]
# 5
# [5, 14, 8]
# 5
# [5, 7, 23]
# 12
# [12, 22, 2]
# 22
# [22, 1, 18]
# 22
# [22, 6, 7]
# 9
# [9, 21, 14]
# 2
# [2, 19, 15]
# 14
# [14, 16, 6]
# 10
# [10, 19, 17]
# 15
# [15, 12, 22]
# 5
# [5, 7, 21]
# 4
# [4, 14, 11]
# 14
# [14, 22, 12]
# 22
# [22, 1, 17]
# 19
# [19, 12, 6]
# 18
# [18, 16, 6]
# 17
# [17, 23, 8]
# 12
# [12, 1, 7]
# 17
# [17, 8, 21]
# 13
# [13, 7, 3]
# 23
# [23, 17, 14]
# 15
# [15, 22, 19]
# 1
# [1, 13, 18]
# 4
# [4, 1, 10]
# 20
# [20, 15, 21]
# 4
# [4, 10, 20]
# 2
# [2, 21, 14]
# 21
# [21, 19, 15]
# 21
# [21, 13, 19]
# 10
# [10, 5, 11]
# 18
# [18, 0, 20]
# 14
# [14, 2, 10]
# 22
# [22, 4, 17]
# 11
# [11, 12, 14]
# 22
# [22, 16, 12]
# 7
# [7, 20, 19]
# 17
# [17, 5, 13]
# 9
# [9, 19, 23]
# 15
# [15, 11, 4]
# 6
# [6, 9, 14]
# 14
# [14, 4, 21]
# 8
# [8, 22, 20]
# 21
# [21, 7, 9]
# 4
# [4, 3, 2]
# 7
# [7, 2, 16]
# 11
# [11, 12, 4]
# 21
# [21, 1, 20]
# 12
# [12, 13, 18]
# 6
# [6, 15, 21]
# 8
# [8, 0, 7]
# 18
# [18, 10, 13]
# 2
# [2, 6, 0]
# 20
# [20, 13, 15]
# 9
# [9, 6, 14]
# 13
# [13, 18, 17]
# 6
# [6, 9, 10]
# 19
# [19, 0, 5]
# 23
# [23, 12, 2]
# 20
# [20, 23, 6]
# 2
# [2, 5, 4]
# 12
# [12, 21, 18]
# 2
# [2, 17, 1]
# 7
# [7, 23, 5]
# 17
# [17, 0, 14]
# 19
# [19, 0, 20]
# 2
# [2, 20, 16]
# 6
# [6, 15, 17]
# 11
# [11, 7, 13]
# 7
# [7, 8, 18]
# 5
# [5, 20, 22]
# 4
# [4, 0, 3]
# 8
# [8, 20, 12]
# 14
# [14, 5, 16]
# 7
# [7, 6, 17]
# 20
# [20, 0, 6]
# 4
# [4, 22, 6]
# 3
# [3, 15, 11]
# 22
# [22, 21, 17]
# 8
# [8, 13, 15]
# 5
# [5, 12, 20]
# 15
# [15, 14, 4]
# 9
# [9, 4, 12]
# 2
# [2, 4, 22]
# 13
# [13, 16, 6]
# 23
# [23, 0, 21]
# 2
# [2, 14, 0]
# 8
# [8, 2, 19]
# 14
# [14, 6, 2]
# 16
# [16, 17, 4]
# 13
# [13, 14, 17]
# 20
# [20, 8, 15]
# 3
# [3, 12, 15]
# 1
# [1, 18, 9]
# 15
# [15, 20, 6]
# 12
# [12, 2, 5]
# 20
# [20, 19, 12]
# 12
# [12, 14, 7]
# 2
# [2, 12, 3]
# 7
# [7, 12, 0]
# 21
# [21, 0, 6]
# 23
# [23, 0, 17]
# 10
# [10, 0, 5]
# 8
# [8, 19, 6]
# 21
# [21, 22, 15]
# 0
# [0, 20, 23]
# 19
# [19, 0, 10]
# 9
# [9, 21, 13]
# 15
# [15, 4, 0]
# 19
# [19, 4, 18]
# 0
# [0, 4, 5]
# 12
# [12, 11, 15]
# 2
# [2, 4, 23]
# 7
# [7, 11, 14]
# 23
# [23, 22, 15]
# 10
# [10, 6, 4]
# 0
# [0, 13, 6]
# 13
# [13, 18, 11]
# 12
# [12, 4, 17]
# 5
# [5, 0, 12]
# 9
# [9, 7, 1]
# 6
# [6, 19, 1]
# 17
# [17, 11, 7]
# 5
# [5, 20, 22]
# 10
# [10, 17, 0]
# 10
# [10, 12, 1]
# 3
# [3, 19, 6]
# 2
# [2, 20, 9]
# 6
# [6, 1, 7]
# 2
# [2, 6, 10]
# 1
# [1, 8, 4]
# 18
# [18, 7, 23]
# 0
# [0, 3, 7]
# 4
# [4, 21, 9]
# 8
# [8, 22, 2]
# 17
# [17, 19, 23]
# 16
# [16, 23, 0]
# 3
# [3, 14, 12]
# 13
# [13, 9, 21]
# 22
# [22, 17, 14]
# 2
# [2, 10, 17]
# 21
# [21, 6, 15]
# 3
# [3, 23, 20]
# 20
# [20, 4, 18]
# 14
# [14, 8, 15]
# 17
# [17, 3, 14]
# 14
# [14, 12, 0]
# 8
# [8, 18, 17]
# 1
# [1, 0, 16]
# 19
# [19, 16, 23]
# 23
# [23, 11, 17]
# 6
# [6, 5, 22]
# 16
# [16, 3, 20]
# 19
# [19, 9, 17]
# 23
# [23, 0, 11]
# 14
# [14, 0, 4]
# 15
# [15, 7, 1]
# 5
# [5, 14, 9]
# 18
# [18, 8, 7]
# 7
# [7, 1, 19]
# 0
# [0, 8, 15]
# 12
# [12, 3, 6]
# 20
# [20, 4, 9]
# 13
# [13, 21, 17]
# 12
# [12, 13, 0]
# 9
# [9, 2, 7]
# 4
# [4, 5, 0]
# 11
# [11, 2, 17]
# 18
# [18, 12, 19]
# 7
# [7, 8, 23]
# 12
# [12, 8, 9]
# 20
# [20, 8, 22]
# 22
# [22, 13, 23]
# 21
# [21, 19, 20]
# 15
# [15, 7, 2]
# 18
# [18, 10, 20]
# 1
# [1, 12, 11]
# 4
# [4, 23, 0]
# 19
# [19, 18, 15]
# 17
# [17, 23, 16]
# 2
# [2, 14, 12]
# 16
# [16, 23, 20]
# 3
# [3, 23, 14]
# 21
# [21, 19, 2]
# 16
# [16, 13, 3]
# 6
# [6, 23, 15]
# 14
# [14, 11, 2]
# 8
# [8, 23, 19]
# 6
# [6, 4, 15]
# 0
# [0, 6, 7]
# 6
# [6, 13, 10]
# 9
# [9, 0, 2]
# 3
# [3, 6, 12]
# 1
# [1, 16, 22]
# 8
# [8, 19, 12]
# 0
# [0, 17, 19]
# 21
# [21, 0, 1]
# 23
# [23, 8, 5]
# 7
# [7, 21, 3]
# 10
# [10, 2, 6]
# 3
# [3, 0, 22]
# 3
# [3, 19, 0]
# 3
# [3, 11, 2]
# 9
# [9, 18, 23]
# 1
# [1, 22, 2]
# 2
# [2, 17, 11]
# 16
# [16, 21, 8]
# 11
# [11, 9, 5]
# 7
# [7, 11, 15]
# 0
# [0, 16, 2]
# 17
# [17, 12, 18]
# 21
# [21, 10, 12]
# 23
# [23, 21, 0]
# 14
# [14, 18, 7]
# 11
# [11, 0, 3]
# 23
# [23, 3, 21]
# 6
# [6, 16, 4]
# 6
# [6, 19, 14]
# 1
# [1, 8, 16]
# 20
# [20, 8, 18]
# 13
# [13, 15, 23]
# 19
# [19, 5, 11]
# 22
# [22, 23, 15]
# 14
# [14, 21, 18]
# 19
# [19, 11, 5]
# 21
# [21, 19, 20]
# 13
# [13, 17, 7]
# 12
# [12, 7, 16]
# 4
# [4, 9, 0]
# 6
# [6, 3, 12]
# 1
# [1, 17, 19]
# 2
# [2, 14, 20]
# 12
# [12, 18, 0]
# 4
# [4, 21, 22]
# 17
# [17, 0, 2]
# 7
# [7, 8, 0]
# 17
# [17, 16, 4]
# 9
# [9, 5, 16]
# 20
# [20, 17, 16]
# 22
# [22, 4, 14]
# 21
# [21, 14, 20]
# 12
# [12, 3, 14]
# 8
# [8, 9, 17]
# 3
# [3, 18, 7]
# 3
# [3, 20, 11]
# 15
# [15, 3, 5]
# 19
# [19, 17, 14]
# 23
# [23, 20, 16]
# 20
# [20, 8, 2]
# 6
# [6, 7, 18]
# 4
# [4, 22, 11]
# 20
# [20, 23, 14]
# 7
# [7, 12, 22]
# 21
# [21, 7, 9]
# 23
# [23, 5, 1]
# 14
# [14, 18, 5]
# 1
# [1, 10, 19]
# 8
# [8, 14, 2]
# 11
# [11, 9, 17]
# 17
# [17, 15, 6]
# 7
# [7, 10, 18]
# 1
# [1, 2, 22]
# 12
# [12, 18, 13]
# 20
# [20, 23, 15]
# 17
# [17, 15, 20]
# 7
# [7, 14, 10]
# 22
# [22, 21, 5]
# 13
# [13, 5, 20]
# 15
# [15, 0, 13]
# 14
# [14, 12, 3]
# 6
# [6, 15, 13]
# 6
# [6, 3, 15]
# 5
# [5, 23, 12]
# 17
# [17, 5, 0]
# 10
# [10, 17, 16]
# 9
# [9, 1, 13]
# 22
# [22, 12, 21]
# 17
# [17, 15, 20]
# 12
# [12, 22, 15]
# 16
# [16, 1, 22]
# 1
# [1, 4, 15]
# 17
# [17, 10, 20]
# 3
# [3, 13, 16]
# 6
# [6, 19, 21]
# 0
# [0, 20, 10]
# 19
# [19, 9, 6]
# 23
# [23, 20, 4]
# 8
# [8, 19, 9]
# 0
# [0, 19, 6]
# 4
# [4, 21, 13]
# 12
# [12, 7, 14]
# 0
# [0, 4, 19]
# 3
# [3, 11, 20]
# 9
# [9, 23, 21]
# 12
# [12, 3, 0]
# 4
# [4, 12, 0]
# 3
# [3, 11, 1]
# 9
# [9, 0, 8]
# 17
# [17, 13, 1]
# 12
# [12, 9, 7]
# 9
# [9, 15, 5]
# 2
# [2, 0, 11]
# 13
# [13, 17, 16]
# 11
# [11, 18, 9]
# 22
# [22, 10, 18]
# 19
# [19, 6, 2]
# 21
# [21, 15, 1]
# 20
# [20, 12, 9]
# 23
# [23, 15, 20]
# 22
# [22, 19, 8]
# 16
# [16, 22, 7]
# 3
# [3, 8, 6]
# 6
# [6, 21, 3]
# 0
# [0, 18, 2]
# 0
# [0, 13, 7]
# 15
# [15, 23, 3]
# 6
# [6, 7, 14]
# 23
# [23, 19, 7]
# 3
# [3, 19, 4]
# 6
# [6, 2, 10]
# 1
# [1, 13, 9]
# 18
# [18, 2, 3]
# 23
# [23, 16, 20]
# 20
# [20, 15, 21]
# 18
# [18, 19, 15]
# 6
# [6, 19, 10]
# 15
# [15, 4, 23]
# 15
# [15, 1, 6]
# 0
# [0, 8, 21]
# 18
# [18, 12, 6]
# 17
# [17, 16, 8]
# 7
# [7, 19, 16]
# 1
# [1, 6, 23]
# 7
# [7, 18, 19]
# 1
# [1, 3, 23]
# 18
# [18, 3, 4]
# 12
# [12, 1, 15]
# 19
# [19, 17, 16]
# 9
# [9, 21, 6]
# 1
# [1, 12, 19]
# 22
# [22, 7, 0]
# 23
# [23, 14, 10]
# 21
# [21, 3, 18]
# 13
# [13, 20, 9]
# 8
# [8, 13, 14]
# 3
# [3, 6, 5]
# 11
# [11, 6, 7]
# 15
# [15, 18, 6]
# 8
# [8, 19, 4]
# 8
# [8, 21, 14]
# 4
# [4, 5, 15]
# 21
# [21, 10, 0]
# 14
# [14, 6, 4]
# 20
# [20, 5, 16]
# 0
# [0, 2, 15]
# 8
# [8, 4, 11]
# 6
# [6, 2, 13]
# 5
# [5, 2, 11]
# 14
# [14, 1, 3]
# 15
# [15, 2, 20]
# 15
# [15, 23, 16]
# 17
# [17, 6, 2]
# 22
# [22, 5, 12]
# 6
# [6, 14, 1]
# 18
# [18, 2, 11]
# 20
# [20, 12, 5]
# 2
# [2, 9, 17]
# 10
# [10, 22, 11]
# 15
# [15, 6, 2]
# 22
# [22, 9, 5]
# 12
# [12, 9, 22]
# 7
# [7, 21, 19]
# 11
# [11, 13, 2]
# 19
# [19, 21, 5]
# 23
# [23, 7, 5]
# 17
# [17, 19, 21]
# 18
# [18, 6, 11]
# 15
# [15, 6, 7]
# 14
# [14, 9, 5]
# 10
# [10, 14, 18]
# 1
# [1, 4, 2]
# 18
# [18, 5, 2]
# 14
# [14, 4, 1]
# 1
# [1, 14, 22]
# 3
# [3, 14, 9]
# 5
# [5, 18, 15]
# 6
# [6, 8, 17]
# 19
# [19, 3, 17]
# 22
# [22, 19, 11]
# 18
# [18, 13, 5]
# 5
# [5, 19, 1]
# 19
# [19, 17, 11]
# 12
# [12, 10, 9]
# 6
# [6, 4, 3]
# 13
# [13, 4, 0]
# 15
# [15, 18, 4]
# 8
# [8, 16, 10]
# 17
# [17, 13, 3]
# 10
# [10, 17, 1]
# 7
# [7, 5, 23]
# 14
# [14, 11, 9]
# 23
# [23, 1, 12]
# 2
# [2, 4, 15]
# 18
# [18, 15, 13]
# 13
# [13, 17, 12]
# 21
# [21, 4, 11]
# 17
# [17, 22, 1]
# 4
# [4, 14, 8]
# 0
# [0, 1, 23]
# 19
# [19, 10, 0]
# 17
# [17, 13, 1]
# 20
# [20, 21, 12]
# 18
# [18, 10, 22]
# 10
# [10, 8, 20]
# 18
# [18, 7, 2]
# 18
# [18, 3, 11]
# 14
# [14, 3, 13]
# 11
# [11, 12, 20]
# 12
# [12, 3, 10]
# 14
# [14, 23, 7]
# 5
# [5, 9, 13]
# 9
# [9, 21, 18]
# 9
# [9, 11, 4]
# 11
# [11, 23, 3]
# 8
# [8, 11, 18]
# 23
# [23, 4, 16]
# 17
# [17, 19, 12]
# 15
# [15, 12, 18]
# 7
# [7, 16, 13]
# 16
# [16, 21, 6]
# 12
# [12, 3, 20]
# 20
# [20, 1, 17]
# 1
# [1, 18, 20]
# 7
# [7, 12, 17]
# 11
# [11, 10, 19]
# 7
# [7, 10, 8]
# 17
# [17, 11, 9]
# 9
# [9, 0, 20]
# 13
# [13, 16, 11]
# 0
# [0, 12, 10]
# 18
# [18, 20, 5]
# 20
# [20, 4, 7]
# 18
# [18, 20, 6]
# 17
# [17, 11, 8]
# 14
# [14, 5, 16]
# 7
# [7, 18, 14]
# 16
# [16, 0, 15]
# 4
# [4, 15, 0]
# 19
# [19, 14, 22]
# 7
# [7, 21, 11]
# 12
# [12, 21, 10]
# 14
# [14, 17, 4]
# 11
# [11, 16, 18]
# 15
# [15, 19, 8]
# 7
# [7, 6, 21]
# 20
# [20, 3, 23]
# 20
# [20, 19, 12]
# 4
# [4, 9, 23]
# 15
# [15, 2, 22]
# 21
# [21, 15, 3]
# 0
# [0, 15, 13]
# 13
# [13, 14, 1]
# 16
# [16, 14, 18]
# 3
# [3, 14, 21]
# 9
# [9, 19, 0]
# 18
# [18, 1, 6]
# 0
# [0, 6, 8]
# 5
# [5, 11, 20]
# 4
# [4, 7, 14]
# 18
# [18, 16, 12]
# 10
# [10, 1, 20]
# 22
# [22, 21, 20]
# 13
# [13, 22, 5]
# 21
# [21, 2, 16]
# 17
# [17, 11, 8]
# 13
# [13, 9, 1]
# 23
# [23, 0, 18]
# 21
# [21, 13, 23]
# 21
# [21, 2, 15]
# 7
# [7, 20, 14]
# 5
# [5, 11, 0]
# 22
# [22, 5, 16]
# 17
# [17, 4, 7]
# 17
# [17, 19, 9]
# 10
# [10, 20, 6]
# 0
# [0, 4, 8]
# 0
# [0, 15, 18]
# 23
# [23, 3, 1]
# 8
# [8, 5, 23]
# 18
# [18, 23, 3]
# 23
# [23, 6, 17]
# 23
# [23, 22, 10]
# 18
# [18, 21, 17]
# 9
# [9, 0, 10]
# 13
# [13, 16, 3]
# 6
# [6, 16, 11]
# 22
# [22, 7, 4]
# 3
# [3, 22, 11]
# 4
# [4, 16, 22]
# 9
# [9, 14, 3]
# 18
# [18, 15, 6]
# 8
# [8, 10, 6]
# 0
# [0, 9, 20]
# 21
# [21, 3, 22]
# 6
# [6, 12, 18]
# 9
# [9, 14, 18]
# 5
# [5, 6, 22]
# 14
# [14, 10, 4]
# 23
# [23, 3, 17]
# 4
# [4, 13, 22]
# 19
# [19, 1, 14]
# 20
# [20, 17, 11]
# 12
# [12, 1, 2]
# 19
# [19, 6, 7]
# 22
# [22, 19, 11]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
#       1 while(True):
#       2     #try:
# ----> 3     Gr = nx.random_regular_graph(3,24)
#       4     if nx.is_connected(Gr):
#       5         c = get_b_chromatic_colouring(Gr)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 4:4, in argmap_random_regular_graph_1(d, n, seed)
#       2 from os.path import splitext
#       3 from contextlib import contextmanager
# ----> 4 from pathlib import Path
#       6 import networkx as nx
#       7 from networkx.utils import create_random_state, create_py_random_state
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/.tests/lib/python3.10/site-packages/networkx/generators/random_graphs.py:532, in random_regular_graph(d, n, seed)
#     529 if (n * d) % 2 != 0:
#     530     raise nx.NetworkXError("n * d must be even")
# --> 532 if not 0 <= d < n:
#     533     raise nx.NetworkXError("the 0 <= d < n inequality must be satisfied")
#     535 if d == 0:
#
# KeyboardInterrupt:

# %%
def bfs_dist_4_2(G, u):
    """Find a vertex path P starting a u and ending at a vertex v such that
      dist(u,v)=4 providing that diam(G) >= 4
    Parameters -> G: graph, u: vertex
    Returns -> P: a path from u to v such that ||P|| = 4 (number of edges)
    """
    dist = {v:-1 for v in G.nodes()}
    #For each i = 1,2,3,4 it stores a pair key:value where key is the vertex at distance i from u 
    # and value is its antecesor in the BFS tree
    distances = {}
    dist[u] = 0
    Q = [u]
    P = []
    while(len(Q) > 0):
        w = Q.pop(0)
        for v in G.adj[w]:
            if(dist[v] == -1):
                dist[v] = dist[w] + 1
                if dist[v] not in distances.keys(): distances[dist[v]] = {v:w}
                else: distances[dist[v]][v] = w
                Q.append(v)
    #w = next(iter(distances[4]))
    #while(len(P) < 4):
    #    P.insert(0, w)
    #    w = distances[5-len(P)][w]
    #P.insert(0,u)
    return P, distances

# %%
bfs_dist_4_2(Gr, 8)
# Out:
# ([],
#  {1: {9: 8, 5: 8, 19: 8},
#   2: {10: 9, 6: 9, 18: 19, 7: 19},
#   3: {23: 10, 20: 18}})

# %%
layout = nx.circular_layout(Gr)
nx.draw(Gr, pos=layout, with_labels=True)

# %%
T = nx.bfs_tree(Gr, 8)
nx.draw(T, with_labels=True)

# %%
u = 21
P = bfs_dist_4(Gr, u)
c, Q = find_3_b_chromatic_vertices(Gr, P)
Gcolours = get_colors_to_use(c)
layout = nx.circular_layout(Gr)
print({u:c[u] for u in P})
nx.draw(Gr, pos=layout, with_labels=True, node_color=Gcolours)
# Out:
# {21: 1, 0: 3, 8: 2, 4: 1, 22: 3}

# %%
c[6]

# %%
for u in Q:
    if c[u] == 4:
        print(u)
# Out:
# 1
# 12
# 6

# %%
Vp = [P[0], P[2], P[4]]#set of b-chromatic vertices
visited = {x:False for x in Gr.nodes()}
success = False
while not success:
    x = Q.pop()
    c, success = find_fourth_b_chromatic_vertex(Gr, x, c, visited, Vp, success, 4)
print(Vp)
assert are_b_chromatic(Gr, c, Vp)
assert {c[w] for w in Vp} == {d for d in c.values() if d is not None}
Gcolours = get_colors_to_use(c)
nx.draw(Gr, pos=layout, with_labels=True, node_color=Gcolours)
# Out:
# [21, 8, 22, 5]

# %%
for u in Vp:
    print(u, c[u])
    for v in Gr[u]:
        print("\t{} {}".format(v, c[v]))
# Out:
# 11 1
# 	9 2
# 	17 3
# 	18 4
# 13 2
# 	14 4
# 	17 3
# 	4 4
# 16 3
# 	12 2
# 	5 1
# 	4 4

# %%
c.values()
# Out:
# dict_values([4, 2, 4, None, None, None, None, 4, None, 1, 3, None, None, None, None, 2, 3, 1, None, None, 2, None, None, None])

# %%
C = {a for a in c.values() if a is not None}
d = 4
f = find_b_chromatic_assignment2(Gr, C, x, c)

# %%
are_b_chromatic(Gr, f, {x})
# Out:
# True

# %%
print(x, f[x])
for y in Gr[x]:
    print(y, f[y])
# Out:
# 11 4
# 0 3
# 1 1
# 19 2

# %%
C = {a for a in c.values() if a is not None}
d = 4
can_u_become_b_chromatic(Gr, C, 18, d, c)
# Out:
# True

# %%
c
# Out:
# {6: 4,
#  21: 3,
#  18: 4,
#  20: 1,
#  3: None,
#  10: None,
#  22: 2,
#  23: 4,
#  19: 1,
#  5: 1,
#  16: 3,
#  0: None,
#  8: None,
#  2: 4,
#  11: 2,
#  17: 2,
#  1: 3,
#  15: 1,
#  7: None,
#  4: None,
#  9: 2,
#  14: None,
#  13: None,
#  12: 1}

# %%
Bpos = nx.bipartite_layout(Hn, X)
nx.draw(Hn, pos=Bpos, with_labels=True)

# %%
def find_b_chromatic_assignment2(G, Cp, x, c):
    """Search through all possible combination of colours in Cp an assigment that makes x b-chromatic(provided that such assignment exists)
    G: graph,
    Cp: Colours that need to be assign to N(u)
    x: vertex to check, 
    c: colouring function, 
    success: True when a b-chromatic assigment has been found"""
    print(Cp)
    C = list(itertools.permutations(list(Cp)))
    #T = {y for y in G.adj[x]}
    for colours in C:
        cp = c.copy()
        for i, xi in enumerate(G.adj[x]):
            if cp[xi] is None:
                cp[xi] = colours[i]
        #print(is_proper(G, cp), are_b_chromatic(G, cp, {x}))
        #print(cp)
        if is_proper(G, cp) and are_b_chromatic(G, cp, {x}): return cp, True
    return c, False

# %% [markdown]
# ## Analizing growing of function $f(d)=\lfloor (3d+5)/2\rfloor$.

# %%
f = lambda d: (3*d+5)//2 
x = [i for i in range(4, 1000)]
y = [f(i) for i in x]
plt.plot(x,y)

# %% [markdown]
# ## Analyzing 4-regular graph with diam $(G)\leq 2$

# %%
diam_k = False
d = 3
while(not diam_k):
    n = 8
    Gp = nx.random_regular_graph(4, n)
    if nx.diameter(Gp) == d: diam_k = True
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/fabriciomendozagranada/Documents/PhD Work/Implementation/b_chromatic/b_chromatic_algorithms_cubic_graphs.ipynb Cell 35 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/fabriciomendozagranada/Documents/PhD%20Work/Implementation/b_chromatic/b_chromatic_algorithms_cubic_graphs.ipynb#X45sZmlsZQ%3D%3D?line=2'>3</a> while(not diam_k):
#       <a href='vscode-notebook-cell:/Users/fabriciomendozagranada/Documents/PhD%20Work/Implementation/b_chromatic/b_chromatic_algorithms_cubic_graphs.ipynb#X45sZmlsZQ%3D%3D?line=3'>4</a>     n = 8
# ----> <a href='vscode-notebook-cell:/Users/fabriciomendozagranada/Documents/PhD%20Work/Implementation/b_chromatic/b_chromatic_algorithms_cubic_graphs.ipynb#X45sZmlsZQ%3D%3D?line=4'>5</a>     Gp = nx.random_regular_graph(4, n)
#       <a href='vscode-notebook-cell:/Users/fabriciomendozagranada/Documents/PhD%20Work/Implementation/b_chromatic/b_chromatic_algorithms_cubic_graphs.ipynb#X45sZmlsZQ%3D%3D?line=5'>6</a>     if nx.diameter(Gp) == d: diam_k = True
#
# File <class 'networkx.utils.decorators.argmap'> compilation 4:4, in argmap_random_regular_graph_1(d, n, seed)
#       2 from os.path import splitext
#       3 from contextlib import contextmanager
# ----> 4 from pathlib import Path
#       6 import networkx as nx
#       7 from networkx.utils import create_random_state, create_py_random_state
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/.tests/lib/python3.10/site-packages/networkx/generators/random_graphs.py:591, in random_regular_graph(d, n, seed)
#     589 edges = _try_creation()
#     590 while edges is None:
# --> 591     edges = _try_creation()
#     593 G = nx.Graph()
#     594 G.add_edges_from(edges)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/.tests/lib/python3.10/site-packages/networkx/generators/random_graphs.py:565, in random_regular_graph.<locals>._try_creation()
#     563 while stubs:
#     564     potential_edges = defaultdict(lambda: 0)
# --> 565     seed.shuffle(stubs)
#     566     stubiter = iter(stubs)
#     567     for s1, s2 in zip(stubiter, stubiter):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/.tests/lib/python3.10/random.py:393, in Random.shuffle(self, x, random)
#     390     randbelow = self._randbelow
#     391     for i in reversed(range(1, len(x))):
#     392         # pick an element in x[:i+1] with which to exchange x[i]
# --> 393         j = randbelow(i + 1)
#     394         x[i], x[j] = x[j], x[i]
#     395 else:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/.tests/lib/python3.10/random.py:239, in Random._randbelow_with_getrandbits(self, n)
#     236             cls._randbelow = cls._randbelow_without_getrandbits
#     237             break
# --> 239 def _randbelow_with_getrandbits(self, n):
#     240     "Return a random int in the range [0,n).  Returns 0 if n==0."
#     242     if not n:
#
# KeyboardInterrupt:

# %%
Gp = nx.random_regular_graph(4,68)
print(nx.diameter(Gp))
nx.draw(Gp, with_labels=True)
# Out:
# 5

# %%
cp = find_b_chromatic_colouring_bruteforce(Gp, 4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/fabriciomendozagranada/Documents/PhD Work/Implementation/b_chromatic/b_chromatic_algorithms_cubic_graphs.ipynb Cell 36 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/fabriciomendozagranada/Documents/PhD%20Work/Implementation/b_chromatic/b_chromatic_algorithms_cubic_graphs.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> cp = find_b_chromatic_colouring_bruteforce(Gp, 4)
#
# /Users/fabriciomendozagranada/Documents/PhD Work/Implementation/b_chromatic/b_chromatic_algorithms_cubic_graphs.ipynb Cell 36 in find_b_chromatic_colouring_bruteforce(G, d)
#      <a href='vscode-notebook-cell:/Users/fabriciomendozagranada/Documents/PhD%20Work/Implementation/b_chromatic/b_chromatic_algorithms_cubic_graphs.ipynb#X46sZmlsZQ%3D%3D?line=12'>13</a> for Xs in colour_prod_permutations:
#      <a href='vscode-notebook-cell:/Users/fabriciomendozagranada/Documents/PhD%20Work/Implementation/b_chromatic/b_chromatic_algorithms_cubic_graphs.ipynb#X46sZmlsZQ%3D%3D?line=13'>14</a>     for i, vi in enumerate(node_sets):
# ---> <a href='vscode-notebook-cell:/Users/fabriciomendozagranada/Documents/PhD%20Work/Implementation/b_chromatic/b_chromatic_algorithms_cubic_graphs.ipynb#X46sZmlsZQ%3D%3D?line=14'>15</a>         for j, uj in enumerate(G.adj[vi]):
#      <a href='vscode-notebook-cell:/Users/fabriciomendozagranada/Documents/PhD%20Work/Implementation/b_chromatic/b_chromatic_algorithms_cubic_graphs.ipynb#X46sZmlsZQ%3D%3D?line=15'>16</a>             if uj not in node_sets:
#      <a href='vscode-notebook-cell:/Users/fabriciomendozagranada/Documents/PhD%20Work/Implementation/b_chromatic/b_chromatic_algorithms_cubic_graphs.ipynb#X46sZmlsZQ%3D%3D?line=16'>17</a>                 c[uj] = Xs[i][j]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/.tests/lib/python3.10/site-packages/networkx/classes/coreviews.py:81, in AdjacencyView.__getitem__(self, name)
#      67 """An AdjacencyView is a Read-only Map of Maps of Maps.
#      68
#      69 It is a View into a dict-of-dict-of-dict data structure.
#    (...)
#      76 MultiAdjacencyView: View into dict-of-dict-of-dict-of-dict
#      77 """
#      79 __slots__ = ()  # Still uses AtlasView slots names _atlas
# ---> 81 def __getitem__(self, name):
#      82     return AtlasView(self._atlas[name])
#      84 def copy(self):
#
# KeyboardInterrupt:

# %%
nx.draw(Gp, with_labels=True)

# %%
n = random.randint(5, 22)
n

# %% [markdown]
# ## Constructing 4-regular graphs with 7 nodes

# %%
G4 = nx.random_regular_graph(4,7)
nx.draw(G4, with_labels=True)
