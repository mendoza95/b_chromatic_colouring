# %% [raw]
# import pandas as pd
# df_res = pd.read_csv("partition_redistribution_heuristic_results.csv",
#                      sep=",",
#                      index_col=0)

# %%
df_res
# Out:
#        n  #colours_used  m_degree_G  #dense_vertices  #b_chromatic_vertices  \
# 0     50        12.0797     25.4209          28.6623                28.1837
# 1    100        20.0333     50.4356          54.8809                53.4121
# 2    150        27.3476     75.4606          80.8035                75.2146
# 3    200        34.2389    100.4675         106.5509                96.1788
# 4    250        40.7870    125.4706         132.2024               118.2580
# 5    300        47.0349    150.4656         157.7905               145.4484
# 6    350        53.4987    175.4627         183.4269               159.0384
# 7    400        59.1255    200.4654         208.9354               190.2040
# 8    450        65.3530    225.4762         234.3432               205.8040
# 9    500        71.4211    250.4689         259.8258               222.0344
# 10   550        76.4665    275.4895         285.2245               263.1880
# ...
