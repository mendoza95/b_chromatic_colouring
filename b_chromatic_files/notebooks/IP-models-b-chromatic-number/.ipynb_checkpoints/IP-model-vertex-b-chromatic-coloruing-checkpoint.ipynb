# %%
import pulp as pl
import networkx as nx

# %%
def get_m_degree(G):
    X = [0 for _ in range(0, len(G.nodes())+1)]
    Z = [0 for _ in range(0, len(G.nodes())+1)]
    max_j = 0
    for u in G.nodes(): X[G.degree(u)] += 1
    for j in range(len(G.nodes())-1, 0, -1): Z[j] = Z[j+1] + X[j]
    for j in range(1, len(G.nodes)):
        if Z[j-1] >= j:
            max_j = j
    return max_j

# %% [markdown]
# #### Choosing a random Graph

# %%
G = nx.random_regular_graph(d=3,n=6)

# %%
nx.draw(G, with_labels=True)

# %% [markdown]
# #### Model definition

# %%
b_chr_model = pl.LpProblem(name="b-chromatic-model")

# %% [markdown]
# #### Variables definition

# %%
n = len(G.nodes) #number of vertices
V = list(G.nodes)
c =  get_m_degree(G)-1#number of colours
C = range(c)

# %% [markdown]
# $x_{vc},z_{vc}\in \{0,1\} \hspace{1cm}\forall v\in V, \forall c\in C$
#
# $d_c\in \{0,1\}\hspace{1cm}\forall c \in C$

# %%
x_vars = {(v,c):pl.LpVariable(
                             cat=pl.LpBinary,
                             name="x_{0}_{1}".format(v,c))
            for v in V for c in C}

z_vars = {(v,c):pl.LpVariable(
                             cat=pl.LpBinary,
                             name="z_{0}_{1}".format(v,c))
            for v in V for c in C}

d_vars = {c:pl.LpVariable(
                cat=pl.LpBinary,
                name="d_{0}".format(c))
             for c in C}

# %% [markdown]
# #### Constraints

# %% [markdown]
# $\sum_{c\in C}x_{vc}=1\hspace{1cm}\forall v\in V$

# %%
one_colour_constraint = {v:b_chr_model.addConstraint(
                            pl.LpConstraint(
                                e=pl.lpSum(x_vars[v,c] for c in C),
                                sense=pl.LpConstraintEQ,
                                rhs=1,
                                name="one_colour_{}".format(v))
                        ) for v in V}

# %% [markdown]
# $x_{vc}+x_{wc}\leq 1\hspace{1cm}\forall vw\in E, \forall c\in C$

# %%
diff_colour_per_edge_constraint = {(v,w,c):b_chr_model.addConstraint(
                                            pl.LpConstraint(
                                                e=x_vars[v,c]+x_vars[w,c],
                                                sense=pl.LpConstraintLE,
                                                rhs=1,
                                                name="diff_colour_{0}_{1}_{2}".format(v,w,c)
                                            )) 
                                   for v, w in G.edges for c in C}

# %% [markdown]
# $z_{vc}\leq \sum_{w\in N(v)}x_{wd}\hspace{1cm} \forall v\in V,\forall c,d\in C, c\neq d$ (is forcing us to use all the colours)

# %%
b_chromatic_vertex_constraint = {(v,c,d):b_chr_model.addConstraint(
                                            pl.LpConstraint(
                                                e=z_vars[v,c]-pl.lpSum(x_vars[w,d] for w in G.neighbors(v)),
                                                sense=pl.LpConstraintLE,
                                                rhs=0,
                                                name="b_chr_vertex_{0}_{1}_{2}".format(v,c,d)
                                            )
                                        )
                                 for v in V for c in C for d in C if c!=d}

# %% [markdown]
# $d_c\leq \sum_{v\in V}z_{vc}\hspace{1cm} c\in C$

# %%
b_chromatic_vertices_constraint = {c:b_chr_model.addConstraint(
                                        pl.LpConstraint(
                                            e=d_vars[c]-pl.lpSum(z_vars[v,c] for v in V),
                                            sense=pl.LpConstraintLE,
                                            rhs=0,
                                            name="b_chro_colour_{0}".format(c)
                                        )
                                    )
                                  for c in C}

# %% [markdown]
# $d_c\geq \sum_{v\in V}x_{vc}\hspace{1cm}\forall c\in C$

# %%
#every_colour_b_chromatic = {c:b_chr_model.addConstraint(
#                                        pl.LpConstraint(
#                                            e=pl.lpSum(x_vars[v,c] for v in V)/n-d_vars[c],
#                                            sense=pl.LpConstraintLE,
#                                            rhs=0,
#                                            name="every_colour_b_chro_{0}".format(c)
#                                        )
#                                    )
#                                  for c in C}

# %%
for c in C:
    print(c,d_vars[c].value())
# Out:
# 0 None
# 1 None
# 2 None

# %% [markdown]
# #### Objective function

# %% [markdown]
# $\max \sum_{c\in C}d_c$

# %%
b_chromatic_number = pl.lpSum(d_vars[c] for c in C)

# %%
b_chr_model.sense = pl.LpMaximize
b_chr_model.setObjective(b_chromatic_number)

# %%
#b_chr_model.solve(solver=pl.get_solver("GUROBI_CMD"))
b_chr_model.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/Caskroom/miniforge/base/envs/.tests/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/ry/3v8_xnw15pd9mvfwjp4s44z80000gn/T/72bdf4f04a8b494eb803f936ca194e92-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/ry/3v8_xnw15pd9mvfwjp4s44z80000gn/T/72bdf4f04a8b494eb803f936ca194e92-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 77 COLUMNS
# At line 396 RHS
# At line 469 BOUNDS
# At line 509 ENDATA
# Problem MODEL has 72 rows, 39 columns and 237 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 3 - 0.00 seconds
# Cgl0004I processed model has 72 rows, 39 columns (39 integer (39 of which binary)) and 237 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 10 integers unsatisfied sum - 5
# Cbc0038I Pass   1: suminf.    5.00000 (10) obj. -3 iterations 13
# Cbc0038I Pass   2: suminf.    5.00000 (10) obj. -3 iterations 9
# Cbc0038I Pass   3: suminf.    5.66667 (17) obj. -3 iterations 18
# Cbc0038I Pass   4: suminf.    5.66667 (17) obj. -3 iterations 0
# Cbc0038I Pass   5: suminf.    6.00000 (12) obj. -3 iterations 21
# Cbc0038I Pass   6: suminf.    6.00000 (12) obj. -3 iterations 9
# Cbc0038I Pass   7: suminf.    6.00000 (12) obj. -3 iterations 4
# Cbc0038I Pass   8: suminf.    4.60000 (14) obj. -3 iterations 19
# Cbc0038I Pass   9: suminf.    4.33333 (13) obj. -3 iterations 12
# Cbc0038I Pass  10: suminf.    4.33333 (13) obj. -3 iterations 17
# Cbc0038I Pass  11: suminf.    4.33333 (13) obj. -3 iterations 6
# Cbc0038I Pass  12: suminf.    4.33333 (13) obj. -3 iterations 19
# Cbc0038I Pass  13: suminf.    5.61111 (19) obj. -2 iterations 22
# Cbc0038I Pass  14: suminf.    5.33333 (16) obj. -2 iterations 3
# Cbc0038I Pass  15: suminf.    4.33333 (13) obj. -2 iterations 17
# Cbc0038I Pass  16: suminf.    4.33333 (13) obj. -2 iterations 6
# Cbc0038I Pass  17: suminf.    4.33333 (13) obj. -2 iterations 18
# Cbc0038I Pass  18: suminf.    4.33333 (13) obj. -2 iterations 3
# Cbc0038I Pass  19: suminf.    4.33333 (13) obj. -2 iterations 17
# Cbc0038I Pass  20: suminf.    4.33333 (13) obj. -2 iterations 4
# Cbc0038I Pass  21: suminf.    6.00000 (12) obj. -2 iterations 11
# Cbc0038I Pass  22: suminf.    6.00000 (12) obj. -2 iterations 12
# Cbc0038I Pass  23: suminf.    6.00000 (12) obj. -2 iterations 6
# Cbc0038I Pass  24: suminf.    5.00000 (10) obj. -1 iterations 11
# Cbc0038I Pass  25: suminf.    5.00000 (10) obj. -1 iterations 7
# Cbc0038I Pass  26: suminf.    5.00000 (10) obj. -1 iterations 5
# Cbc0038I Pass  27: suminf.    6.00000 (12) obj. -2 iterations 26
# Cbc0038I Pass  28: suminf.    6.00000 (12) obj. -2 iterations 16
# Cbc0038I Pass  29: suminf.    6.00000 (12) obj. -2 iterations 9
# Cbc0038I Pass  30: suminf.    6.00000 (12) obj. -1 iterations 13
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 72 rows 39 columns, reduced to 64 rows 35 columns
# Cbc0038I Mini branch and bound improved solution from 1.79769e+308 to -1 (0.09 seconds)
# Cbc0038I Round again with cutoff of -2.09991
# Cbc0038I Reduced cost fixing fixed 3 variables on major pass 2
# Cbc0038I Pass  30: suminf.    5.00000 (10) obj. -3 iterations 0
# Cbc0038I Pass  31: suminf.    5.00000 (10) obj. -3 iterations 8
# Cbc0038I Pass  32: suminf.    5.00000 (10) obj. -3 iterations 6
# Cbc0038I Pass  33: suminf.    5.00000 (10) obj. -3 iterations 9
# Cbc0038I Pass  34: suminf.    5.00000 (10) obj. -3 iterations 9
# Cbc0038I Pass  35: suminf.    6.00000 (12) obj. -3 iterations 15
# Cbc0038I Pass  36: suminf.    6.00000 (12) obj. -3 iterations 13
# Cbc0038I Pass  37: suminf.    6.00000 (12) obj. -3 iterations 9
# Cbc0038I Pass  38: suminf.    5.00000 (15) obj. -3 iterations 17
# Cbc0038I Pass  39: suminf.    5.00000 (15) obj. -3 iterations 6
# Cbc0038I Pass  40: suminf.    5.00000 (15) obj. -3 iterations 15
# Cbc0038I Pass  41: suminf.    5.00000 (15) obj. -3 iterations 4
# Cbc0038I Pass  42: suminf.    5.00000 (15) obj. -3 iterations 9
# Cbc0038I Pass  43: suminf.    5.33333 (16) obj. -3 iterations 12
# Cbc0038I Pass  44: suminf.    5.33333 (16) obj. -3 iterations 2
# Cbc0038I Pass  45: suminf.    5.33333 (16) obj. -3 iterations 11
# Cbc0038I Pass  46: suminf.    5.33333 (16) obj. -3 iterations 2
# Cbc0038I Pass  47: suminf.    5.33333 (16) obj. -3 iterations 12
# Cbc0038I Pass  48: suminf.    5.33333 (16) obj. -3 iterations 12
# Cbc0038I Pass  49: suminf.    5.33333 (16) obj. -3 iterations 7
# Cbc0038I Pass  50: suminf.    5.33333 (16) obj. -3 iterations 3
# Cbc0038I Pass  51: suminf.    5.33333 (16) obj. -3 iterations 12
# Cbc0038I Pass  52: suminf.    5.33333 (16) obj. -3 iterations 3
# Cbc0038I Pass  53: suminf.    5.33333 (16) obj. -3 iterations 6
# Cbc0038I Pass  54: suminf.    5.60000 (17) obj. -3 iterations 17
# Cbc0038I Pass  55: suminf.    5.33333 (16) obj. -3 iterations 3
# Cbc0038I Pass  56: suminf.    5.33333 (16) obj. -3 iterations 6
# Cbc0038I Pass  57: suminf.    5.33333 (16) obj. -3 iterations 11
# Cbc0038I Pass  58: suminf.    5.33333 (16) obj. -3 iterations 4
# Cbc0038I Pass  59: suminf.    5.33333 (16) obj. -3 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 11 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 72 rows 39 columns, reduced to 49 rows 24 columns
# Cbc0038I Mini branch and bound did not improve solution (0.10 seconds)
# Cbc0038I After 0.10 seconds - Feasibility pump exiting with objective of -1 - took 0.08 seconds
# Cbc0012I Integer solution of -1 found by feasibility pump after 0 iterations and 0 nodes (0.11 seconds)
# Cbc0038I Full problem 72 rows 39 columns, reduced to 16 rows 7 columns
# Cbc0031I 14 added rows had average density of 6.9285714
# Cbc0013I At root node, 14 cuts changed objective from -3 to -3 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 615 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 621 row cuts average 27.4 elements, 0 column cuts (0 active)  in 0.013 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 10 row cuts average 5.7 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 3 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 2 row cuts average 10.5 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 60 row cuts average 13.2 elements, 0 column cuts (0 active)  in 0.010 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 109 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.351 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -1 best solution, best possible -3 (0.61 seconds)
# Cbc0001I Search completed - best objective -1, took 1947 iterations and 12 nodes (0.63 seconds)
# Cbc0032I Strong branching done 236 times (1611 iterations), fathomed 3 nodes and fixed 1 variables
# Cbc0035I Maximum depth 5, 4 variables fixed on reduced cost
# Cuts at root node changed objective from -3 to -3
# Probing was tried 100 times and created 615 cuts of which 0 were active after adding rounds of cuts (0.017 seconds)
# Gomory was tried 100 times and created 621 cuts of which 0 were active after adding rounds of cuts (0.013 seconds)
# Knapsack was tried 100 times and created 10 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# Clique was tried 100 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# MixedIntegerRounding2 was tried 100 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 100 times and created 60 cuts of which 0 were active after adding rounds of cuts (0.010 seconds)
# ZeroHalf was tried 100 times and created 109 cuts of which 0 were active after adding rounds of cuts (0.351 seconds)
# ImplicationCuts was tried 13 times and created 263 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               12
# Total iterations:               1947
# Time (CPU seconds):             0.59
# Time (Wallclock seconds):       0.64
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.59   (Wallclock seconds):       0.65
# 1

# %%
for c in C:
    print(d_vars[c].value())
# Out:
# 0.0
# 0.0
# 1.0

# %%
for v in V:
    for c in C:
        if x_vars[v,c].value() == 1.0:
            print(v,c)
# Out:
# 0 3
# 1 1
# 2 2
# 4 3
# 3 3
# 5 0

# %% [markdown]
# ### Results

# %%
import pickle as pkl

# %%
with open("Linear_program_model_results.pkl", "rb") as handle:
    results = pkl.load(handle)

# %%
results.keys()
# Out:
# dict_keys([3, 4, 5, 6, 7, 8])

# %%
def show_b_chromatic_number_by_degree(results, d):
    print("{}-regular graphs".format(d))
    for key in results[d].keys():
        if(results[d][key] != {}):
            print("# vertices: {} -> b-chromatic number: {}".format(key, results[d][key]["solution"]))

# %%
show_b_chromatic_number_by_degree(results, 3)
# Out:
# 3-regular graphs
# # vertices: 6 -> b-chromatic number: 3.0
# # vertices: 8 -> b-chromatic number: 4.0
# # vertices: 10 -> b-chromatic number: 4.0
# # vertices: 12 -> b-chromatic number: 4.0
# # vertices: 14 -> b-chromatic number: 4.0
# # vertices: 16 -> b-chromatic number: 4.0
# # vertices: 18 -> b-chromatic number: 4.0
# # vertices: 20 -> b-chromatic number: 4.0
# # vertices: 22 -> b-chromatic number: 4.0
# # vertices: 24 -> b-chromatic number: 4.0
# # vertices: 26 -> b-chromatic number: 4.0
# # vertices: 28 -> b-chromatic number: 4.0
# # vertices: 30 -> b-chromatic number: 4.0
# # vertices: 32 -> b-chromatic number: 4.0
# # vertices: 34 -> b-chromatic number: 4.0
# # vertices: 36 -> b-chromatic number: 4.0
# # vertices: 38 -> b-chromatic number: 4.0
# # vertices: 40 -> b-chromatic number: 4.0
# # vertices: 42 -> b-chromatic number: 4.0
# # vertices: 44 -> b-chromatic number: 4.0
# # vertices: 46 -> b-chromatic number: 4.0
# # vertices: 48 -> b-chromatic number: 4.0
# # vertices: 50 -> b-chromatic number: 4.0
# # vertices: 52 -> b-chromatic number: 4.0
# # vertices: 54 -> b-chromatic number: 4.0
# # vertices: 56 -> b-chromatic number: 4.0
# # vertices: 58 -> b-chromatic number: 4.0
# # vertices: 60 -> b-chromatic number: 4.0
# # vertices: 62 -> b-chromatic number: 4.0
# # vertices: 64 -> b-chromatic number: 4.0
# # vertices: 66 -> b-chromatic number: 4.0
# # vertices: 68 -> b-chromatic number: 4.0
# # vertices: 70 -> b-chromatic number: 4.0
# # vertices: 72 -> b-chromatic number: 4.0
# # vertices: 74 -> b-chromatic number: 4.0
# # vertices: 76 -> b-chromatic number: 4.0
# # vertices: 78 -> b-chromatic number: 4.0
# # vertices: 80 -> b-chromatic number: 4.0
# # vertices: 82 -> b-chromatic number: 4.0
# # vertices: 84 -> b-chromatic number: 4.0
# # vertices: 86 -> b-chromatic number: 4.0
# # vertices: 88 -> b-chromatic number: 4.0
# # vertices: 90 -> b-chromatic number: 4.0
# # vertices: 92 -> b-chromatic number: 4.0
# # vertices: 94 -> b-chromatic number: 4.0
# # vertices: 96 -> b-chromatic number: 4.0
# # vertices: 98 -> b-chromatic number: 4.0

# %%
show_b_chromatic_number_by_degree(results, 4)
# Out:
# 4-regular graphs
# # vertices: 6 -> b-chromatic number: 3.0
# # vertices: 7 -> b-chromatic number: 3.0
# # vertices: 8 -> b-chromatic number: 4.0
# # vertices: 9 -> b-chromatic number: 4.0
# # vertices: 10 -> b-chromatic number: 5.0
# # vertices: 11 -> b-chromatic number: 5.0
# # vertices: 12 -> b-chromatic number: 5.0
# # vertices: 38 -> b-chromatic number: 8.0
# # vertices: 40 -> b-chromatic number: 8.0
# # vertices: 42 -> b-chromatic number: 8.0
# # vertices: 44 -> b-chromatic number: 8.0
# # vertices: 46 -> b-chromatic number: 8.0
# # vertices: 48 -> b-chromatic number: 8.0
# # vertices: 50 -> b-chromatic number: 8.0
# # vertices: 52 -> b-chromatic number: 8.0
# # vertices: 54 -> b-chromatic number: 8.0
# # vertices: 56 -> b-chromatic number: 8.0
# # vertices: 58 -> b-chromatic number: 8.0
# # vertices: 60 -> b-chromatic number: 8.0
# # vertices: 62 -> b-chromatic number: 8.0
# # vertices: 64 -> b-chromatic number: 8.0
# # vertices: 66 -> b-chromatic number: 8.0
# # vertices: 68 -> b-chromatic number: 8.0
# # vertices: 70 -> b-chromatic number: 8.0
# # vertices: 72 -> b-chromatic number: 8.0
# # vertices: 74 -> b-chromatic number: 8.0
# # vertices: 76 -> b-chromatic number: 8.0
# # vertices: 78 -> b-chromatic number: 8.0
# # vertices: 80 -> b-chromatic number: 8.0
# # vertices: 82 -> b-chromatic number: 8.0
# # vertices: 84 -> b-chromatic number: 8.0
# # vertices: 86 -> b-chromatic number: 8.0
# # vertices: 88 -> b-chromatic number: 8.0
# # vertices: 90 -> b-chromatic number: 8.0
# # vertices: 92 -> b-chromatic number: 8.0
# # vertices: 94 -> b-chromatic number: 8.0
# # vertices: 96 -> b-chromatic number: 8.0
# # vertices: 98 -> b-chromatic number: 8.0

# %%
show_b_chromatic_number_by_degree(results, 8)
# Out:
# 8-regular graphs
# # vertices: 10 -> b-chromatic number: 5.0
# # vertices: 11 -> b-chromatic number: 5.0
# # vertices: 12 -> b-chromatic number: 6.0
# # vertices: 13 -> b-chromatic number: 7.0
# # vertices: 14 -> b-chromatic number: 7.0
# # vertices: 15 -> b-chromatic number: 7.0
# # vertices: 16 -> b-chromatic number: 7.0
# # vertices: 17 -> b-chromatic number: 8.0
# # vertices: 18 -> b-chromatic number: 7.0
# # vertices: 19 -> b-chromatic number: 8.0
# # vertices: 20 -> b-chromatic number: 8.0
# # vertices: 21 -> b-chromatic number: 8.0
# # vertices: 22 -> b-chromatic number: 8.0
# # vertices: 23 -> b-chromatic number: 8.0
# # vertices: 24 -> b-chromatic number: 8.0
# # vertices: 25 -> b-chromatic number: 8.0
# # vertices: 26 -> b-chromatic number: 8.0
# # vertices: 27 -> b-chromatic number: 8.0

# %%
results[8][27]["colouring"]
# Out:
# {15: 2,
#  21: 3,
#  16: 3,
#  20: 0,
#  7: 2,
#  17: 5,
#  26: 4,
#  4: 1,
#  9: 4,
#  3: 4,
#  13: 2,
#  12: 6,
#  25: 5,
#  22: 6,
#  8: 7,
#  18: 1,
#  11: 7,
#  14: 0,
#  23: 3,
#  19: 0,
#  24: 7,
#  0: 1,
#  6: 0,
#  1: 1,
#  5: 2,
#  10: 5,
#  2: 6}
