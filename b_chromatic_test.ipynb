# %%
from b_chromatic_colouring import *
from b_chromatic_utils import *
from timeit import default_timer as timer
from IPython.display import clear_output
from scipy.sparse.csgraph import minimum_spanning_tree

# %%
n_vertices_list = [i for i in range(100,1100,100)]+[j for j in range(1500,10500,500)]

# %% [markdown]
# Testing time when generating MST trees

# %%
mst_times = []
for n in n_vertices_list:
    t = timer()
    Ti = random_mst_tree(n)
    t = timer()-t
    mst_times.append(t)
    print("{} -> {}".format(n, t))
# Out:
# 100 -> 0.015524121999987983
# 200 -> 0.0832444799999621
# 300 -> 0.1163200199999892
# 400 -> 0.28787130900002467
# 500 -> 0.45793343100001493
# 600 -> 0.6219327049999492
# 700 -> 0.8948518390000118
# 800 -> 1.159899176999943
# 900 -> 1.5583321980000164
# 1000 -> 1.8938146170000891
# 1500 -> 4.3882951379999895
# 2000 -> 8.041179072999967
# 2500 -> 12.815910607000092
# 3000 -> 17.82892937500003
# 3500 -> 25.09508211100001
# 4000 -> 32.6042324
# 4500 -> 43.918743300000074
# 5000 -> 55.52445067999997
# 5500 -> 67.98326554899995
# 6000 -> 81.98290298100005
# 6500 -> 91.40736554799992
# 7000 -> 101.51969100099996
# 7500 -> 128.78330323399996
# 8000 -> 137.85003239999992
# 8500 -> 168.3835612280002
# 9000 -> 191.59912505900002
# 9500 -> 196.66236717000015
# 10000 -> 232.29282630600028

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1)
ax.set_xlabel("Number of vertices")
ax.set_ylabel("Execution time in seconds")
ax.plot(n_vertices_list, mst_times, "-go", label="Random Tree via MST")
ax.legend()
fig.savefig("random_tree_mst_execution_time.pdf")

# %%
bfs_times = []
for n in n_vertices_list:
    t = timer()
    Ti = random_bfs_tree(n)
    t = timer()-t
    bfs_times.append(t)
    print("{} -> {}".format(n, t))
# Out:
# 100 -> 0.3074662910075858
# 200 -> 0.0008059170213527977
# 300 -> 0.00126391596859321
# 400 -> 0.0020048749865964055
# 500 -> 0.003065542026888579
# 600 -> 0.0035083339898847044
# 700 -> 0.0045205409987829626
# 800 -> 0.005563708022236824
# 900 -> 0.00684874999569729
# 1000 -> 0.008018166001420468
# 1500 -> 0.016640709014609456
# 2000 -> 0.02848999999696389
# 2500 -> 0.044209874991793185
# 3000 -> 0.06185945897595957
# 3500 -> 0.0838783749495633
# 4000 -> 0.10774187499191612
# 4500 -> 0.13424020900856704
# 5000 -> 0.17222483397927135
# 5500 -> 0.202980958041735
# 6000 -> 0.2748851670185104
# 6500 -> 0.27510091598378494
# 7000 -> 0.3187308330088854
# 7500 -> 0.37417399999685585
# 8000 -> 0.41455558297457173
# 8500 -> 0.46940820902818814
# 9000 -> 0.5276124170050025
# 9500 -> 0.6176929579814896
# 10000 -> 0.6371187909971923

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1)
ax.set_xlabel("Number of vertices")
ax.set_ylabel("Execution time in seconds")
ax.plot(n_vertices_list, bfs_times, "-go", label="Random Tree via BFS")
ax.legend()
fig.savefig("random_tree_bfs_execution_time.pdf")

# %%
rtrees_times = []
for n in n_vertices_list:
    t = timer()
    Ti = random_recursive_tree(n)
    t = timer()-t
    rtrees_times.append(t)
    print("{} -> {}".format(n, t))
# Out:
# 100 -> 0.0009798750397749245
# 200 -> 0.00040954200085252523
# 300 -> 0.0004539170186035335
# 400 -> 0.0006602499634027481
# 500 -> 0.0007706250180490315
# 600 -> 0.0008938329992815852
# 700 -> 0.0010599579545669258
# 800 -> 0.0013896669843234122
# 900 -> 0.0013522079680114985
# 1000 -> 0.001497749995905906
# 1500 -> 0.0025619170046411455
# 2000 -> 0.0032790410332381725
# 2500 -> 0.004066333989612758
# 3000 -> 0.004902874992694706
# 3500 -> 0.005708250042516738
# 4000 -> 0.006375833007041365
# 4500 -> 0.0071012499975040555
# 5000 -> 0.00822541699744761
# 5500 -> 0.009056125010829419
# 6000 -> 0.009793207980692387
# 6500 -> 0.05922829202609137
# 7000 -> 0.011163583025336266
# 7500 -> 0.011973457993008196
# 8000 -> 0.01271795795764774
# 8500 -> 0.013804415997583419
# 9000 -> 0.01459808397339657
# 9500 -> 0.01513658300973475
# 10000 -> 0.07133908401010558

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1)
ax.set_xlabel("Number of vertices")
ax.set_ylabel("Execution time in seconds")
ax.plot(n_vertices_list, rtrees_times, "-go", label="Recursive Random Tree")
ax.legend()
fig.savefig("recursive_random_tree_execution_time.pdf")

# %%
prufer_trees_times = []
for n in n_vertices_list:
    t = timer()
    Ti = nx.random_tree(n)
    t = timer()-t
    prufer_trees_times.append(t)
    print("{} -> {}".format(n, t))
# Out:
# 100 -> 0.0015403329744003713
# 200 -> 0.00048216601135209203
# 300 -> 0.0008014580234885216
# 400 -> 0.0009974169661290944
# 500 -> 0.0012585000367835164
# 600 -> 0.0015099170268513262
# 700 -> 0.00178341701393947
# 800 -> 0.002174958004616201
# 900 -> 0.002192416985053569
# 1000 -> 0.0026796659803949296
# 1500 -> 0.003963958995882422
# 2000 -> 0.005051916989032179
# 2500 -> 0.006729708984494209
# 3000 -> 0.007882916019298136
# 3500 -> 0.009152749960776418
# 4000 -> 0.010341458022594452
# 4500 -> 0.011574750009458512
# 5000 -> 0.01306733296951279
# 5500 -> 0.014651832985691726
# 6000 -> 0.015640583005733788
# 6500 -> 0.016940791974775493
# 7000 -> 0.018811874964740127
# 7500 -> 0.01946700003463775
# 8000 -> 0.0734477499499917
# 8500 -> 0.02467225003056228
# 9000 -> 0.025799916009418666
# 9500 -> 0.026953874970786273
# 10000 -> 0.026395958964712918

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1)
ax.set_xlabel("Number of vertices")
ax.set_ylabel("Execution time in seconds")
ax.plot(n_vertices_list, prufer_trees_times, "-go", label="Prüfer Random Tree")
ax.legend()
fig.savefig("prufer_tree_execution_time.pdf")

# %% [markdown]
# We'll check on the acumulated time for generating the trees

# %%
#added_mst_times = [sum(mst_times[:i]) for i in range(len(mst_times))]
added_bfs_times = [sum(bfs_times[:i]) for i in range(len(bfs_times))]
added_rtrees_times = [sum(rtrees_times[:i]) for i in range(len(rtrees_times))]
added_prufer_times = [sum(prufer_trees_times[:i]) for i in range(len(prufer_trees_times))]

# %%
fig, ax = plt.subplots(1)
ax.set_xlabel("Number of vertices")
ax.set_ylabel("Cumulative Execution time in seconds")
#ax.plot(n_vertices_list, added_mst_times, "-ro", label="MST Random Tree")
ax.plot(n_vertices_list, added_bfs_times, "-bo", label="BFS Random Tree")
ax.plot(n_vertices_list, added_rtrees_times, "-yo", label="Recursive Random Tree")
ax.plot(n_vertices_list, added_prufer_times, "-go", label="Prüfer Random Tree")
ax.legend()
fig.savefig("cumulative_execution_times.pdf")

# %% [markdown]
# The recursive and prufer tree generation techniques evolve linearly while MST and BFS exponentially. We are going to generate 5000 samples for the recursive and prufer techniques and 1000 samples for the other two. While the maximum number of vertices for the recursive and prufer technique will be 10000 for the MST technique the maximum number of vertices will be 5000 and for the BST technique 4000.

# %%
n_vertices_list1 = [i for i in range(100,1100,100)]+[j for j in range(1500, 10500,500)]
n_vertices_list2 = [i for i in range(100,1100,100)]+[j for j in range(1500, 5500,500)]
n_vertices_list3 = [i for i in range(100,1100,100)]+[j for j in range(1500, 4500,500)]

# %%
with open("saving_trees_1.trees", "a") as f:
    for n in n_vertices_list1:
        for _ in range(1000):
            Ti = nx.random_tree(n)
            f.write("{} {}\n".format(len(Ti.nodes()), len(Ti.edges())))
            for u, v in Ti.edges():
                f.write("{} {}\n".format(u,v))

# %%
with open("saving_trees_1.trees", "r") as f:
    for n in n_vertices_list1:
        for i in range (1000):

# %%
n = 30
G1 = nx.random_tree(n)
G2 = random_mst_tree(n)
G3 = random_recursive_tree(n)
G4 = random_bfs_tree(n)

# %%
nx.draw(G1, with_labels=True)

# %%
nx.draw(G2, with_labels=True)

# %%
nx.draw(G3, with_labels=True)

# %%
nx.draw(G4, with_labels=True)

# %%
edges_indexes = {i*n+j:False for i in range(n) for j in range(i+1, n)}
vertices_sets = [i for i in range(n)]
edges_list = []
while len(edges_list) < n-1:
    i = random.randint(1,n-2)
    j = random.randint(i+1,n-1)
    if i != j and edges_indexes[i*n+j] is False and vertices_sets[i] != vertices_sets[j]:
        edges_list.append((i,j))
        vertices_sets[j] = vertices_sets[i]
        edges_indexes[i*n+j] = True

# %%
edges_list
# Out:
# [(3, 4), (4, 8), (4, 6), (5, 6), (6, 8), (2, 8), (2, 5), (4, 7), (6, 9)]

# %%
T = nx.Graph(edges_list)
nx.draw(T, with_labels=True)
